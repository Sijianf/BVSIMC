# %% [markdown]
# # Run NRLMF

# %%
import os
import time
import gzip
import pickle
import warnings

# %matplotlib inline
import matplotlib.pyplot as plt

import numpy as np

from tqdm import TqdmSynchronisationWarning
warnings.simplefilter("ignore", TqdmSynchronisationWarning)

# %%
PATH_ROOT = "/Users/sijianfan/Documents/projects/BiSSGL"
PATH_DATA = os.path.join(PATH_ROOT, "datasets/realAnalysis/cdataset/cv_data")

PATH_OUTPUT = os.path.join(PATH_ROOT, "outputs/results/realAnalysis/cdataset/separate")
if not os.path.isdir(PATH_OUTPUT):
    os.makedirs(PATH_OUTPUT)

PATH_ARCHIVE = os.path.join(PATH_OUTPUT, "archived")
if not os.path.isdir(PATH_ARCHIVE):
    os.makedirs(PATH_ARCHIVE)

# %%
filename_staged = os.path.join(PATH_DATA, "staged_dataset.gz")

filenames = {"input": "staged_dataset.gz", "output": "results_nrlmf.gz"}

# %%
filename_input = os.path.join(PATH_DATA, filenames["input"])

filename_output = os.path.join(PATH_OUTPUT, filenames["output"])

if os.path.exists(filename_output):
    mdttm = time.strftime("%Y%m%d_%H%M%S")
    os.rename(
        filename_output,
        os.path.join(PATH_ARCHIVE, "%s%s" % (mdttm, filenames["output"])),
    )

# %%
from sgimc.utils import mc_split

# %%
from sgimc.utils import get_submatrix

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_auc_score
from sgimc.utils import sparsify_with_mask


def mc_get_scores(R_true, R_prob):
    R_pred = np.where(R_prob.data > 0.5, 1, -1)

    # compute the confusion matrix for ±1 labels (`-1` is negative)
    ii, jj = ((R_pred + 1) // 2).astype(int), ((R_true.data + 1) // 2).astype(int)
    cnfsn = confusion_matrix(y_true=jj, y_pred=ii)

    return {
        "tn": cnfsn[0, 0],
        "fn": cnfsn[1, 0],
        "fp": cnfsn[0, 1],
        "tp": cnfsn[1, 1],
        "auc": roc_auc_score(R_true.data, R_prob.data),
    }

# %%
import numpy as np


def get_metrics(real_score, predict_score):
    sorted_predict_score = np.array(
        sorted(list(set(np.array(predict_score).flatten())))
    )
    sorted_predict_score_num = len(sorted_predict_score)
    thresholds = sorted_predict_score[
        np.int32(sorted_predict_score_num * np.arange(1, 1000) / 1000)
    ]
    thresholds = np.mat(thresholds)
    thresholds_num = thresholds.shape[1]

    predict_score_matrix = np.tile(predict_score, (thresholds_num, 1))
    negative_index = np.where(predict_score_matrix < thresholds.T)
    positive_index = np.where(predict_score_matrix >= thresholds.T)
    predict_score_matrix[negative_index] = 0
    predict_score_matrix[positive_index] = 1
    TP = predict_score_matrix.dot(real_score.T)
    FP = predict_score_matrix.sum(axis=1) - TP
    FN = real_score.sum() - TP
    TN = len(real_score.T) - TP - FP - FN

    fpr = FP / (FP + TN)
    tpr = TP / (TP + FN)
    ROC_dot_matrix = np.mat(sorted(np.column_stack((fpr, tpr)).tolist())).T
    ROC_dot_matrix.T[0] = [0, 0]
    ROC_dot_matrix = np.c_[ROC_dot_matrix, [1, 1]]
    x_ROC = ROC_dot_matrix[0].T
    y_ROC = ROC_dot_matrix[1].T
    auc = 0.5 * (x_ROC[1:] - x_ROC[:-1]).T * (y_ROC[:-1] + y_ROC[1:])

    recall_list = tpr
    precision_list = TP / (TP + FP)
    PR_dot_matrix = np.mat(
        sorted(np.column_stack((recall_list, precision_list)).tolist())
    ).T
    PR_dot_matrix.T[0] = [0, 1]
    PR_dot_matrix = np.c_[PR_dot_matrix, [1, 0]]
    x_PR = PR_dot_matrix[0].T
    y_PR = PR_dot_matrix[1].T
    aupr = 0.5 * (x_PR[1:] - x_PR[:-1]).T * (y_PR[:-1] + y_PR[1:])

    f1_score_list = 2 * TP / (len(real_score.T) + TP - TN)
    accuracy_list = (TP + TN) / len(real_score.T)
    specificity_list = TN / (TN + FP)

    max_index = np.argmax(f1_score_list)
    f1_score = f1_score_list[max_index]
    accuracy = accuracy_list[max_index]
    specificity = specificity_list[max_index]
    recall = recall_list[max_index]
    precision = precision_list[max_index]
    return [aupr[0, 0], auc[0, 0], f1_score, accuracy, recall, specificity, precision]

# %%
random_state = np.random.RandomState(0x0BADCAFE)

# %% [markdown]
# ## Import model

# %%
# import sys
# import getopt

# package-qualified imports (preferred)
# from PyDTI3 import cv_eval  # if cv_eval exposes functions at top-level
# from PyDTI3.functions import *
from PyDTI3.nrlmf import NRLMF

# from PyDTI3.new_pairs import novel_prediction_analysis

# %% [markdown]
# ## Load data

# %%
from sgimc.utils import load, save

U, V, Y = load(filename_input)

Y = Y.astype(float)

# %% [markdown]
# ## Without selection

# %% [markdown]
# ### Prepare similarity matrix

# %%
# Quick prepare of similarity matrix
from sklearn.metrics.pairwise import cosine_similarity

simD = cosine_similarity(U[:, :])
simT = cosine_similarity(V[:, :])

# %%
# Jaccard distance → convert to similarity
from sklearn.metrics import pairwise_distances

simD = 1 - pairwise_distances(U.toarray(), metric="jaccard")
simT = 1 - pairwise_distances(V.toarray(), metric="jaccard")
# Out:
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/sklearn/metrics/pairwise.py:2182: DataConversionWarning: Data was converted to boolean for metric jaccard
#   warnings.warn(msg, DataConversionWarning)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/sklearn/metrics/pairwise.py:2182: DataConversionWarning: Data was converted to boolean for metric jaccard
#   warnings.warn(msg, DataConversionWarning)

# %% [markdown]
# ### Implementation

# %%
dvlp_size, test_size = 0.9, 0.1

ind_dvlp, ind_test = next(
    mc_split(
        Y,
        n_splits=1,
        random_state=random_state,
        train_size=dvlp_size,
        test_size=test_size,
    )
)

Y_test = get_submatrix(Y, ind_test)

# %%
from sklearn.model_selection import ParameterGrid

grid_dataset = ParameterGrid(
    {
        "train_size": np.arange(0.1, 0.9, 0.1),
        # "train_size": [0.2],
        "n_splits": [5],
    }
)

grid_model = ParameterGrid(
    {
        "c": [1, 3, 5, 7, 9],  # confidence level
        # "c": [5],  # confidence level
        "K1": [5],
        "K2": [5],
        "r": [50, 200],  # rank
        "lambda_d": [0.125],
        "lambda_t": [0.125],
        "alpha": [0.25],
        "beta": [0.125],
        "theta": [0.5],
        "max_iter": [100],
    }
)

# %%
from tqdm import tqdm
from sklearn.model_selection import ShuffleSplit, KFold
from sklearn.model_selection import train_test_split
from scipy.special import expit


results = []
for par_dtst in tqdm(grid_dataset):
    # prepare the train dataset: take the specified share from the beginnig of the index array
    ind_train_all, _ = train_test_split(
        ind_dvlp,
        shuffle=False,
        random_state=random_state,
        test_size=(1 - (par_dtst["train_size"] / dvlp_size)),
    )

    # Run the experiment: the model
    for par_mdl in grid_model:  # tqdm.tqdm(, desc="cv %02d" % (cv,))
        Y_train = get_submatrix(Y, ind_train_all)
        Y_train[Y_train == 0] = 0.5
        Y_train[Y_train == -1] = 0.0

        # set up the model
        model = NRLMF(
            cfix=par_mdl["c"],
            K1=par_mdl["K1"],
            K2=par_mdl["K2"],
            num_factors=par_mdl["r"],
            lambda_d=par_mdl["lambda_d"],
            lambda_t=par_mdl["lambda_t"],
            alpha=par_mdl["alpha"],
            beta=par_mdl["beta"],
            theta=par_mdl["theta"],
            max_iter=par_mdl["max_iter"],
        )

        # fit on the whole development dataset
        model.fix_model(
            np.ones((Y_train.shape[0], Y_train.shape[1])), Y_train.toarray(), simD, simT
        )
        est_A, est_B = model.U, model.V

        # get the score
        prob_full = expit(simD @ est_A @ est_B.T @ simT.T)
        prob_test = get_submatrix(prob_full, ind_test)
        scores_test = get_metrics((Y_test.data + 1) / 2, prob_test.data)
        d1_test = sum(abs(est_A).max(axis=1) > 0)
        d2_test = sum(abs(est_B).max(axis=1) > 0)

        # record the results
        results.append(
            {
                "train_size": par_dtst["train_size"],
                "lambda_d": par_mdl["lambda_d"],
                "lambda_t": par_mdl["lambda_t"],
                "c": par_mdl["c"],
                "r": par_mdl["r"],
                "test_score": scores_test,
                "test_d1": d1_test,
                "test_d2": d2_test,
            }
        )
# Out:
# 100%|██████████| 8/8 [01:31<00:00, 11.38s/it]

# %%
results
# Out:
# [{'train_size': 0.1,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 1,
#   'r': 50,
#   'test_score': [0.007389338186916924,
#    0.5081525515560957,
#    0.02753441802252816,
#    0.9711291940697804,
#    0.044897959183673466,
#    0.9796385180740963,
#    0.019855595667870037],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.1,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 1,
#   'r': 200,
#   'test_score': [0.02444216131698628,
#    0.5170265976497093,
#    0.0546448087431694,
#    0.9871437595214209,
#    0.04081632653061224,
#    0.9958377081145943,
#    0.08264462809917356],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.1,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 3,
#   'r': 50,
#   'test_score': [0.007832957541483372,
#    0.5083617757887616,
#    0.03379416282642089,
#    0.9766283951993461,
#    0.044897959183673466,
#    0.9851882405879706,
#    0.027093596059113302],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.1,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 3,
#   'r': 200,
#   'test_score': [0.020379014035015623,
#    0.517029429140788,
#    0.05115089514066496,
#    0.9862148404116969,
#    0.04081632653061224,
#    0.9949002549872507,
#    0.0684931506849315],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.1,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 5,
#   'r': 50,
#   'test_score': [0.0074023150194354355,
#    0.5082593064224338,
#    0.029372496662216287,
#    0.9729870322892282,
#    0.044897959183673466,
#    0.9815134243287835,
#    0.021825396825396824],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.1,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 5,
#   'r': 200,
#   'test_score': [0.03969401722700003,
#    0.5160904454777261,
#    0.05141388174807198,
#    0.9862891539404749,
#    0.04081632653061224,
#    0.9949752512374381,
#    0.06944444444444445],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.1,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 7,
#   'r': 50,
#   'test_score': [0.007631214324583271,
#    0.5083158597172182,
#    0.032362459546925564,
#    0.9777802548954037,
#    0.04081632653061224,
#    0.9863881805909704,
#    0.02680965147453083],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.1,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 7,
#   'r': 200,
#   'test_score': [0.0380059860485941,
#    0.5151084537609855,
#    0.050505050505050504,
#    0.9860290565897522,
#    0.04081632653061224,
#    0.9947127643617819,
#    0.06622516556291391],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.1,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 9,
#   'r': 50,
#   'test_score': [0.007564095611320503,
#    0.5081830092168861,
#    0.027149321266968326,
#    0.968045182625497,
#    0.04897959183673469,
#    0.9764886755662217,
#    0.018779342723004695],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.1,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 9,
#   'r': 200,
#   'test_score': [0.020717859149721192,
#    0.5144384617503818,
#    0.04395604395604396,
#    0.9838368074908037,
#    0.04081632653061224,
#    0.992500374981251,
#    0.047619047619047616],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.2,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 1,
#   'r': 50,
#   'test_score': [0.007397199954435182,
#    0.5081494904846594,
#    0.026845637583892617,
#    0.9676736149816074,
#    0.04897959183673469,
#    0.9761136943152843,
#    0.01848998459167951],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.2,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 1,
#   'r': 200,
#   'test_score': [0.03707987499402641,
#    0.5146456197598284,
#    0.04987531172069826,
#    0.9858432727678074,
#    0.04081632653061224,
#    0.9945252737363132,
#    0.0641025641025641],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.2,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 3,
#   'r': 50,
#   'test_score': [0.007557539473294036,
#    0.5082293844491448,
#    0.029239766081871343,
#    0.9753279084457326,
#    0.04081632653061224,
#    0.9839133043347833,
#    0.022779043280182234],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.2,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 3,
#   'r': 200,
#   'test_score': [0.01826791716557383,
#    0.5141433744639299,
#    0.0447427293064877,
#    0.9841340616059153,
#    0.04081632653061224,
#    0.9928003599820009,
#    0.04950495049504951],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.2,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 5,
#   'r': 50,
#   'test_score': [0.00712037870417446,
#    0.5082026000740778,
#    0.0274442538593482,
#    0.9789321145914613,
#    0.0326530612244898,
#    0.9876256187190641,
#    0.023668639053254437],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.2,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 5,
#   'r': 200,
#   'test_score': [0.031356031258981724,
#    0.5140953156423812,
#    0.04608294930875576,
#    0.9846170995429718,
#    0.04081632653061224,
#    0.9932878356082195,
#    0.05291005291005291],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.2,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 7,
#   'r': 50,
#   'test_score': [0.007450566987934358,
#    0.5081848458597478,
#    0.027739251040221916,
#    0.9739531081633411,
#    0.04081632653061224,
#    0.9825258737063147,
#    0.02100840336134454],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.2,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 7,
#   'r': 200,
#   'test_score': [0.03320259826753423,
#    0.5134610616407955,
#    0.04739336492890995,
#    0.9850629807156392,
#    0.04081632653061224,
#    0.9937378131093445,
#    0.05649717514124294],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.2,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 9,
#   'r': 50,
#   'test_score': [0.007275947761987247,
#    0.5081537759846703,
#    0.025613660618996798,
#    0.9660758741128822,
#    0.04897959183673469,
#    0.9745012749362532,
#    0.017341040462427744],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.2,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 9,
#   'r': 200,
#   'test_score': [0.01885757782116428,
#    0.5142909181071559,
#    0.046511627906976744,
#    0.9847657266005276,
#    0.04081632653061224,
#    0.9934378281085946,
#    0.05405405405405406],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.30000000000000004,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 1,
#   'r': 50,
#   'test_score': [0.00716252672125174,
#    0.5081646427882688,
#    0.02699055330634278,
#    0.973209972875562,
#    0.04081632653061224,
#    0.9817759112044397,
#    0.020161290322580645],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.30000000000000004,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 1,
#   'r': 200,
#   'test_score': [0.04374283500457338,
#    0.5150363655286624,
#    0.05333333333333334,
#    0.9868093486419203,
#    0.04081632653061224,
#    0.9955002249887506,
#    0.07692307692307693],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.30000000000000004,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 3,
#   'r': 50,
#   'test_score': [0.007213755964771839,
#    0.5081983145740671,
#    0.027906976744186046,
#    0.9689369449708319,
#    0.04897959183673469,
#    0.9773886305684716,
#    0.01951219512195122],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.30000000000000004,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 3,
#   'r': 200,
#   'test_score': [0.020122934216257198,
#    0.5142277069819978,
#    0.049723756906077346,
#    0.9872180730501988,
#    0.036734693877551024,
#    0.9959502024898755,
#    0.07692307692307693],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.30000000000000004,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 5,
#   'r': 50,
#   'test_score': [0.007231037842690473,
#    0.5081603572882581,
#    0.026634382566585957,
#    0.9701259614312786,
#    0.044897959183673466,
#    0.9786260686965652,
#    0.0189328743545611],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.30000000000000004,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 5,
#   'r': 200,
#   'test_score': [0.03204115680220164,
#    0.5128680555768131,
#    0.046511627906976744,
#    0.9847657266005276,
#    0.04081632653061224,
#    0.9934378281085946,
#    0.05405405405405406],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.30000000000000004,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 7,
#   'r': 50,
#   'test_score': [0.007515030853856054,
#    0.5081461233060796,
#    0.026119402985074626,
#    0.9806041689889644,
#    0.02857142857142857,
#    0.9893505324733763,
#    0.024054982817869417],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.30000000000000004,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 7,
#   'r': 200,
#   'test_score': [0.019293761542024772,
#    0.5156485032891213,
#    0.05263157894736842,
#    0.9866235648199755,
#    0.04081632653061224,
#    0.9953127343632818,
#    0.07407407407407407],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.30000000000000004,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 9,
#   'r': 50,
#   'test_score': [0.007141231346070852,
#    0.5081462763596514,
#    0.02631578947368421,
#    0.969754393787389,
#    0.044897959183673466,
#    0.9782510874456277,
#    0.018612521150592216],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.30000000000000004,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 9,
#   'r': 200,
#   'test_score': [0.017579802384658755,
#    0.5125701367992824,
#    0.04699738903394256,
#    0.9864377809980307,
#    0.036734693877551024,
#    0.9951627418629069,
#    0.06521739130434782],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.4,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 1,
#   'r': 50,
#   'test_score': [0.00728928206551175,
#    0.5081427561274998,
#    0.02607561929595828,
#    0.9722438970014491,
#    0.04081632653061224,
#    0.9808009599520024,
#    0.019157088122605363],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.4,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 1,
#   'r': 200,
#   'test_score': [0.046177758441862046,
#    0.5149638181356241,
#    0.05449591280653951,
#    0.9871066027570319,
#    0.04081632653061224,
#    0.9958002099895005,
#    0.08196721311475409],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.4,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 3,
#   'r': 50,
#   'test_score': [0.007419660841190554,
#    0.5083091253600585,
#    0.03210272873194221,
#    0.9775944710734589,
#    0.04081632653061224,
#    0.9862006899655017,
#    0.026455026455026454],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.4,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 3,
#   'r': 200,
#   'test_score': [0.02383185732095599,
#    0.5157124796821385,
#    0.05115089514066496,
#    0.9862148404116969,
#    0.04081632653061224,
#    0.9949002549872507,
#    0.0684931506849315],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.4,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 5,
#   'r': 50,
#   'test_score': [0.007236443463517698,
#    0.508216221841969,
#    0.02973977695167286,
#    0.9806041689889644,
#    0.0326530612244898,
#    0.9893130343482825,
#    0.027303754266211604],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.4,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 5,
#   'r': 200,
#   'test_score': [0.02358175562172722,
#    0.5137789539094476,
#    0.05194805194805195,
#    0.9864377809980307,
#    0.04081632653061224,
#    0.9951252437378131,
#    0.07142857142857142],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.4,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 7,
#   'r': 50,
#   'test_score': [0.007146568124339609,
#    0.5081830092168863,
#    0.028368794326241134,
#    0.9745476163935645,
#    0.04081632653061224,
#    0.9831258437078146,
#    0.021739130434782608],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.4,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 7,
#   'r': 200,
#   'test_score': [0.016603598893062253,
#    0.5132151810776808,
#    0.046511627906976744,
#    0.9847657266005276,
#    0.04081632653061224,
#    0.9934378281085946,
#    0.05405405405405406],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.4,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 9,
#   'r': 50,
#   'test_score': [0.00731730173762176,
#    0.5082224970384132,
#    0.028282828282828285,
#    0.9821275963289117,
#    0.02857142857142857,
#    0.9908879556022199,
#    0.028],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.4,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 9,
#   'r': 200,
#   'test_score': [0.02061303388499708,
#    0.5097691799083516,
#    0.045454545454545456,
#    0.9843941589566381,
#    0.04081632653061224,
#    0.9930628468576571,
#    0.05128205128205128],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.5,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 1,
#   'r': 50,
#   'test_score': [0.007212957901945022,
#    0.5082385676634534,
#    0.028208744710860368,
#    0.9743989893360087,
#    0.04081632653061224,
#    0.9829758512074396,
#    0.021551724137931036],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.5,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 1,
#   'r': 200,
#   'test_score': [0.026890568159935544,
#    0.5165450911127913,
#    0.05405405405405406,
#    0.986995132463865,
#    0.04081632653061224,
#    0.9956877156142193,
#    0.08],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.5,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 3,
#   'r': 50,
#   'test_score': [0.007431359582513039,
#    0.5083011665743242,
#    0.03273809523809524,
#    0.975848103147178,
#    0.044897959183673466,
#    0.984400779961002,
#    0.02576112412177986],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.5,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 3,
#   'r': 200,
#   'test_score': [0.020522898825087805,
#    0.5168661975064512,
#    0.05249343832020997,
#    0.9865864080555865,
#    0.04081632653061224,
#    0.9952752362381881,
#    0.07352941176470588],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.5,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 5,
#   'r': 50,
#   'test_score': [0.007296528110629854,
#    0.5081291343596085,
#    0.026221692491060787,
#    0.9696429234942221,
#    0.044897959183673466,
#    0.9781385930703465,
#    0.018518518518518517],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.5,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 5,
#   'r': 200,
#   'test_score': [0.027289355581449973,
#    0.5132172473009003,
#    0.04736842105263158,
#    0.9865492512911975,
#    0.036734693877551024,
#    0.9952752362381881,
#    0.06666666666666667],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.5,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 7,
#   'r': 50,
#   'test_score': [0.007244821944499231,
#    0.5082240275741313,
#    0.02831858407079646,
#    0.9796009363504626,
#    0.0326530612244898,
#    0.9883005849707515,
#    0.025],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.5,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 7,
#   'r': 200,
#   'test_score': [0.01747405165300882,
#    0.5118269851813531,
#    0.045548654244306416,
#    0.9828707316166908,
#    0.044897959183673466,
#    0.9914879256037198,
#    0.046218487394957986],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.5,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 9,
#   'r': 50,
#   'test_score': [0.00758924123595746,
#    0.5083225940743779,
#    0.03257328990228013,
#    0.9779288819529596,
#    0.04081632653061224,
#    0.9865381730913454,
#    0.02710027100271003],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.5,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 9,
#   'r': 200,
#   'test_score': [0.016872488310947224,
#    0.5090988817906044,
#    0.04405286343612335,
#    0.9838739642551927,
#    0.04081632653061224,
#    0.9925378731063447,
#    0.04784688995215311],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.6000000000000001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 1,
#   'r': 50,
#   'test_score': [0.007285831342845994,
#    0.5083010135207524,
#    0.030612244897959183,
#    0.9717608590643927,
#    0.04897959183673469,
#    0.9802384880755962,
#    0.022263450834879406],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.6000000000000001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 1,
#   'r': 200,
#   'test_score': [0.025144380839690426,
#    0.5164430043803933,
#    0.056657223796033995,
#    0.9876267974584774,
#    0.04081632653061224,
#    0.9963251837408129,
#    0.09259259259259259],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.6000000000000001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 3,
#   'r': 50,
#   'test_score': [0.007673134100002776,
#    0.5083565719673201,
#    0.03454231433506045,
#    0.9792293687065731,
#    0.04081632653061224,
#    0.9878506074696265,
#    0.029940119760479042],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.6000000000000001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 3,
#   'r': 200,
#   'test_score': [0.03050700822287585,
#    0.5164592280590053,
#    0.05167958656330749,
#    0.9863634674692527,
#    0.04081632653061224,
#    0.9950502474876256,
#    0.07042253521126761],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.6000000000000001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 5,
#   'r': 50,
#   'test_score': [0.007301965200969018,
#    0.5082739995653279,
#    0.03125,
#    0.9746590866867313,
#    0.044897959183673466,
#    0.9832008399580021,
#    0.023965141612200435],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.6000000000000001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 5,
#   'r': 200,
#   'test_score': [0.017678601917986404,
#    0.5144372373218074,
#    0.05319148936170213,
#    0.9867721918775313,
#    0.04081632653061224,
#    0.9954627268636568,
#    0.07633587786259542],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.6000000000000001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 7,
#   'r': 50,
#   'test_score': [0.007385899013832166,
#    0.508317543306508,
#    0.03305785123966942,
#    0.9782632928324602,
#    0.04081632653061224,
#    0.9868756562171891,
#    0.027777777777777776],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.6000000000000001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 7,
#   'r': 200,
#   'test_score': [0.017526244046778088,
#    0.5112809665639169,
#    0.05432098765432099,
#    0.9857689592390295,
#    0.044897959183673466,
#    0.9944127793610319,
#    0.06875],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.6000000000000001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 9,
#   'r': 50,
#   'test_score': [0.007480709902571362,
#    0.5082852490028559,
#    0.03048780487804878,
#    0.9763682978486233,
#    0.04081632653061224,
#    0.9849632518374082,
#    0.024330900243309004],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.6000000000000001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 9,
#   'r': 200,
#   'test_score': [0.01759606360527113,
#    0.5069855180710352,
#    0.0398406374501992,
#    0.9820904395645227,
#    0.04081632653061224,
#    0.9907379631018449,
#    0.038910505836575876],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.7000000000000001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 1,
#   'r': 50,
#   'test_score': [0.007365771587188107,
#    0.5083463173780086,
#    0.032564450474898234,
#    0.9735072269906736,
#    0.04897959183673469,
#    0.9820008999550023,
#    0.024390243902439025],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.7000000000000001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 1,
#   'r': 200,
#   'test_score': [0.02499978358572887,
#    0.5148792560371983,
#    0.056022408963585436,
#    0.9874781704009215,
#    0.04081632653061224,
#    0.996175191240438,
#    0.08928571428571429],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.7000000000000001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 3,
#   'r': 50,
#   'test_score': [0.007170591884155865,
#    0.508255250502781,
#    0.03007518796992481,
#    0.9808271095752982,
#    0.0326530612244898,
#    0.9895380230988451,
#    0.027874564459930314],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.7000000000000001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 3,
#   'r': 200,
#   'test_score': [0.027514433069333412,
#    0.5156748285034728,
#    0.05361930294906166,
#    0.9868836621706982,
#    0.04081632653061224,
#    0.995575221238938,
#    0.078125],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.7000000000000001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 5,
#   'r': 50,
#   'test_score': [0.007382844377376946,
#    0.5082263233777086,
#    0.028205128205128206,
#    0.9718351725931705,
#    0.044897959183673466,
#    0.9803509824508775,
#    0.020560747663551402],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.7000000000000001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 5,
#   'r': 200,
#   'test_score': [0.02742596073603993,
#    0.5127819629426692,
#    0.05115089514066496,
#    0.9862148404116969,
#    0.04081632653061224,
#    0.9949002549872507,
#    0.0684931506849315],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.7000000000000001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 7,
#   'r': 50,
#   'test_score': [0.007570750544308932,
#    0.5083838155031024,
#    0.03717472118959108,
#    0.9807527960465202,
#    0.04081632653061224,
#    0.98938803059847,
#    0.034129692832764506],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.7000000000000001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 7,
#   'r': 200,
#   'test_score': [0.016960897219171937,
#    0.5110653906080206,
#    0.048458149779735685,
#    0.9839482777839705,
#    0.044897959183673466,
#    0.9925753712314385,
#    0.05263157894736842],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.7000000000000001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 9,
#   'r': 50,
#   'test_score': [0.007294745655373599,
#    0.5081822439490271,
#    0.02666666666666667,
#    0.981012893397243,
#    0.02857142857142857,
#    0.9897630118494075,
#    0.025],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.7000000000000001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 9,
#   'r': 200,
#   'test_score': [0.018034627381084384,
#    0.5068410354992454,
#    0.03508771929824561,
#    0.9816074016274663,
#    0.036734693877551024,
#    0.99028798560072,
#    0.033582089552238806],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.8,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 1,
#   'r': 50,
#   'test_score': [0.008643421275573581,
#    0.5084113651460281,
#    0.03735144312393888,
#    0.9789321145914613,
#    0.044897959183673466,
#    0.9875131243437828,
#    0.03197674418604651],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.8,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 1,
#   'r': 200,
#   'test_score': [0.023915445751337024,
#    0.5164546364518509,
#    0.055865921787709494,
#    0.9874410136365326,
#    0.04081632653061224,
#    0.9961376931153443,
#    0.08849557522123894],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.8,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 3,
#   'r': 50,
#   'test_score': [0.008021244107735921,
#    0.5083377463779873,
#    0.031746031746031744,
#    0.9773343737227362,
#    0.04081632653061224,
#    0.9859382030898455,
#    0.025974025974025976],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.8,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 3,
#   'r': 200,
#   'test_score': [0.025435422795569276,
#    0.5159843793524609,
#    0.05319148936170213,
#    0.9867721918775313,
#    0.04081632653061224,
#    0.9954627268636568,
#    0.07633587786259542],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.8,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 5,
#   'r': 50,
#   'test_score': [0.008070796902944655,
#    0.5082474447706185,
#    0.028985507246376812,
#    0.9775944710734589,
#    0.036734693877551024,
#    0.9862381880905955,
#    0.023936170212765957],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.8,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 5,
#   'r': 200,
#   'test_score': [0.01605222254864006,
#    0.514548660322086,
#    0.04484304932735426,
#    0.9841712183703043,
#    0.04081632653061224,
#    0.9928378581070947,
#    0.04975124378109453],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.8,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 7,
#   'r': 50,
#   'test_score': [0.008183970815868129,
#    0.5083175433065081,
#    0.03076923076923077,
#    0.9765912384349571,
#    0.04081632653061224,
#    0.9851882405879706,
#    0.024691358024691357],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.8,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 7,
#   'r': 200,
#   'test_score': [0.013958203461346018,
#    0.5104621299547267,
#    0.04219409282700422,
#    0.9831308289674136,
#    0.04081632653061224,
#    0.9917879106044698,
#    0.043668122270742356],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.8,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 9,
#   'r': 50,
#   'test_score': [0.007542236283536781,
#    0.5081876008240405,
#    0.026871401151631478,
#    0.9811615204547988,
#    0.02857142857142857,
#    0.9899130043497825,
#    0.025362318840579712],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.8,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 9,
#   'r': 200,
#   'test_score': [0.009066992351448273,
#    0.5084737344765413,
#    0.0380952380952381,
#    0.9812358339835767,
#    0.04081632653061224,
#    0.9898755062246888,
#    0.03571428571428571],
#   'test_d1': 658,
#   'test_d2': 409}]

# %%
filename_output
# Out:
# '/Users/sijianfan/Documents/projects/BiSSGL/outputs/results/realAnalysis/cdataset/separate/results_nrlmf.gz'

# %%
with gzip.open(filename_output, "wb+", 4) as fout:
    pickle.dump(results, fout)

# %% [markdown]
# ---

# %% [markdown]
# ## With identity matrix

# %%
# Just use no information
simD = np.eye(U.shape[0])
simT = np.eye(V.shape[0])

# %%
simD.shape, simT.shape
# Out:
# ((658, 658), (409, 409))

# %% [markdown]
# ### Implementation

# %%
dvlp_size, test_size = 0.9, 0.1

ind_dvlp, ind_test = next(
    mc_split(
        Y,
        n_splits=1,
        random_state=random_state,
        train_size=dvlp_size,
        test_size=test_size,
    )
)

Y_test = get_submatrix(Y, ind_test)

# %%
from sklearn.model_selection import ParameterGrid

grid_dataset = ParameterGrid(
    {
        "train_size": np.arange(0.1, 0.9, 0.1),
        # "train_size": [0.2],
        "n_splits": [5],
    }
)

grid_model = ParameterGrid(
    {
        "c": [1, 3, 5, 7, 9],  # confidence level
        # "c": [5],  # confidence level
        "K1": [5],
        "K2": [5],
        "r": [50, 200],  # rank
        "lambda_d": [0.125],
        "lambda_t": [0.125],
        "alpha": [0.25],
        "beta": [0.125],
        "theta": [0.5],
        "max_iter": [100],
    }
)

# %%
from tqdm import tqdm
from sklearn.model_selection import ShuffleSplit, KFold
from sklearn.model_selection import train_test_split
from scipy.special import expit


results = []
for par_dtst in tqdm(grid_dataset):
    # prepare the train dataset: take the specified share from the beginnig of the index array
    ind_train_all, _ = train_test_split(
        ind_dvlp,
        shuffle=False,
        random_state=random_state,
        test_size=(1 - (par_dtst["train_size"] / dvlp_size)),
    )

    # Run the experiment: the model
    for par_mdl in grid_model:  # tqdm.tqdm(, desc="cv %02d" % (cv,))
        Y_train = get_submatrix(Y, ind_train_all)
        Y_train[Y_train == 0] = 0.5
        Y_train[Y_train == -1] = 0.0

        # set up the model
        model = NRLMF(
            cfix=par_mdl["c"],
            K1=par_mdl["K1"],
            K2=par_mdl["K2"],
            num_factors=par_mdl["r"],
            lambda_d=par_mdl["lambda_d"],
            lambda_t=par_mdl["lambda_t"],
            alpha=par_mdl["alpha"],
            beta=par_mdl["beta"],
            theta=par_mdl["theta"],
            max_iter=par_mdl["max_iter"],
        )

        # fit on the whole development dataset
        model.fix_model(
            np.ones((Y_train.shape[0], Y_train.shape[1])), Y_train.toarray(), simD, simT
        )
        est_A, est_B = model.U, model.V

        # get the score
        prob_full = expit(simD @ est_A @ est_B.T @ simT.T)
        prob_test = get_submatrix(prob_full, ind_test)
        scores_test = get_metrics((Y_test.data + 1) / 2, prob_test.data)
        d1_test = sum(abs(est_A).max(axis=1) > 0)
        d2_test = sum(abs(est_B).max(axis=1) > 0)

        # record the results
        results.append(
            {
                "train_size": par_dtst["train_size"],
                "lambda_d": par_mdl["lambda_d"],
                "lambda_t": par_mdl["lambda_t"],
                "c": par_mdl["c"],
                "r": par_mdl["r"],
                "test_score": scores_test,
                "test_d1": d1_test,
                "test_d2": d2_test,
            }
        )
# Out:
# 100%|██████████| 8/8 [01:34<00:00, 11.79s/it]

# %%
results
# Out:
# [{'train_size': 0.1,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 1,
#   'r': 50,
#   'test_score': [0.03778609968222549,
#    0.6561540202202141,
#    0.0749185667752443,
#    0.9788949578270724,
#    0.08712121212121213,
#    0.9877293707080941,
#    0.06571428571428571],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.1,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 1,
#   'r': 200,
#   'test_score': [0.024145553986608045,
#    0.630280486958974,
#    0.0774365821094793,
#    0.9743246758072307,
#    0.10984848484848485,
#    0.9828886637397276,
#    0.05979381443298969],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.1,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 3,
#   'r': 50,
#   'test_score': [0.03403473955174802,
#    0.6698703516079403,
#    0.06451612903225806,
#    0.9515104224724111,
#    0.17045454545454544,
#    0.9592480018011933,
#    0.03978779840848806],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.1,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 3,
#   'r': 200,
#   'test_score': [0.038874732621616434,
#    0.5969034741197863,
#    0.08678500986193294,
#    0.982796418087913,
#    0.08333333333333333,
#    0.991707005891403,
#    0.09053497942386832],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.1,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 5,
#   'r': 50,
#   'test_score': [0.029642080015567736,
#    0.669235556055887,
#    0.06429780033840947,
#    0.9178092371716271,
#    0.2878787878787879,
#    0.9240496829149312,
#    0.03619047619047619],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.1,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 5,
#   'r': 200,
#   'test_score': [0.04223690418500421,
#    0.6343505839664232,
#    0.1198501872659176,
#    0.9825363207371902,
#    0.12121212121212122,
#    0.9910690832676649,
#    0.11851851851851852],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.1,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 7,
#   'r': 50,
#   'test_score': [0.03934373818233997,
#    0.6627109920549638,
#    0.07100591715976332,
#    0.9824991639728012,
#    0.06818181818181818,
#    0.9915569064505235,
#    0.07407407407407407],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.1,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 7,
#   'r': 200,
#   'test_score': [0.03647388205243885,
#    0.6104291252045388,
#    0.09397590361445783,
#    0.9720581131795043,
#    0.14772727272727273,
#    0.9802243986641149,
#    0.06890459363957598],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.1,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 9,
#   'r': 50,
#   'test_score': [0.027696154165150255,
#    0.6616723778366804,
#    0.060941828254847646,
#    0.9748077137442871,
#    0.08333333333333333,
#    0.9836391609441255,
#    0.048034934497816595],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.1,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 9,
#   'r': 200,
#   'test_score': [0.042490820024078654,
#    0.6177137097645372,
#    0.1260647359454855,
#    0.980938579868465,
#    0.14015151515151514,
#    0.9892678899771098,
#    0.11455108359133127],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.2,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 1,
#   'r': 50,
#   'test_score': [0.07036828931090656,
#    0.6802882619962998,
#    0.13615023474178403,
#    0.9863263107048639,
#    0.10984848484848485,
#    0.9950091935907539,
#    0.17901234567901234],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.2,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 1,
#   'r': 200,
#   'test_score': [0.052836456220653916,
#    0.6777885946030154,
#    0.1,
#    0.9839482777839705,
#    0.09090909090909091,
#    0.99279522683778,
#    0.1111111111111111],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.2,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 3,
#   'r': 50,
#   'test_score': [0.05416978132073492,
#    0.6935126481521281,
#    0.09859154929577464,
#    0.9857318024746405,
#    0.07954545454545454,
#    0.9947089947089947,
#    0.12962962962962962],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.2,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 3,
#   'r': 200,
#   'test_score': [0.07145079423340103,
#    0.6720416764743006,
#    0.1134020618556701,
#    0.9744361461003975,
#    0.16666666666666666,
#    0.9824383654170888,
#    0.0859375],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.2,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 5,
#   'r': 50,
#   'test_score': [0.062098127255737906,
#    0.6858267323692855,
#    0.11544461778471139,
#    0.9789321145914613,
#    0.14015151515151514,
#    0.9872415475252355,
#    0.09814323607427056],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.2,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 5,
#   'r': 200,
#   'test_score': [0.049606486354258544,
#    0.6898357804090665,
#    0.0997229916897507,
#    0.975848103147178,
#    0.13636363636363635,
#    0.984164508987204,
#    0.07860262008733625],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.2,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 7,
#   'r': 50,
#   'test_score': [0.06478715497866541,
#    0.6748636454605722,
#    0.1237410071942446,
#    0.9773715304871252,
#    0.16287878787878787,
#    0.9854403542346805,
#    0.09976798143851508],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.2,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 7,
#   'r': 200,
#   'test_score': [0.06586743745698784,
#    0.6886594328970216,
#    0.12265758091993186,
#    0.9808642663396872,
#    0.13636363636363635,
#    0.9892303651168899,
#    0.11145510835913312],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.2,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 9,
#   'r': 50,
#   'test_score': [0.0647201705703874,
#    0.6771209647982697,
#    0.1237785016286645,
#    0.9800096607587411,
#    0.14393939393939395,
#    0.9882922436113926,
#    0.10857142857142857],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.2,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 9,
#   'r': 200,
#   'test_score': [0.06047731672402553,
#    0.697518569120224,
#    0.11232449297971919,
#    0.9788578010626835,
#    0.13636363636363635,
#    0.9872040226650156,
#    0.09549071618037135],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.30000000000000004,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 1,
#   'r': 50,
#   'test_score': [0.09531662402698216,
#    0.7455067533377226,
#    0.17263843648208468,
#    0.9811243636904098,
#    0.20075757575757575,
#    0.9888551165146909,
#    0.15142857142857144],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.30000000000000004,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 1,
#   'r': 200,
#   'test_score': [0.09718646121695154,
#    0.7496063443167462,
#    0.14964028776978416,
#    0.9780403522461264,
#    0.19696969696969696,
#    0.9857780779766595,
#    0.12064965197215777],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.30000000000000004,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 3,
#   'r': 50,
#   'test_score': [0.11416894702354805,
#    0.789730725014413,
#    0.17089452603471295,
#    0.9769256493144577,
#    0.24242424242424243,
#    0.9842020338474239,
#    0.13195876288659794],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.30000000000000004,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 3,
#   'r': 200,
#   'test_score': [0.10511268335468167,
#    0.7308762509708135,
#    0.18101545253863136,
#    0.9862148404116969,
#    0.1553030303030303,
#    0.9944463206874554,
#    0.21693121693121692],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.30000000000000004,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 5,
#   'r': 50,
#   'test_score': [0.09536310516002597,
#    0.7347221227244869,
#    0.15730337078651685,
#    0.9832794560249694,
#    0.1590909090909091,
#    0.9914443318698638,
#    0.15555555555555556],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.30000000000000004,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 5,
#   'r': 200,
#   'test_score': [0.07905125721492315,
#    0.7535284739776466,
#    0.1410071942446043,
#    0.9778174116597926,
#    0.1856060606060606,
#    0.9856655033959999,
#    0.1136890951276102],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.30000000000000004,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 7,
#   'r': 50,
#   'test_score': [0.07958782448774537,
#    0.7106012420728733,
#    0.16568047337278108,
#    0.9842826886634712,
#    0.1590909090909091,
#    0.9924575030958009,
#    0.1728395061728395],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.30000000000000004,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 7,
#   'r': 200,
#   'test_score': [0.07514700838645164,
#    0.7371650053387642,
#    0.11098527746319366,
#    0.9708319399546688,
#    0.1856060606060606,
#    0.9786108296746595,
#    0.0791599353796446],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.30000000000000004,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 9,
#   'r': 50,
#   'test_score': [0.07841042637084647,
#    0.7413562053041958,
#    0.14419225634178906,
#    0.9761825140266785,
#    0.20454545454545456,
#    0.9838267852452249,
#    0.11134020618556702],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.30000000000000004,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 9,
#   'r': 200,
#   'test_score': [0.07303571166060194,
#    0.7484958074497081,
#    0.12702366127023662,
#    0.9739531081633411,
#    0.19318181818181818,
#    0.9816878682126909,
#    0.09461966604823747],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.4,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 1,
#   'r': 50,
#   'test_score': [0.18888283954956847,
#    0.7814733368811383,
#    0.2693156732891832,
#    0.9877011109872552,
#    0.23106060606060605,
#    0.9951968178918533,
#    0.32275132275132273],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.4,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 1,
#   'r': 200,
#   'test_score': [0.15215351455062381,
#    0.7841454196359634,
#    0.22459893048128343,
#    0.9838368074908037,
#    0.23863636363636365,
#    0.9912191827085444,
#    0.21212121212121213],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.4,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 3,
#   'r': 50,
#   'test_score': [0.1919115551333703,
#    0.7833673473448888,
#    0.2638146167557932,
#    0.9846542563073608,
#    0.2803030303030303,
#    0.9916319561709632,
#    0.24915824915824916],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.4,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 3,
#   'r': 200,
#   'test_score': [0.2174188735745819,
#    0.792860070933357,
#    0.30985915492957744,
#    0.9890759112696467,
#    0.25,
#    0.99639761341889,
#    0.4074074074074074],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.4,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 5,
#   'r': 50,
#   'test_score': [0.1892794082048726,
#    0.7580431837228527,
#    0.26048565121412803,
#    0.9875524839296994,
#    0.22348484848484848,
#    0.9951217681714135,
#    0.31216931216931215],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.4,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 5,
#   'r': 200,
#   'test_score': [0.168213904926047,
#    0.797591756811615,
#    0.23399558498896247,
#    0.9871066027570319,
#    0.20075757575757575,
#    0.9948966190100942,
#    0.2804232804232804],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.4,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 7,
#   'r': 50,
#   'test_score': [0.1888985034390273,
#    0.756400333971256,
#    0.26490066225165565,
#    0.9876267974584774,
#    0.22727272727272727,
#    0.9951592930316334,
#    0.31746031746031744],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.4,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 7,
#   'r': 200,
#   'test_score': [0.15750151886862168,
#    0.785163139329806,
#    0.2119205298013245,
#    0.9867350351131423,
#    0.18181818181818182,
#    0.9947089947089947,
#    0.25396825396825395],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.4,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 9,
#   'r': 50,
#   'test_score': [0.18014502220424647,
#    0.7439911896176672,
#    0.2737306843267108,
#    0.9877754245160332,
#    0.23484848484848486,
#    0.9952343427520732,
#    0.328042328042328],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.4,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 9,
#   'r': 200,
#   'test_score': [0.17142146864244548,
#    0.7972951114204069,
#    0.23655913978494625,
#    0.9894474789135362,
#    0.16666666666666666,
#    0.9975984089459267,
#    0.4074074074074074],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.5,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 1,
#   'r': 50,
#   'test_score': [0.1995865328847461,
#    0.8271769820233177,
#    0.27938671209540034,
#    0.9842826886634712,
#    0.3106060606060606,
#    0.9909565086870051,
#    0.25386996904024767],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.5,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 1,
#   'r': 200,
#   'test_score': [0.19771201617913312,
#    0.8241460677926399,
#    0.2833333333333333,
#    0.9872180730501988,
#    0.25757575757575757,
#    0.9944463206874554,
#    0.3148148148148148],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.5,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 3,
#   'r': 50,
#   'test_score': [0.22773596229808962,
#    0.8133332935342391,
#    0.3037475345167653,
#    0.9868836621706982,
#    0.2916666666666667,
#    0.9937708732034973,
#    0.3168724279835391],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.5,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 3,
#   'r': 200,
#   'test_score': [0.2564020429610682,
#    0.8070171772890449,
#    0.3373083475298126,
#    0.9855460186526958,
#    0.375,
#    0.9915944313107433,
#    0.3065015479876161],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.5,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 5,
#   'r': 50,
#   'test_score': [0.23515951932152385,
#    0.7988531748874539,
#    0.3258426966292135,
#    0.9866235648199755,
#    0.32954545454545453,
#    0.9931329505797591,
#    0.32222222222222224],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.5,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 5,
#   'r': 200,
#   'test_score': [0.21631719310961384,
#    0.8406418684196462,
#    0.2887700534759358,
#    0.9851744510088062,
#    0.3068181818181818,
#    0.9918946301925026,
#    0.2727272727272727],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.5,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 7,
#   'r': 50,
#   'test_score': [0.23490628589209528,
#    0.8159694149646868,
#    0.32085561497326204,
#    0.9858432727678074,
#    0.3409090909090909,
#    0.9922323539344816,
#    0.30303030303030304],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.5,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 7,
#   'r': 200,
#   'test_score': [0.20859903199458749,
#    0.8252689708067958,
#    0.2709447415329768,
#    0.9848028833649166,
#    0.2878787878787879,
#    0.991707005891403,
#    0.2558922558922559],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.5,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 9,
#   'r': 50,
#   'test_score': [0.23837985542464538,
#    0.7889871926514953,
#    0.30985915492957744,
#    0.9890759112696467,
#    0.25,
#    0.99639761341889,
#    0.4074074074074074],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.5,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 9,
#   'r': 200,
#   'test_score': [0.22172747083586608,
#    0.8261318293824205,
#    0.29213483146067415,
#    0.9859547430609743,
#    0.29545454545454547,
#    0.99279522683778,
#    0.28888888888888886],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.6000000000000001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 1,
#   'r': 50,
#   'test_score': [0.3084416534161655,
#    0.8600471960401038,
#    0.37083333333333335,
#    0.988778657154535,
#    0.3371212121212121,
#    0.9952343427520732,
#    0.41203703703703703],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.6000000000000001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 1,
#   'r': 200,
#   'test_score': [0.2573694981076241,
#    0.8495895576273826,
#    0.3375,
#    0.9881841489243117,
#    0.3068181818181818,
#    0.9949341438703141,
#    0.375],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.6000000000000001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 3,
#   'r': 50,
#   'test_score': [0.35152475506292,
#    0.8405106024786877,
#    0.40601503759398494,
#    0.9911938468398171,
#    0.3068181818181818,
#    0.9979736575481256,
#    0.6],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.6000000000000001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 3,
#   'r': 200,
#   'test_score': [0.404613594221979,
#    0.8676811597910888,
#    0.4507042253521127,
#    0.9913053171329841,
#    0.36363636363636365,
#    0.9975233592254868,
#    0.5925925925925926],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.6000000000000001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 5,
#   'r': 50,
#   'test_score': [0.32256620590933227,
#    0.8340797795585029,
#    0.39166666666666666,
#    0.9891502247984245,
#    0.3560606060606061,
#    0.9954219670531728,
#    0.4351851851851852],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.6000000000000001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 5,
#   'r': 200,
#   'test_score': [0.34976490371554486,
#    0.8737518719788224,
#    0.4105960264900662,
#    0.9900791439081484,
#    0.3522727272727273,
#    0.99639761341889,
#    0.49206349206349204],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.6000000000000001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 7,
#   'r': 50,
#   'test_score': [0.3479126963426461,
#    0.8215861331996084,
#    0.41102756892230574,
#    0.9912681603685951,
#    0.3106060606060606,
#    0.9980111824083455,
#    0.6074074074074074],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.6000000000000001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 7,
#   'r': 200,
#   'test_score': [0.34021982190805883,
#    0.8700785577263118,
#    0.40100250626566414,
#    0.9911195333110393,
#    0.30303030303030304,
#    0.9979361326879057,
#    0.5925925925925926],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.6000000000000001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 9,
#   'r': 50,
#   'test_score': [0.35900575895108155,
#    0.8344930505095989,
#    0.41025641025641024,
#    0.9888901274477019,
#    0.3939393939393939,
#    0.9947840444294345,
#    0.4279835390946502],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.6000000000000001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 9,
#   'r': 200,
#   'test_score': [0.3387169878750028,
#    0.8755608829485898,
#    0.4131455399061033,
#    0.9907108089027608,
#    0.3333333333333333,
#    0.9972231603437277,
#    0.5432098765432098],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.7000000000000001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 1,
#   'r': 50,
#   'test_score': [0.3867434426368461,
#    0.8681018930723422,
#    0.44150110375275936,
#    0.9905993386095939,
#    0.3787878787878788,
#    0.9966602874404293,
#    0.5291005291005291],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.7000000000000001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 1,
#   'r': 200,
#   'test_score': [0.3943040299038871,
#    0.8655064946436105,
#    0.4647887323943662,
#    0.9915282577193179,
#    0.375,
#    0.9976359338061466,
#    0.6111111111111112],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.7000000000000001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 3,
#   'r': 50,
#   'test_score': [0.4262683671265207,
#    0.83687502629583,
#    0.48621553884711777,
#    0.9923828633002638,
#    0.36742424242424243,
#    0.998574055311644,
#    0.7185185185185186],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.7000000000000001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 3,
#   'r': 200,
#   'test_score': [0.46104460912602935,
#    0.8873858334555734,
#    0.5012531328320802,
#    0.9926058038865976,
#    0.3787878787878788,
#    0.9986866298923036,
#    0.7407407407407407],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.7000000000000001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 5,
#   'r': 50,
#   'test_score': [0.43284924665102836,
#    0.8598318545127056,
#    0.4788732394366197,
#    0.9917511983056515,
#    0.38636363636363635,
#    0.9977485083868063,
#    0.6296296296296297],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.7000000000000001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 5,
#   'r': 200,
#   'test_score': [0.4411023685591283,
#    0.9013143082292019,
#    0.47619047619047616,
#    0.992234236242708,
#    0.35984848484848486,
#    0.9984990055912042,
#    0.7037037037037037],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.7000000000000001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 7,
#   'r': 50,
#   'test_score': [0.4609889164275284,
#    0.8430787811697977,
#    0.4988962472406181,
#    0.9915654144837067,
#    0.42803030303030304,
#    0.9971481106232879,
#    0.5978835978835979],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.7000000000000001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 7,
#   'r': 200,
#   'test_score': [0.43795132715011154,
#    0.8920509269209032,
#    0.48621553884711777,
#    0.9923828633002638,
#    0.36742424242424243,
#    0.998574055311644,
#    0.7185185185185186],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.7000000000000001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 9,
#   'r': 50,
#   'test_score': [0.42915908994356394,
#    0.8370087796801744,
#    0.48120300751879697,
#    0.9923085497714859,
#    0.36363636363636365,
#    0.9985365304514241,
#    0.7111111111111111],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.7000000000000001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 9,
#   'r': 200,
#   'test_score': [0.44708422290274374,
#    0.8745591539622273,
#    0.5164319248826291,
#    0.9923457065358748,
#    0.4166666666666667,
#    0.9980487072685654,
#    0.6790123456790124],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.8,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 1,
#   'r': 50,
#   'test_score': [0.4622475044953839,
#    0.8844167499604852,
#    0.5083333333333333,
#    0.9912310036042061,
#    0.4621212121212121,
#    0.9964726631393298,
#    0.5648148148148148],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.8,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 1,
#   'r': 200,
#   'test_score': [0.4230707554049661,
#    0.8899448441410616,
#    0.4988962472406181,
#    0.9915654144837067,
#    0.42803030303030304,
#    0.9971481106232879,
#    0.5978835978835979],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.8,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 3,
#   'r': 50,
#   'test_score': [0.4793479868474447,
#    0.8749189804154343,
#    0.5083333333333333,
#    0.9912310036042061,
#    0.4621212121212121,
#    0.9964726631393298,
#    0.5648148148148148],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.8,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 3,
#   'r': 200,
#   'test_score': [0.5334680059068626,
#    0.8917704854466084,
#    0.565121412803532,
#    0.9926801174153754,
#    0.48484848484848486,
#    0.9977109835265864,
#    0.6772486772486772],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.8,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 5,
#   'r': 50,
#   'test_score': [0.48148709481319685,
#    0.8791520404995583,
#    0.5263157894736842,
#    0.9929773715304872,
#    0.3977272727272727,
#    0.9988742541934031,
#    0.7777777777777778],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.8,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 5,
#   'r': 200,
#   'test_score': [0.5254401392556151,
#    0.910954501675542,
#    0.5695364238410596,
#    0.9927544309441534,
#    0.48863636363636365,
#    0.9977485083868063,
#    0.6825396825396826],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.8,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 7,
#   'r': 50,
#   'test_score': [0.49557421466695617,
#    0.8713097000626551,
#    0.5208333333333334,
#    0.9914539441905399,
#    0.4734848484848485,
#    0.9965852377199895,
#    0.5787037037037037],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.8,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 7,
#   'r': 200,
#   'test_score': [0.5143746012234842,
#    0.9083262689941176,
#    0.5446009389671361,
#    0.9927915877085424,
#    0.4393939393939394,
#    0.9982738564298848,
#    0.7160493827160493],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.8,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 9,
#   'r': 50,
#   'test_score': [0.4778557268664156,
#    0.8629208327789888,
#    0.5165562913907285,
#    0.9918626685988184,
#    0.4431818181818182,
#    0.9972982100641675,
#    0.6190476190476191],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.8,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 9,
#   'r': 200,
#   'test_score': [0.49605734887318065,
#    0.8951647796210445,
#    0.5625,
#    0.992197079478319,
#    0.5113636363636364,
#    0.9969604863221885,
#    0.625],
#   'test_d1': 658,
#   'test_d2': 409}]

# %%
filename_output = "/Users/sijianfan/Documents/projects/BiSSGL/outputs/results/realAnalysis/cdataset/separate/results_nrlmf_identity.gz"

# %%
with gzip.open(filename_output, "wb+", 4) as fout:
    pickle.dump(results, fout)

# %% [markdown]
# ---

# %% [markdown]
# ## With selection

# %%
from sgimc import SparseGroupIMCClassifier

C_lasso, C_group, C_ridge, rank = (0.0, 1.0, 1.0, 13)

imc = SparseGroupIMCClassifier(
    rank,
    n_threads=8,
    random_state=42,
    C_lasso=C_lasso,
    C_group=C_group,
    C_ridge=C_ridge,
)

# fit on the whole development dataset
Y_train = get_submatrix(Y, ind_train_all)
imc.fit(U, V, Y_train)

# get the score
prob_full = imc.predict_proba(U, V)
prob_test = get_submatrix(prob_full, ind_test)
scores_test = mc_get_scores(Y_test, prob_test)
d1_test = sum(abs(imc.coef_W_).max(axis=1) > 0)
d2_test = sum(abs(imc.coef_H_).max(axis=1) > 0)

print(scores_test, d1_test, d2_test)
# Out:
# {'tn': 5309, 'fn': 408, 'fp': 335, 'tp': 2982, 'auc': 0.9661509912633355} 1457 22

# %% [markdown]
# ### Prepare similarity matrix

# %%
# Jaccard distance → convert to similarity
from sklearn.metrics import pairwise_distances

simD = 1 - pairwise_distances(
    U[:, np.where(abs(imc.coef_W_).max(axis=1) > 0)[0]].toarray(), metric="jaccard"
)
simT = 1 - pairwise_distances(
    V[:, np.where(abs(imc.coef_H_).max(axis=1) > 0)[0]].toarray(), metric="jaccard"
)
# Out:
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/sklearn/metrics/pairwise.py:2182: DataConversionWarning: Data was converted to boolean for metric jaccard
#   warnings.warn(msg, DataConversionWarning)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/sklearn/metrics/pairwise.py:2182: DataConversionWarning: Data was converted to boolean for metric jaccard
#   warnings.warn(msg, DataConversionWarning)

# %% [markdown]
# ### Implementation

# %%
dvlp_size, test_size = 0.9, 0.1

ind_dvlp, ind_test = next(
    mc_split(
        Y,
        n_splits=1,
        random_state=random_state,
        train_size=dvlp_size,
        test_size=test_size,
    )
)

Y_test = get_submatrix(Y, ind_test)

# %%
from sklearn.model_selection import ParameterGrid

grid_dataset = ParameterGrid(
    {
        "train_size": np.arange(0.001, 0.2, 0.02),
        # "train_size": [0.2],
        "n_splits": [2],
    }
)

grid_model = ParameterGrid(
    {
        "c": [1, 3, 5, 7, 9],  # confidence level
        # "c": [1],  # confidence level
        "K1": [5],
        "K2": [5],
        "r": [50],  # rank
        "lambda_d": [0.125],
        "lambda_t": [0.125],
        "alpha": [0.25],
        "beta": [0.125],
        "theta": [0.5],
        "max_iter": [100],
    }
)

# %%
from tqdm import tqdm
from sklearn.model_selection import ShuffleSplit, KFold
from sklearn.model_selection import train_test_split
from scipy.special import expit


results = []
for par_dtst in tqdm(grid_dataset):
    # prepare the train dataset: take the specified share from the beginnig of the index array
    ind_train_all, _ = train_test_split(
        ind_dvlp,
        shuffle=False,
        random_state=random_state,
        test_size=(1 - (par_dtst["train_size"] / dvlp_size)),
    )

    # Run the experiment: the model
    for par_mdl in grid_model:  # tqdm.tqdm(, desc="cv %02d" % (cv,))
        Y_train = get_submatrix(Y, ind_train_all)

        Y_train[Y_train == 0] = 0.5
        Y_train[Y_train == -1] = 0.0

        # set up the model
        model = NRLMF(
            cfix=par_mdl["c"],
            K1=par_mdl["K1"],
            K2=par_mdl["K2"],
            num_factors=par_mdl["r"],
            lambda_d=par_mdl["lambda_d"],
            lambda_t=par_mdl["lambda_t"],
            alpha=par_mdl["alpha"],
            beta=par_mdl["beta"],
            theta=par_mdl["theta"],
            max_iter=par_mdl["max_iter"],
        )

        # fit on the whole development dataset
        model.fix_model(np.ones(Y_train.shape), Y_train.toarray(), simD, simT)
        est_A, est_B = model.U, model.V

        # get the score
        prob_full = expit(simD @ est_A @ est_B.T @ simT.T)
        prob_test = get_submatrix(prob_full, ind_test)
        scores_test = mc_get_scores(Y_test, prob_test)
        d1_test = sum(abs(est_A).max(axis=1) > 0)
        d2_test = sum(abs(est_B).max(axis=1) > 0)

        # record the results
        results.append(
            {
                "train_size": par_dtst["train_size"],
                "lambda_d": par_mdl["lambda_d"],
                "lambda_t": par_mdl["lambda_t"],
                "c": par_mdl["c"],
                "r": par_mdl["r"],
                "test_score": scores_test["auc"],
                "test_d1": d1_test,
                "test_d2": d2_test,
            }
        )
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]/Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
#  10%|█         | 1/10 [00:34<05:13, 34.86s/it]/Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
#  20%|██        | 2/10 [01:11<04:45, 35.68s/it]/Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
#  30%|███       | 3/10 [01:50<04:23, 37.59s/it]/Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
#  40%|████      | 4/10 [02:30<03:50, 38.36s/it]/Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
#  50%|█████     | 5/10 [03:09<03:12, 38.55s/it]/Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
#  60%|██████    | 6/10 [03:49<02:35, 38.99s/it]/Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
#  70%|███████   | 7/10 [04:28<01:56, 38.97s/it]/Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
#  80%|████████  | 8/10 [05:09<01:19, 39.61s/it]/Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
#  90%|█████████ | 9/10 [05:50<00:40, 40.22s/it]/Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# 100%|██████████| 10/10 [06:27<00:00, 38.78s/it]

# %%
results
# Out:
# [{'train_size': 0.001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 1,
#   'r': 50,
#   'test_score': 0.6974269223901604,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 3,
#   'r': 50,
#   'test_score': 0.5001759324419424,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 5,
#   'r': 50,
#   'test_score': 0.5001759324419424,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 7,
#   'r': 50,
#   'test_score': 0.5001759324419424,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 9,
#   'r': 50,
#   'test_score': 0.5001759324419424,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.021,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 1,
#   'r': 50,
#   'test_score': 0.7786309830159547,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.021,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 3,
#   'r': 50,
#   'test_score': 0.5001759324419424,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.021,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 5,
#   'r': 50,
#   'test_score': 0.5001759324419424,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.021,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 7,
#   'r': 50,
#   'test_score': 0.5001759324419424,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.021,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 9,
#   'r': 50,
#   'test_score': 0.5001759324419424,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.041,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 1,
#   'r': 50,
#   'test_score': 0.7799316751919502,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.041,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 3,
#   'r': 50,
#   'test_score': 0.5001759324419424,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.041,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 5,
#   'r': 50,
#   'test_score': 0.5001759324419424,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.041,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 7,
#   'r': 50,
#   'test_score': 0.5001759324419424,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.041,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 9,
#   'r': 50,
#   'test_score': 0.5001759324419424,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.061,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 1,
#   'r': 50,
#   'test_score': 0.7803930645855872,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.061,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 3,
#   'r': 50,
#   'test_score': 0.5001759324419424,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.061,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 5,
#   'r': 50,
#   'test_score': 0.5001759324419424,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.061,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 7,
#   'r': 50,
#   'test_score': 0.5001759324419424,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.061,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 9,
#   'r': 50,
#   'test_score': 0.5001759324419424,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.081,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 1,
#   'r': 50,
#   'test_score': 0.7572269108363878,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.081,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 3,
#   'r': 50,
#   'test_score': 0.5001759324419424,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.081,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 5,
#   'r': 50,
#   'test_score': 0.5001759324419424,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.081,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 7,
#   'r': 50,
#   'test_score': 0.5001759324419424,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.081,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 9,
#   'r': 50,
#   'test_score': 0.5001759324419424,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.101,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 1,
#   'r': 50,
#   'test_score': 0.7385303864211666,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.101,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 3,
#   'r': 50,
#   'test_score': 0.5001759324419424,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.101,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 5,
#   'r': 50,
#   'test_score': 0.5001759324419424,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.101,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 7,
#   'r': 50,
#   'test_score': 0.5001759324419424,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.101,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 9,
#   'r': 50,
#   'test_score': 0.5001759324419424,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.121,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 1,
#   'r': 50,
#   'test_score': 0.6984576501727813,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.121,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 3,
#   'r': 50,
#   'test_score': 0.5001759324419424,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.121,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 5,
#   'r': 50,
#   'test_score': 0.5001759324419424,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.121,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 7,
#   'r': 50,
#   'test_score': 0.5001759324419424,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.121,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 9,
#   'r': 50,
#   'test_score': 0.5001759324419424,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.14100000000000001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 1,
#   'r': 50,
#   'test_score': 0.6782890701313979,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.14100000000000001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 3,
#   'r': 50,
#   'test_score': 0.5001759324419424,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.14100000000000001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 5,
#   'r': 50,
#   'test_score': 0.5001759324419424,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.14100000000000001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 7,
#   'r': 50,
#   'test_score': 0.5001759324419424,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.14100000000000001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 9,
#   'r': 50,
#   'test_score': 0.5001759324419424,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.161,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 1,
#   'r': 50,
#   'test_score': 0.6352313380318674,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.161,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 3,
#   'r': 50,
#   'test_score': 0.5001759324419424,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.161,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 5,
#   'r': 50,
#   'test_score': 0.5001759324419424,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.161,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 7,
#   'r': 50,
#   'test_score': 0.5001759324419424,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.161,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 9,
#   'r': 50,
#   'test_score': 0.5001759324419424,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.181,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 1,
#   'r': 50,
#   'test_score': 0.6020384005377756,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.181,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 3,
#   'r': 50,
#   'test_score': 0.5001759324419424,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.181,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 5,
#   'r': 50,
#   'test_score': 0.5001759324419424,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.181,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 7,
#   'r': 50,
#   'test_score': 0.5001759324419424,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.181,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 9,
#   'r': 50,
#   'test_score': 0.5001759324419424,
#   'test_d1': 6949,
#   'test_d2': 13}]

# %%
filename_output
# Out:
# '/Users/sijianfan/Documents/projects/BiSSGL/outputs/results/realAnalysis/tuberculosis/results_drimc.gz'

# %%
with gzip.open(filename_output, "wb+", 4) as fout:
    pickle.dump(results, fout)

# %% [markdown]
# ---

# %% [markdown]
# ## Quick check of the results

# %%
from collections import defaultdict


def get_test_results(results, param="train_size", hyp_param="C_group"):
    # grouping by validation
    id_result = {}
    param_ids = defaultdict(list)

    for _id, result in enumerate(results):
        comb = "{}|{}".format(result[param], result[hyp_param])
        param_ids[comb].append(_id)

        id_result[_id] = [
            result[param],
            result[hyp_param],
            # result["val_score"],
            result["test_score"],
        ]

    id_groups = list(param_ids.values())

    # averaging the cross-validation results
    results_avg = []

    for ids in id_groups:
        val_res = [id_result[_id] for _id in ids]
        avg_res = np.max(val_res, axis=0)
        results_avg.append(avg_res)

    results_avg = np.array(results_avg)

    # grouping by train_size
    id_result = {}
    param_ids = defaultdict(list)

    for _id, val_res in enumerate(results_avg):
        comb = "{}".format(val_res[0])
        param_ids[comb].append(_id)

        id_result[_id] = val_res[[0, 2]]

    id_groups = list(param_ids.values())

    results_final = []

    for ids in id_groups:
        param_res = results_avg[ids]
        val = [x[2] for x in param_res]
        chosen_result = param_res[np.argmax(val)]
        results_final.append(chosen_result[[0, 2]])

    results_final = np.array(results_final)

    return results_final.T


results_final = []

results_final.append(get_test_results(results, param="train_size", hyp_param="c"))
results_final = np.array(results_final)
results_nrlmf = np.mean(results_final, axis=0)

# %%
results_nrlmf
# Out:
# array([[0.001     , 0.021     , 0.041     , 0.061     , 0.081     ,
#         0.101     , 0.121     , 0.141     , 0.161     , 0.181     ],
#        [0.69742692, 0.77863098, 0.77993168, 0.78039306, 0.75722691,
#         0.73853039, 0.69845765, 0.67828907, 0.63523134, 0.6020384 ]])
