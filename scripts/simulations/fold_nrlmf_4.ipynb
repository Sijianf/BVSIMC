# %% [markdown]
# # NRLMF Simulation — Local Notebook Runner

# %% [markdown]
# Pairwise-CV protocol (same as the HPC masked scripts):
#
# outer doCrossValidationByPairwise on the OBSERVED matrix R_noisy,
#
# nested inner CV for HP selection,
#
# outer test scored against the clean truth R.
#
# Parallelised by opening several notebooks, each owning a slice of DATASET_IDS.

# %% [markdown]
# ## Cell 1 — Configure which datasets this notebook runs

# %%
# ============================================================
# USER SETTINGS — change these per notebook instance
# ============================================================

# A unique label for this notebook — used in the output filename
# e.g. 'nb0', 'nb1', 'nb2' ... open one notebook per label
NOTEBOOK_ID = "nb4"

# Which dataset_grid indices (i_ds) this notebook will process.
# dataset_grid has 100 entries (10 feature sizes x 10 repeats),
# indexed 0..99. Split them across notebooks however you like.
#
# Example splits across 4 notebooks:
#   nb0: list(range(0,  25))   # feature_id 0-1, all repeats
#   nb1: list(range(25, 50))   # feature_id 2-3, all repeats
#   nb2: list(range(50, 75))   # feature_id 4-6, all repeats
#   nb3: list(range(75, 100))  # feature_id 7-9, all repeats
#
# Or by repeat_id if you prefer:
#   nb0: [i for i in range(100) if (i % 10) < 5]   # repeat_id 0-4
#   nb1: [i for i in range(100) if (i % 10) >= 5]  # repeat_id 5-9

DATASET_IDS = list(range(80, 100))  # <-- change this per notebook

BASE_SEED = 123456  # must match HPC runs for reproducible splits

# ============================================================

# %% [markdown]
# ## Cell 2 — Paths

# %%
import os
import sys
import gzip
import pickle
import warnings

import numpy as np
from tqdm import TqdmSynchronisationWarning, tqdm

warnings.simplefilter("ignore", TqdmSynchronisationWarning)

# ====== user paths — adjust to your local machine ======
PATH_ROOT = "/Users/sijianfan/projects/BiSSGL"  # <-- local root
PATH_DATA = os.path.join(PATH_ROOT, "datasets/simulations/masked_ones")
PATH_OUTPUT = os.path.join(PATH_ROOT, "outputs/results/simulations/masked_ones")
PATH_ARCHIVE = os.path.join(PATH_OUTPUT, "archived")
DRIMC_PATH = os.path.join(PATH_ROOT, "scripts/methods/DRIMC")

for p in (PATH_OUTPUT, PATH_ARCHIVE):
    os.makedirs(p, exist_ok=True)

sys.path.append(PATH_ROOT)

print(f"Output will be saved to: {PATH_OUTPUT}")
print(f"Notebook ID: {NOTEBOOK_ID}  |  Datasets to run: {len(DATASET_IDS)}")
# Out:
# Output will be saved to: /Users/sijianfan/projects/BiSSGL/outputs/results/simulations/masked_ones
# Notebook ID: nb4  |  Datasets to run: 20

# %% [markdown]
# ## Cell 3 — Imports

# %%
from sklearn.metrics import pairwise_distances
from sklearn.model_selection import ParameterGrid
from scipy.special import expit
 
from PyDTI3.nrlmf import NRLMF
 
print("Imports OK.")
# Out:
# Imports OK.

# %% [markdown]
# ## Cell 4 — R setup via rpy2

# %%
import rpy2.robjects as robjects

r = robjects.r
r(f'setwd("{DRIMC_PATH}")')

for pkg in ["matrixcalc", "data.table", "Rcpp", "ROCR", "Bolstad2", "MESS"]:
    r(f"library({pkg})")

for r_file in [
    "doCrossValidationByPairwise.R",
    "constrNeig.R",
    "calcLogLik.R",
    "calcDeriv.R",
    "updateUV.R",
]:
    r(f'source("{r_file}")')

r("library(Rcpp)")
for cpp_file in ["log1pexp.cpp", "sigmoid.cpp"]:
    r(f'sourceCpp("{cpp_file}")')

doCrossValidationByPairwise_R = r["doCrossValidationByPairwise"]
constrNeig_R = r["constrNeig"]
print("R setup complete.")
# Out:
# R callback write-console: data.table 1.17.8 using 6 threads (see ?getDTthreads).
# R callback write-console: Latest news: r-datatable.com
# R setup complete.

# %% [markdown]
# ## Cell 5 — Helper functions

# %%
def get_metrics(real_score, predict_score):
    sorted_predict_score = np.array(
        sorted(list(set(np.array(predict_score).flatten())))
    )
    sorted_predict_score_num = len(sorted_predict_score)
    thresholds = sorted_predict_score[
        np.int32(sorted_predict_score_num * np.arange(1, 1000) / 1000)
    ]
    thresholds = np.mat(thresholds)
    thresholds_num = thresholds.shape[1]
    predict_score_matrix = np.tile(predict_score, (thresholds_num, 1))
    negative_index = np.where(predict_score_matrix < thresholds.T)
    positive_index = np.where(predict_score_matrix >= thresholds.T)
    predict_score_matrix[negative_index] = 0
    predict_score_matrix[positive_index] = 1
    TP = predict_score_matrix.dot(real_score.T)
    FP = predict_score_matrix.sum(axis=1) - TP
    FN = real_score.sum() - TP
    TN = len(real_score.T) - TP - FP - FN
    fpr = FP / (FP + TN)
    tpr = TP / (TP + FN)
    ROC_dot_matrix = np.mat(sorted(np.column_stack((fpr, tpr)).tolist())).T
    ROC_dot_matrix.T[0] = [0, 0]
    ROC_dot_matrix = np.c_[ROC_dot_matrix, [1, 1]]
    x_ROC = ROC_dot_matrix[0].T
    y_ROC = ROC_dot_matrix[1].T
    auc = 0.5 * (x_ROC[1:] - x_ROC[:-1]).T * (y_ROC[:-1] + y_ROC[1:])
    recall_list = tpr
    precision_list = TP / (TP + FP)
    PR_dot_matrix = np.mat(
        sorted(np.column_stack((recall_list, precision_list)).tolist())
    ).T
    PR_dot_matrix.T[0] = [0, 1]
    PR_dot_matrix = np.c_[PR_dot_matrix, [1, 0]]
    x_PR = PR_dot_matrix[0].T
    y_PR = PR_dot_matrix[1].T
    aupr = 0.5 * (x_PR[1:] - x_PR[:-1]).T * (y_PR[:-1] + y_PR[1:])
    f1_score_list = 2 * TP / (len(real_score.T) + TP - TN)
    accuracy_list = (TP + TN) / len(real_score.T)
    specificity_list = TN / (TN + FP)
    max_index = np.argmax(f1_score_list)
    f1_score = f1_score_list[max_index]
    accuracy = accuracy_list[max_index]
    specificity = specificity_list[max_index]
    recall = recall_list[max_index]
    precision = precision_list[max_index]
    return [aupr[0, 0], auc[0, 0], f1_score, accuracy, recall, specificity, precision]


def to_r_matrix(arr):
    return r.matrix(
        robjects.FloatVector(arr.flatten()),
        byrow=True,
        nrow=arr.shape[0],
        ncol=arr.shape[1],
    )


def build_sim_matrices(U, V, K=20):
    simD = 1 - pairwise_distances(U, metric="cosine")
    simT = 1 - pairwise_distances(V, metric="cosine")
    simD = np.nan_to_num(simD, nan=0.0)
    simT = np.nan_to_num(simT, nan=0.0)
    np.fill_diagonal(simD, 1.0)
    np.fill_diagonal(simT, 1.0)
    lap = constrNeig_R(to_r_matrix(simD), to_r_matrix(simT), K=K)
    simD_R = lap.rx2("simD")
    simT_R = lap.rx2("simT")
    return np.array(simD_R), np.array(simT_R), simD_R, simT_R  # constrained np + R


def extract_fold(savedFolds, trial, fold):
    fold_data = savedFolds.rx2(trial + 1).rx2(fold + 1)
    Y_train = np.array(fold_data.rx2(7))
    test_label = np.array(fold_data.rx2(1)).flatten()
    test_row = np.array(fold_data.rx2(3)).flatten().astype(int) - 1
    test_col = np.array(fold_data.rx2(4)).flatten().astype(int) - 1
    known_drug_idx = np.array(fold_data.rx2(5)).flatten().astype(int)
    known_target_idx = np.array(fold_data.rx2(6)).flatten().astype(int)
    return Y_train, test_row, test_col, test_label, known_drug_idx, known_target_idx


def fit_nrlmf(Y_dense, simD, simT, par, seed):
    """Fit NRLMF on a fully-observed {0,1} fold matrix; return (U, V) factors.
 
    `W` is the ones-mask (every cell observed), matching the pairwise protocol
    where the fold matrix has held-out positives zeroed rather than masked out.
    """
    np.random.seed(seed)   # PyDTI3's NRLMF seeds off numpy's global RNG
    model = NRLMF(
        cfix=par["c"], K1=par["K1"], K2=par["K2"],
        num_factors=par["r"],
        lambda_d=par["lambda_d"], lambda_t=par["lambda_t"],
        alpha=par["alpha"], beta=par["beta"], theta=par["theta"],
        max_iter=par["max_iter"],
    )
    model.fix_model(np.ones(Y_dense.shape), np.asarray(Y_dense, dtype=float),
                    simD, simT)
    return model.U, model.V


print("Helpers defined.")
# Out:
# Helpers defined.

# %% [markdown]
# ## Cell 6 — Build grids

# %%
n_features_grid = np.arange(50, 501, 50)
n_repeats = 10
filename_template = "data_feature_{:03d}_rep_{:02d}.gz"

dataset_grid = []
for feature_id, n_features in enumerate(n_features_grid):
    for repeat_id in range(n_repeats):
        dataset_grid.append(
            {
                "feature_id": int(feature_id),
                "n_features": int(n_features),
                "repeat_id": int(repeat_id),
                "filename": os.path.join(
                    PATH_DATA, filename_template.format(n_features, repeat_id)
                ),
            }
        )

# CV config
KFOLD = 10
NUMSPLIT_OUTER = 1
N_INNER_KFOLD = 10
N_INNER_EVAL = 2
DO_INNER_CV = True
K2 = 20  # for similarity matrices (so far we used the suggested K=20 from the DRIMC paper, but you can change this)
grid_model = ParameterGrid(
    {
        "c":        [1, 5, 10],   # confidence level — main tuning parameter
        "K1":       [5],          # neighbourhood size for rows (fixed)
        "K2":       [5],          # neighbourhood size for cols (fixed)
        "r":        [25],         # rank (fixed, matches other methods)
        "lambda_d": [0.125],
        "lambda_t": [0.125],
        "alpha":    [0.25],
        "beta":     [0.125],
        "theta":    [0.5],
        "max_iter": [100],
    }
)
n_m = len(list(grid_model))
 
my_ids = list(DATASET_IDS)
print(f"Datasets assigned : {len(my_ids)}")
print(f"Folds per dataset : {KFOLD}")
print(f"Hyperparam combos : {n_m}")
print(f"Total fits (outer): {len(my_ids) * KFOLD * n_m}")
# Out:
# Datasets assigned : 20
# Folds per dataset : 10
# Hyperparam combos : 3
# Total fits (outer): 600

# %% [markdown]
# ## Cell 7 — Run
#
# Progress bars are shown per dataset.
# Results are **incrementally saved** after each dataset finishes — if the kernel dies mid-run you keep completed datasets.

# %%
outfile = os.path.join(PATH_OUTPUT, f"results_nrlmf_local_{NOTEBOOK_ID}.gz")
all_results = []
 
for i_ds in tqdm(my_ids, desc="Datasets"):
    ds = dataset_grid[i_ds]
 
    with gzip.open(ds["filename"], "rb") as fin:
        data = pickle.load(fin)
    U = np.asarray(data["X"], dtype=float)
    V = np.asarray(data["Y"], dtype=float)
    R_true = np.asarray(data["R"], dtype=float)        # clean truth {0,1}
    R_obs = np.asarray(data["R_noisy"], dtype=float)   # observed {0,1}
 
    # NRLMF can just use numpy arrays 
    simD, simT, _, _ = build_sim_matrices(U, V, K=K2)
 
    # outer pairwise folds on the OBSERVED matrix — once per dataset
    # (same seed formula as the DRIMC/HPC runners -> identical folds)
    outer_seed = (BASE_SEED + i_ds * 7919) % (2**31 - 1)
    savedFolds = doCrossValidationByPairwise_R(
        to_r_matrix(R_obs), kfold=KFOLD, numSplit=NUMSPLIT_OUTER,
        seeds=robjects.IntVector([outer_seed]),
    )
 
    _inner_folds_cache = {}
    dataset_results = []
 
    for fold in range(KFOLD):
        Y_train_dense, test_row, test_col, _obs_label, _, _ = extract_fold(
            savedFolds, 0, fold
        )
        test_label_true = R_true[test_row, test_col]
 
        for i_m, par_mdl in enumerate(grid_model):
            combo_idx = i_ds * KFOLD * n_m + fold * n_m + i_m
            model_seed = BASE_SEED + combo_idx
 
            try:
                # ---- outer fit -> test score (vs CLEAN truth R) ----
                est_U, est_V = fit_nrlmf(
                    Y_train_dense, simD, simT, par_mdl,
                    model_seed % (2**31 - 1),
                )
                SA = simD @ est_U
                STB = simT @ est_V
                prob_full = expit(SA @ STB.T)
                prob_test = prob_full[test_row, test_col]
                scores_test = get_metrics(
                    np.asarray(test_label_true, dtype=float),
                    np.asarray(prob_test, dtype=float),
                )
                # nonzero latent-row counts (NRLMF does NO feature selection)
                d1_test = int(sum(abs(est_U).max(axis=1) > 0))
                d2_test = int(sum(abs(est_V).max(axis=1) > 0))
 
                # ---- inner CV for HP selection (OBSERVED labels) ----
                inner_scores = []
                if DO_INNER_CV:
                    if fold not in _inner_folds_cache:
                        inner_seed = (BASE_SEED + i_ds * 7919 + fold + 31415) % (2**31 - 1)
                        _inner_folds_cache[fold] = doCrossValidationByPairwise_R(
                            to_r_matrix(Y_train_dense),
                            kfold=N_INNER_KFOLD, numSplit=1,
                            seeds=robjects.IntVector([inner_seed]),
                        )
                    inner_savedFolds = _inner_folds_cache[fold]
 
                    for cv in range(N_INNER_EVAL):
                        Y_inner, val_row, val_col, val_label, _, _ = extract_fold(
                            inner_savedFolds, 0, cv
                        )
                        est_U_cv, est_V_cv = fit_nrlmf(
                            Y_inner, simD, simT, par_mdl,
                            model_seed % (2**31 - 1),
                        )
                        SA_cv = simD @ est_U_cv
                        STB_cv = simT @ est_V_cv
                        prob_full_cv = expit(SA_cv @ STB_cv.T)
                        prob_valid = prob_full_cv[val_row, val_col]
                        scores_valid = get_metrics(
                            np.asarray(val_label, dtype=float),
                            np.asarray(prob_valid, dtype=float),
                        )
                        inner_scores.append((int(cv), scores_valid,
                                             int(sum(abs(est_U_cv).max(axis=1) > 0)),
                                             int(sum(abs(est_V_cv).max(axis=1) > 0))))
                else:
                    inner_scores.append((-1, [np.nan] * 7, -1, -1))
 
                for cv, scores_valid, d1_valid, d2_valid in inner_scores:
                    dataset_results.append(
                        {
                            "feature_id": ds["feature_id"],
                            "n_features": ds["n_features"],
                            "repeat_id": ds["repeat_id"],
                            "fold": int(fold),
                            "c": par_mdl["c"], 
                            "K1": par_mdl["K1"], "K2": par_mdl["K2"],
                            "r": par_mdl["r"],
                            "lambda_d": par_mdl["lambda_d"],
                            "lambda_t": par_mdl["lambda_t"],
                            "alpha": par_mdl["alpha"], "beta": par_mdl["beta"],
                            "theta": par_mdl["theta"], "max_iter": par_mdl["max_iter"],
                            "cv": int(cv),
                            "val_score": scores_valid,
                            "val_d1": d1_valid, "val_d2": d2_valid,
                            "test_score": scores_test,
                            "test_d1": d1_test, "test_d2": d2_test,
                        }
                    )
 
            except Exception as e:
                print(f"  ERROR i_ds={i_ds} fold={fold} c={par_mdl['c']}: {e}")
 
    # ---- incremental save after each dataset ----
    all_results.extend(dataset_results)
    with gzip.open(outfile, "wb+", 4) as fout:
        pickle.dump(all_results, fout)
    print(f"  i_ds={i_ds} done — {len(all_results)} rows so far -> {outfile}")

print(f"\nDone. Total rows: {len(all_results)}")
# Out:
# Datasets:   0%|          | 0/20 [00:00<?, ?it/s]
# Datasets:   5%|▌         | 1/20 [33:55<10:44:43, 2035.98s/it]
#   i_ds=80 done — 60 rows so far -> /Users/sijianfan/projects/BiSSGL/outputs/results/simulations/masked_ones/results_nrlmf_local_nb4.gz
# Datasets:  10%|█         | 2/20 [1:02:35<9:14:58, 1849.93s/it]
#   i_ds=81 done — 120 rows so far -> /Users/sijianfan/projects/BiSSGL/outputs/results/simulations/masked_ones/results_nrlmf_local_nb4.gz
# Datasets:  15%|█▌        | 3/20 [1:32:58<8:40:41, 1837.74s/it]
#   i_ds=82 done — 180 rows so far -> /Users/sijianfan/projects/BiSSGL/outputs/results/simulations/masked_ones/results_nrlmf_local_nb4.gz
# Datasets:  20%|██        | 4/20 [2:02:50<8:05:12, 1819.51s/it]
#   i_ds=83 done — 240 rows so far -> /Users/sijianfan/projects/BiSSGL/outputs/results/simulations/masked_ones/results_nrlmf_local_nb4.gz
# Datasets:  25%|██▌       | 5/20 [2:32:58<7:33:52, 1815.50s/it]
#   i_ds=84 done — 300 rows so far -> /Users/sijianfan/projects/BiSSGL/outputs/results/simulations/masked_ones/results_nrlmf_local_nb4.gz
# Datasets:  30%|███       | 6/20 [3:00:24<6:50:06, 1757.64s/it]
#   i_ds=85 done — 360 rows so far -> /Users/sijianfan/projects/BiSSGL/outputs/results/simulations/masked_ones/results_nrlmf_local_nb4.gz
# Datasets:  35%|███▌      | 7/20 [3:30:26<6:24:00, 1772.35s/it]
#   i_ds=86 done — 420 rows so far -> /Users/sijianfan/projects/BiSSGL/outputs/results/simulations/masked_ones/results_nrlmf_local_nb4.gz
# Datasets:  40%|████      | 8/20 [4:00:03<5:54:42, 1773.57s/it]
#   i_ds=87 done — 480 rows so far -> /Users/sijianfan/projects/BiSSGL/outputs/results/simulations/masked_ones/results_nrlmf_local_nb4.gz
# Datasets:  45%|████▌     | 9/20 [4:27:18<5:17:14, 1730.42s/it]
#   i_ds=88 done — 540 rows so far -> /Users/sijianfan/projects/BiSSGL/outputs/results/simulations/masked_ones/results_nrlmf_local_nb4.gz
# Datasets:  50%|█████     | 10/20 [4:57:39<4:53:03, 1758.32s/it]
#   i_ds=89 done — 600 rows so far -> /Users/sijianfan/projects/BiSSGL/outputs/results/simulations/masked_ones/results_nrlmf_local_nb4.gz
# Datasets:  55%|█████▌    | 11/20 [5:28:56<4:29:10, 1794.55s/it]
#   i_ds=90 done — 660 rows so far -> /Users/sijianfan/projects/BiSSGL/outputs/results/simulations/masked_ones/results_nrlmf_local_nb4.gz
# Datasets:  60%|██████    | 12/20 [5:59:45<4:01:30, 1811.34s/it]
#   i_ds=91 done — 720 rows so far -> /Users/sijianfan/projects/BiSSGL/outputs/results/simulations/masked_ones/results_nrlmf_local_nb4.gz
# Datasets:  65%|██████▌   | 13/20 [6:28:26<3:28:08, 1784.02s/it]
#   i_ds=92 done — 780 rows so far -> /Users/sijianfan/projects/BiSSGL/outputs/results/simulations/masked_ones/results_nrlmf_local_nb4.gz
# Datasets:  70%|███████   | 14/20 [6:57:21<2:56:55, 1769.20s/it]
#   i_ds=93 done — 840 rows so far -> /Users/sijianfan/projects/BiSSGL/outputs/results/simulations/masked_ones/results_nrlmf_local_nb4.gz
# Datasets:  75%|███████▌  | 15/20 [7:27:20<2:28:10, 1778.15s/it]
#   i_ds=94 done — 900 rows so far -> /Users/sijianfan/projects/BiSSGL/outputs/results/simulations/masked_ones/results_nrlmf_local_nb4.gz
# Datasets:  80%|████████  | 16/20 [7:57:14<1:58:50, 1782.73s/it]
#   i_ds=95 done — 960 rows so far -> /Users/sijianfan/projects/BiSSGL/outputs/results/simulations/masked_ones/results_nrlmf_local_nb4.gz
# Datasets:  85%|████████▌ | 17/20 [8:27:03<1:29:13, 1784.66s/it]
#   i_ds=96 done — 1020 rows so far -> /Users/sijianfan/projects/BiSSGL/outputs/results/simulations/masked_ones/results_nrlmf_local_nb4.gz
# Datasets:  90%|█████████ | 18/20 [8:57:03<59:38, 1789.44s/it]
#   i_ds=97 done — 1080 rows so far -> /Users/sijianfan/projects/BiSSGL/outputs/results/simulations/masked_ones/results_nrlmf_local_nb4.gz
# Datasets:  95%|█████████▌| 19/20 [10:59:46<57:43, 3463.45s/it]
#   i_ds=98 done — 1140 rows so far -> /Users/sijianfan/projects/BiSSGL/outputs/results/simulations/masked_ones/results_nrlmf_local_nb4.gz
# Datasets: 100%|██████████| 20/20 [11:36:05<00:00, 2088.29s/it]
#   i_ds=99 done — 1200 rows so far -> /Users/sijianfan/projects/BiSSGL/outputs/results/simulations/masked_ones/results_nrlmf_local_nb4.gz
#
# Done. Total rows: 1200
