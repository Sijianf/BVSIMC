# %% [markdown]
# # Run NRLMF

# %%
import os
import time
import gzip
import pickle
import warnings

# %matplotlib inline
import matplotlib.pyplot as plt

import numpy as np

from tqdm import TqdmSynchronisationWarning
warnings.simplefilter("ignore", TqdmSynchronisationWarning)

# %%
PATH_ROOT = "/Users/sijianfan/Documents/projects/BiSSGL"
PATH_DATA = os.path.join(PATH_ROOT, "datasets/realAnalysis/cdataset/cv_data")

PATH_OUTPUT = os.path.join(PATH_ROOT, "outputs/results/realAnalysis/cdataset/noisy")
if not os.path.isdir(PATH_OUTPUT):
    os.makedirs(PATH_OUTPUT)

PATH_ARCHIVE = os.path.join(PATH_OUTPUT, "archived")
if not os.path.isdir(PATH_ARCHIVE):
    os.makedirs(PATH_ARCHIVE)

# %%
filename_staged = os.path.join(PATH_DATA, "staged_dataset.gz")

filenames = {"input": "staged_dataset.gz", "output": "results_nrlmf.gz"}

# %%
filename_input = os.path.join(PATH_DATA, filenames["input"])

filename_output = os.path.join(PATH_OUTPUT, filenames["output"])

if os.path.exists(filename_output):
    mdttm = time.strftime("%Y%m%d_%H%M%S")
    os.rename(
        filename_output,
        os.path.join(PATH_ARCHIVE, "%s%s" % (mdttm, filenames["output"])),
    )

# %%
from sgimc.utils import mc_split

# %%
from sgimc.utils import get_submatrix

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_auc_score
from sgimc.utils import sparsify_with_mask


def mc_get_scores(R_true, R_prob):
    R_pred = np.where(R_prob.data > 0.5, 1, -1)

    # compute the confusion matrix for ±1 labels (`-1` is negative)
    ii, jj = ((R_pred + 1) // 2).astype(int), ((R_true.data + 1) // 2).astype(int)
    cnfsn = confusion_matrix(y_true=jj, y_pred=ii)

    return {
        "tn": cnfsn[0, 0],
        "fn": cnfsn[1, 0],
        "fp": cnfsn[0, 1],
        "tp": cnfsn[1, 1],
        "auc": roc_auc_score(R_true.data, R_prob.data),
    }

# %%
import numpy as np


def get_metrics(real_score, predict_score):
    sorted_predict_score = np.array(
        sorted(list(set(np.array(predict_score).flatten())))
    )
    sorted_predict_score_num = len(sorted_predict_score)
    thresholds = sorted_predict_score[
        np.int32(sorted_predict_score_num * np.arange(1, 1000) / 1000)
    ]
    thresholds = np.mat(thresholds)
    thresholds_num = thresholds.shape[1]

    predict_score_matrix = np.tile(predict_score, (thresholds_num, 1))
    negative_index = np.where(predict_score_matrix < thresholds.T)
    positive_index = np.where(predict_score_matrix >= thresholds.T)
    predict_score_matrix[negative_index] = 0
    predict_score_matrix[positive_index] = 1
    TP = predict_score_matrix.dot(real_score.T)
    FP = predict_score_matrix.sum(axis=1) - TP
    FN = real_score.sum() - TP
    TN = len(real_score.T) - TP - FP - FN

    fpr = FP / (FP + TN)
    tpr = TP / (TP + FN)
    ROC_dot_matrix = np.mat(sorted(np.column_stack((fpr, tpr)).tolist())).T
    ROC_dot_matrix.T[0] = [0, 0]
    ROC_dot_matrix = np.c_[ROC_dot_matrix, [1, 1]]
    x_ROC = ROC_dot_matrix[0].T
    y_ROC = ROC_dot_matrix[1].T
    auc = 0.5 * (x_ROC[1:] - x_ROC[:-1]).T * (y_ROC[:-1] + y_ROC[1:])

    recall_list = tpr
    precision_list = TP / (TP + FP)
    PR_dot_matrix = np.mat(
        sorted(np.column_stack((recall_list, precision_list)).tolist())
    ).T
    PR_dot_matrix.T[0] = [0, 1]
    PR_dot_matrix = np.c_[PR_dot_matrix, [1, 0]]
    x_PR = PR_dot_matrix[0].T
    y_PR = PR_dot_matrix[1].T
    aupr = 0.5 * (x_PR[1:] - x_PR[:-1]).T * (y_PR[:-1] + y_PR[1:])

    f1_score_list = 2 * TP / (len(real_score.T) + TP - TN)
    accuracy_list = (TP + TN) / len(real_score.T)
    specificity_list = TN / (TN + FP)

    max_index = np.argmax(f1_score_list)
    f1_score = f1_score_list[max_index]
    accuracy = accuracy_list[max_index]
    specificity = specificity_list[max_index]
    recall = recall_list[max_index]
    precision = precision_list[max_index]
    return [aupr[0, 0], auc[0, 0], f1_score, accuracy, recall, specificity, precision]

# %%
random_state = np.random.RandomState(0x0BADCAFE)

# %% [markdown]
# ## Import model

# %%
# import sys
# import getopt

# package-qualified imports (preferred)
# from PyDTI3 import cv_eval  # if cv_eval exposes functions at top-level
# from PyDTI3.functions import *
from PyDTI3.nrlmf import NRLMF

# from PyDTI3.new_pairs import novel_prediction_analysis

# %% [markdown]
# ## Load data

# %%
from sgimc.utils import load, save

U, V, Y = load(filename_input)

Y = Y.astype(float)

# %% [markdown]
# ## Without selection

# %% [markdown]
# ### Prepare similarity matrix

# %%
# Quick prepare of similarity matrix
from sklearn.metrics.pairwise import cosine_similarity

simD = cosine_similarity(U[:, :])
simT = cosine_similarity(V[:, :])

# %%
# Jaccard distance → convert to similarity
from sklearn.metrics import pairwise_distances

simD = 1 - pairwise_distances(U.toarray(), metric="jaccard")
simT = 1 - pairwise_distances(V.toarray(), metric="jaccard")
# Out:
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/sklearn/metrics/pairwise.py:2182: DataConversionWarning: Data was converted to boolean for metric jaccard
#   warnings.warn(msg, DataConversionWarning)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/sklearn/metrics/pairwise.py:2182: DataConversionWarning: Data was converted to boolean for metric jaccard
#   warnings.warn(msg, DataConversionWarning)

# %% [markdown]
# ### Implementation

# %%
dvlp_size, test_size = 0.9, 0.1

ind_dvlp, ind_test = next(
    mc_split(
        Y,
        n_splits=1,
        random_state=random_state,
        train_size=dvlp_size,
        test_size=test_size,
    )
)

Y_test = get_submatrix(Y, ind_test)

# %%
from sklearn.model_selection import ParameterGrid

grid_dataset = ParameterGrid(
    {
        "train_size": np.arange(0.1, 0.9, 0.1),
        # "train_size": [0.2],
        "n_splits": [5],
    }
)

grid_model = ParameterGrid(
    {
        "c": [1, 3, 5, 7, 9],  # confidence level
        # "c": [5],  # confidence level
        "K1": [5],
        "K2": [5],
        "r": [50, 200],  # rank
        "lambda_d": [0.125],
        "lambda_t": [0.125],
        "alpha": [0.25],
        "beta": [0.125],
        "theta": [0.5],
        "max_iter": [100],
    }
)

# %%
from tqdm import tqdm
from sklearn.model_selection import ShuffleSplit, KFold
from sklearn.model_selection import train_test_split
from scipy.special import expit


results = []
for par_dtst in tqdm(grid_dataset):
    # prepare the train dataset: take the specified share from the beginnig of the index array
    ind_train_all, _ = train_test_split(
        ind_dvlp,
        shuffle=False,
        random_state=random_state,
        test_size=(1 - (par_dtst["train_size"] / dvlp_size)),
    )

    # Run the experiment: the model
    for par_mdl in grid_model:  # tqdm.tqdm(, desc="cv %02d" % (cv,))
        Y_train = get_submatrix(Y, ind_train_all)
        Y_train[Y_train == -1] = 0.0

        # set up the model
        model = NRLMF(
            cfix=par_mdl["c"],
            K1=par_mdl["K1"],
            K2=par_mdl["K2"],
            num_factors=par_mdl["r"],
            lambda_d=par_mdl["lambda_d"],
            lambda_t=par_mdl["lambda_t"],
            alpha=par_mdl["alpha"],
            beta=par_mdl["beta"],
            theta=par_mdl["theta"],
            max_iter=par_mdl["max_iter"],
        )

        # fit on the whole development dataset
        model.fix_model(
            np.ones((Y_train.shape[0], Y_train.shape[1])), Y_train.toarray(), simD, simT
        )
        est_A, est_B = model.U, model.V

        # get the score
        prob_full = expit(simD @ est_A @ est_B.T @ simT.T)
        prob_test = get_submatrix(prob_full, ind_test)
        scores_test = get_metrics((Y_test.data + 1) / 2, prob_test.data)
        d1_test = sum(abs(est_A).max(axis=1) > 0)
        d2_test = sum(abs(est_B).max(axis=1) > 0)

        # record the results
        results.append(
            {
                "train_size": par_dtst["train_size"],
                "lambda_d": par_mdl["lambda_d"],
                "lambda_t": par_mdl["lambda_t"],
                "c": par_mdl["c"],
                "r": par_mdl["r"],
                "test_score": scores_test,
                "test_d1": d1_test,
                "test_d2": d2_test,
            }
        )
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]/Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# 100%|██████████| 8/8 [01:41<00:00, 12.64s/it]

# %%
results
# Out:
# [{'train_size': 0.1,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 1,
#   'r': 50,
#   'test_score': [0.009101192319451085,
#    0.4738563837114267,
#    0.027918781725888325,
#    0.9715379184780589,
#    0.044897959183673466,
#    0.9800509974501275,
#    0.020257826887661142],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.1,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 1,
#   'r': 200,
#   'test_score': [0.011252601909557904,
#    0.47551288251913937,
#    0.029023746701846966,
#    0.9726526214097276,
#    0.044897959183673466,
#    0.9811759412029398,
#    0.021442495126705652],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.1,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 3,
#   'r': 50,
#   'test_score': [0.5025426262174739,
#    0.5020200775675502,
#    0.01815958195901123,
#    0.015605841043361945,
#    1.0,
#    0.00656217189140543,
#    0.009162989004413195],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.1,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 3,
#   'r': 200,
#   'test_score': [0.5005152209294237,
#    0.5008893177790089,
#    0.018146803940448857,
#    0.014899862519971762,
#    1.0,
#    0.0058497075146242685,
#    0.009156482415816422],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.1,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 5,
#   'r': 50,
#   'test_score': [0.5045517036376472,
#    0.5004124793760312,
#    0.018057193396226415,
#    0.009920856091851522,
#    1.0,
#    0.0008249587520623968,
#    0.009110854932877171],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.1,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 5,
#   'r': 200,
#   'test_score': [0.5045517036376472,
#    0.5004312284385781,
#    0.018057858853878755,
#    0.009958012856240478,
#    1.0,
#    0.0008624568771561422,
#    0.009111193752324285],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.1,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 7,
#   'r': 50,
#   'test_score': [0.5045517036376472,
#    0.5002062396880156,
#    0.018049876597782444,
#    0.009512131683572995,
#    1.0,
#    0.0004124793760311984,
#    0.009107129581443758],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.1,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 7,
#   'r': 200,
#   'test_score': [0.5045517036376472,
#    0.5002062396880156,
#    0.018049876597782444,
#    0.009512131683572995,
#    1.0,
#    0.0004124793760311984,
#    0.009107129581443758],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.1,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 9,
#   'r': 50,
#   'test_score': [0.5045517036376472,
#    0.500149992500375,
#    0.018047882136279926,
#    0.009400661390406123,
#    1.0,
#    0.0002999850007499625,
#    0.00910611410518491],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.1,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 9,
#   'r': 200,
#   'test_score': [0.5045517036376472,
#    0.500149992500375,
#    0.018047882136279926,
#    0.009400661390406123,
#    1.0,
#    0.0002999850007499625,
#    0.00910611410518491],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.2,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 1,
#   'r': 50,
#   'test_score': [0.00604509337148257,
#    0.48857057147142646,
#    0.023255813953488372,
#    0.9594248132872589,
#    0.053061224489795916,
#    0.967751612419379,
#    0.014891179839633447],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.2,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 1,
#   'r': 200,
#   'test_score': [0.005585927328756957,
#    0.4955067297655526,
#    0.024024024024024024,
#    0.9637721547207669,
#    0.04897959183673469,
#    0.972176391180441,
#    0.015915119363395226],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.2,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 3,
#   'r': 50,
#   'test_score': [0.49239991573209746,
#    0.500130478169969,
#    0.018177737881508078,
#    0.024634934789878497,
#    0.9918367346938776,
#    0.01574921253937303,
#    0.009172926654335434],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.2,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 3,
#   'r': 200,
#   'test_score': [0.4863206391454159,
#    0.49740137993100336,
#    0.018235029266096353,
#    0.027756102998550886,
#    0.9918367346938776,
#    0.018899055047247638,
#    0.009202105502328927],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.2,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 5,
#   'r': 50,
#   'test_score': [0.5045517036376472,
#    0.5010124493775312,
#    0.018078512396694214,
#    0.011109872552298146,
#    1.0,
#    0.002024898755062247,
#    0.009121709669012249],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.2,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 5,
#   'r': 200,
#   'test_score': [0.5045517036376472,
#    0.5016311684415778,
#    0.01810055040449189,
#    0.012336045777133728,
#    1.0,
#    0.003262336883155842,
#    0.009132930738835459],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.2,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 7,
#   'r': 50,
#   'test_score': [0.5045517036376472,
#    0.5003374831258437,
#    0.018054532056005896,
#    0.009772229034295693,
#    1.0,
#    0.0006749662516874156,
#    0.00910949990704592],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.2,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 7,
#   'r': 200,
#   'test_score': [0.5045517036376472,
#    0.5003937303134843,
#    0.018056527987618382,
#    0.009883699327462565,
#    1.0,
#    0.0007874606269686516,
#    0.009110516138628589],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.2,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 9,
#   'r': 50,
#   'test_score': [0.5045517036376472,
#    0.5002062396880156,
#    0.018049876597782444,
#    0.009512131683572995,
#    1.0,
#    0.0004124793760311984,
#    0.009107129581443758],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.2,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 9,
#   'r': 200,
#   'test_score': [0.5045517036376472,
#    0.5002062396880156,
#    0.018049876597782444,
#    0.009512131683572995,
#    1.0,
#    0.0004124793760311984,
#    0.009107129581443758],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.30000000000000004,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 1,
#   'r': 50,
#   'test_score': [0.006356536574119304,
#    0.5103117548204221,
#    0.025284450063211124,
#    0.9713521346561141,
#    0.04081632653061224,
#    0.9799010049497525,
#    0.018315018315018316],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.30000000000000004,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 1,
#   'r': 200,
#   'test_score': [0.006438130453583315,
#    0.5017999100044997,
#    0.027366020524515394,
#    0.9683052799762196,
#    0.04897959183673469,
#    0.9767511624418779,
#    0.0189873417721519],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.30000000000000004,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 3,
#   'r': 50,
#   'test_score': [0.4822650108631506,
#    0.4960255813739925,
#    0.018285800285950785,
#    0.030505703563333705,
#    0.9918367346938776,
#    0.02167391630418479,
#    0.00922796491094824],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.30000000000000004,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 3,
#   'r': 200,
#   'test_score': [0.48023209109656834,
#    0.4943539302626704,
#    0.018343060714015008,
#    0.037565488797235536,
#    0.9877551020408163,
#    0.028836058197090144,
#    0.009257488236869286],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.30000000000000004,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 5,
#   'r': 50,
#   'test_score': [0.5004937739368617,
#    0.49896979640813877,
#    0.018121301775147928,
#    0.013487905473191394,
#    1.0,
#    0.004424778761061947,
#    0.009143496921067364],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.30000000000000004,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 5,
#   'r': 200,
#   'test_score': [0.49241878186930593,
#    0.5000592317322908,
#    0.018211920529801324,
#    0.030505703563333705,
#    0.9877551020408163,
#    0.021711414429278535,
#    0.009190687782461737],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.30000000000000004,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 7,
#   'r': 50,
#   'test_score': [0.5045517036376472,
#    0.5006749662516874,
#    0.01806651426885923,
#    0.01044105079329692,
#    1.0,
#    0.0013499325033748313,
#    0.009115600699482829],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.30000000000000004,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 7,
#   'r': 200,
#   'test_score': [0.5025268250999564,
#    0.5010357135204464,
#    0.018104563088860152,
#    0.012558986363467469,
#    1.0,
#    0.0034873256337183143,
#    0.009134973900074572],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.30000000000000004,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 9,
#   'r': 50,
#   'test_score': [0.5045517036376472,
#    0.5003749812509375,
#    0.01805586262804923,
#    0.009846542563073608,
#    1.0,
#    0.0007499625018749063,
#    0.009110177369575726],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.30000000000000004,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 9,
#   'r': 200,
#   'test_score': [0.5045517036376472,
#    0.5006937153142343,
#    0.01806718041370156,
#    0.010478207557685876,
#    1.0,
#    0.0013874306284685765,
#    0.009115939872004762],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.4,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 1,
#   'r': 50,
#   'test_score': [0.0062955147126911555,
#    0.504954191065957,
#    0.029459901800327332,
#    0.9779660387173484,
#    0.036734693877551024,
#    0.9866131693415329,
#    0.02459016393442623],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.4,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 1,
#   'r': 200,
#   'test_score': [0.007144591703361466,
#    0.506483119721565,
#    0.028368794326241134,
#    0.9745476163935645,
#    0.04081632653061224,
#    0.9831258437078146,
#    0.021739130434782608],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.4,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 3,
#   'r': 50,
#   'test_score': [0.4822730320417767,
#    0.4964759415090468,
#    0.01839604713036868,
#    0.04038940289079627,
#    0.9877551020408163,
#    0.03168591570421479,
#    0.009284481104929982],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.4,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 3,
#   'r': 200,
#   'test_score': [0.016916318684286464,
#    0.4966257044290643,
#    0.04221635883905013,
#    0.9865120945268087,
#    0.0326530612244898,
#    0.9952752362381881,
#    0.05970149253731343],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.4,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 5,
#   'r': 50,
#   'test_score': [0.5005054177763111,
#    0.5078614436625107,
#    0.01832855634333987,
#    0.03280942295544904,
#    0.9918367346938776,
#    0.023998800059997,
#    0.009249743062692703],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.4,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 5,
#   'r': 200,
#   'test_score': [0.482274771646867,
#    0.49679490515270147,
#    0.018399543812963316,
#    0.04057518671274105,
#    0.9877551020408163,
#    0.03187340632968352,
#    0.00928626247122026],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.4,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 7,
#   'r': 50,
#   'test_score': [0.5025269683164616,
#    0.5003448296972907,
#    0.018103894184585828,
#    0.012521829599078512,
#    1.0,
#    0.0034498275086245686,
#    0.009134633309719996],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.4,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 7,
#   'r': 200,
#   'test_score': [0.49246024020314944,
#    0.5047560632172472,
#    0.018347226980320507,
#    0.04176420317318768,
#    0.9836734693877551,
#    0.03311084445777711,
#    0.009259970798432337],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.4,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 9,
#   'r': 50,
#   'test_score': [0.5045517036376472,
#    0.5007124643767812,
#    0.018067846607669618,
#    0.010515364322074833,
#    1.0,
#    0.001424928753562322,
#    0.009116279069767442],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.4,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 9,
#   'r': 200,
#   'test_score': [0.4985174837817674,
#    0.5046450228508982,
#    0.018238450857507412,
#    0.02794188682049567,
#    0.9918367346938776,
#    0.019086545672716365,
#    0.009203848193318688],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.5,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 1,
#   'r': 50,
#   'test_score': [0.00725984317763273,
#    0.5068584836064319,
#    0.03089887640449438,
#    0.9743618325716197,
#    0.044897959183673466,
#    0.9829008549572521,
#    0.023554603854389723],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.5,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 1,
#   'r': 200,
#   'test_score': [0.007296519448075235,
#    0.5090313086386498,
#    0.03184713375796178,
#    0.9774086872515141,
#    0.04081632653061224,
#    0.986013199340033,
#    0.02610966057441253],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.5,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 3,
#   'r': 50,
#   'test_score': [0.030368864636093586,
#    0.4950301974697183,
#    0.06779661016949153,
#    0.9897818897930368,
#    0.04081632653061224,
#    0.9985000749962502,
#    0.2],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.5,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 3,
#   'r': 200,
#   'test_score': [0.0098178475602273,
#    0.5061905578190479,
#    0.047619047619047616,
#    0.9881098353955338,
#    0.0326530612244898,
#    0.9968876556172191,
#    0.08791208791208792],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.5,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 5,
#   'r': 50,
#   'test_score': [0.484313724118996,
#    0.49837885656737546,
#    0.01838922589752394,
#    0.0439936090365251,
#    0.9836734693877551,
#    0.03536073196340183,
#    0.009281367942694293],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.5,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 5,
#   'r': 200,
#   'test_score': [0.0192304554063078,
#    0.5077659382337004,
#    0.05144694533762058,
#    0.9890387545052577,
#    0.0326530612244898,
#    0.9978251087445628,
#    0.12121212121212122],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.5,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 7,
#   'r': 50,
#   'test_score': [0.500506321793202,
#    0.5079482250377276,
#    0.018331321665660833,
#    0.03295805001300487,
#    0.9918367346938776,
#    0.02414879256037198,
#    0.009251151635131533],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.5,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 7,
#   'r': 200,
#   'test_score': [0.030454502900232754,
#    0.5124662134240228,
#    0.06206896551724138,
#    0.9898933600862037,
#    0.036734693877551024,
#    0.9986500674966252,
#    0.2],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.5,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 9,
#   'r': 50,
#   'test_score': [0.5004985578063285,
#    0.4999999234732141,
#    0.018134715025906734,
#    0.014231040760970535,
#    1.0,
#    0.005174741262936853,
#    0.009150326797385621],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.5,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 9,
#   'r': 200,
#   'test_score': [0.04133628687224718,
#    0.631317745337223,
#    0.05673758865248227,
#    0.9851744510088062,
#    0.04897959183673469,
#    0.9937753112344383,
#    0.06741573033707865],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.6000000000000001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 1,
#   'r': 50,
#   'test_score': [0.007604852988268284,
#    0.5090179929779021,
#    0.03526448362720403,
#    0.9857689592390295,
#    0.02857142857142857,
#    0.994562771861407,
#    0.046052631578947366],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.6000000000000001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 1,
#   'r': 200,
#   'test_score': [0.0076776341914279265,
#    0.5080173287254004,
#    0.0340632603406326,
#    0.985248764537584,
#    0.02857142857142857,
#    0.9940377981100945,
#    0.04216867469879518],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.6000000000000001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 3,
#   'r': 50,
#   'test_score': [0.016781962632713532,
#    0.5076765549477628,
#    0.056962025316455694,
#    0.9889272842120909,
#    0.036734693877551024,
#    0.9976751162441878,
#    0.1267605633802817],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.6000000000000001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 3,
#   'r': 200,
#   'test_score': [0.008736638072525015,
#    0.5080172521986146,
#    0.0392156862745098,
#    0.98361386690447,
#    0.036734693877551024,
#    0.9923128843557822,
#    0.04205607476635514],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.6000000000000001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 5,
#   'r': 50,
#   'test_score': [0.03737710428718049,
#    0.5780041355075103,
#    0.06382978723404255,
#    0.9869208189350871,
#    0.04897959183673469,
#    0.9955377231138443,
#    0.0916030534351145],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.6000000000000001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 5,
#   'r': 200,
#   'test_score': [0.011909456720611559,
#    0.5081094669756308,
#    0.05278592375366569,
#    0.9879983651023669,
#    0.036734693877551024,
#    0.9967376631168442,
#    0.09375],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.6000000000000001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 7,
#   'r': 50,
#   'test_score': [0.48431373827066676,
#    0.49851048263913317,
#    0.018426863625980356,
#    0.04202430052391038,
#    0.9877551020408163,
#    0.033335833208339584,
#    0.009300180623342685],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.6000000000000001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 7,
#   'r': 200,
#   'test_score': [0.015681141975252312,
#    0.508659005825219,
#    0.048484848484848485,
#    0.9883327759818675,
#    0.0326530612244898,
#    0.9971126443677816,
#    0.09411764705882353],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.6000000000000001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 9,
#   'r': 50,
#   'test_score': [0.49653352008125023,
#    0.507086992589146,
#    0.018415368875753096,
#    0.03745401850406867,
#    0.9918367346938776,
#    0.028686065696715165,
#    0.00929396465998623],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.6000000000000001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 9,
#   'r': 200,
#   'test_score': [0.017841866896356518,
#    0.5062751964442594,
#    0.053156146179401995,
#    0.9894103221491473,
#    0.0326530612244898,
#    0.9982000899955003,
#    0.14285714285714285],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.7000000000000001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 1,
#   'r': 50,
#   'test_score': [0.008106411636829115,
#    0.5079387357162753,
#    0.03257328990228013,
#    0.9779288819529596,
#    0.04081632653061224,
#    0.9865381730913454,
#    0.02710027100271003],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.7000000000000001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 1,
#   'r': 200,
#   'test_score': [0.00797383942895508,
#    0.5083519038333798,
#    0.03669724770642202,
#    0.9804926986957976,
#    0.04081632653061224,
#    0.9891255437228138,
#    0.03333333333333333],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.7000000000000001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 3,
#   'r': 50,
#   'test_score': [0.008427004224899642,
#    0.5051938729594133,
#    0.0375,
#    0.9828335748523018,
#    0.036734693877551024,
#    0.9915254237288136,
#    0.03829787234042553],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.7000000000000001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 3,
#   'r': 200,
#   'test_score': [0.007685860046340579,
#    0.5083991208602836,
#    0.034055727554179564,
#    0.9768141790212909,
#    0.044897959183673466,
#    0.9853757312134394,
#    0.02743142144638404],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.7000000000000001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 5,
#   'r': 50,
#   'test_score': [0.015086417064585831,
#    0.5089067230311953,
#    0.0299625468164794,
#    0.9903763980232602,
#    0.0163265306122449,
#    0.9993250337483126,
#    0.18181818181818182],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.7000000000000001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 5,
#   'r': 200,
#   'test_score': [0.009796499030522616,
#    0.5085892133964731,
#    0.043835616438356165,
#    0.987032289228254,
#    0.0326530612244898,
#    0.9958002099895005,
#    0.06666666666666667],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.7000000000000001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 7,
#   'r': 50,
#   'test_score': [0.016586329140866884,
#    0.4941246560120974,
#    0.0477326968973747,
#    0.9851744510088062,
#    0.04081632653061224,
#    0.9938503074846258,
#    0.05747126436781609],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.7000000000000001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 7,
#   'r': 200,
#   'test_score': [0.008935397853544804,
#    0.5085353385391954,
#    0.04747774480712166,
#    0.9880726786311448,
#    0.0326530612244898,
#    0.9968501574921254,
#    0.08695652173913043],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.7000000000000001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 9,
#   'r': 50,
#   'test_score': [0.02603207705058397,
#    0.5712224847941276,
#    0.04984423676012461,
#    0.9886671868613681,
#    0.0326530612244898,
#    0.9974501274936253,
#    0.10526315789473684],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.7000000000000001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 9,
#   'r': 200,
#   'test_score': [0.011750973054319085,
#    0.508644312682325,
#    0.05,
#    0.9887043436257571,
#    0.0326530612244898,
#    0.9974876256187191,
#    0.10666666666666667],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.8,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 1,
#   'r': 50,
#   'test_score': [0.008079089503007543,
#    0.5081961718240617,
#    0.02736318407960199,
#    0.9709434102478356,
#    0.044897959183673466,
#    0.9794510274486276,
#    0.01967799642218247],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.8,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 1,
#   'r': 200,
#   'test_score': [0.008348321333297824,
#    0.5082154565741099,
#    0.026066350710900472,
#    0.9694571396722773,
#    0.044897959183673466,
#    0.9779511024448777,
#    0.018363939899833055],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.8,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 3,
#   'r': 50,
#   'test_score': [0.0069365678466585525,
#    0.507294609759308,
#    0.021653543307086614,
#    0.9630661761973768,
#    0.044897959183673466,
#    0.9715014249287536,
#    0.014267185473411154],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.8,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 3,
#   'r': 200,
#   'test_score': [0.00813288084287996,
#    0.5083263438868872,
#    0.030874785591766724,
#    0.9790064281202393,
#    0.036734693877551024,
#    0.9876631168441578,
#    0.026627218934911243],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.8,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 5,
#   'r': 50,
#   'test_score': [0.0067921723567729644,
#    0.5083128751725681,
#    0.021439509954058193,
#    0.9525136551109129,
#    0.05714285714285714,
#    0.9607394630268487,
#    0.013195098963242224],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.8,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 5,
#   'r': 200,
#   'test_score': [0.008220618144460949,
#    0.5082629031813715,
#    0.03143418467583497,
#    0.9816817151562441,
#    0.0326530612244898,
#    0.9904004799760012,
#    0.030303030303030304],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.8,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 7,
#   'r': 50,
#   'test_score': [0.006841492534253364,
#    0.5078257056534928,
#    0.022090059473237042,
#    0.9572325641883105,
#    0.053061224489795916,
#    0.9655392230388481,
#    0.013948497854077254],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.8,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 7,
#   'r': 200,
#   'test_score': [0.010401656998660476,
#    0.5084280479853557,
#    0.03308823529411765,
#    0.9804555419314086,
#    0.036734693877551024,
#    0.9891255437228138,
#    0.030100334448160536],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.8,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 9,
#   'r': 50,
#   'test_score': [0.006678195847885407,
#    0.5069782480263743,
#    0.0214168039538715,
#    0.955857763905919,
#    0.053061224489795916,
#    0.9641517924103795,
#    0.013415892672858616],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.8,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 9,
#   'r': 200,
#   'test_score': [0.009036231951849718,
#    0.5084996770569635,
#    0.041025641025641026,
#    0.9861033701185301,
#    0.0326530612244898,
#    0.9948627568621569,
#    0.05517241379310345],
#   'test_d1': 658,
#   'test_d2': 409}]

# %%
filename_output
# Out:
# '/Users/sijianfan/Documents/projects/BiSSGL/outputs/results/realAnalysis/cdataset/noisy/results_nrlmf.gz'

# %%
with gzip.open(filename_output, "wb+", 4) as fout:
    pickle.dump(results, fout)

# %% [markdown]
# ---

# %% [markdown]
# ## With identity matrix

# %%
# Just use no information
simD = np.eye(U.shape[0])
simT = np.eye(V.shape[0])

# %%
simD.shape, simT.shape
# Out:
# ((658, 658), (409, 409))

# %% [markdown]
# ### Implementation

# %%
dvlp_size, test_size = 0.9, 0.1

ind_dvlp, ind_test = next(
    mc_split(
        Y,
        n_splits=1,
        random_state=random_state,
        train_size=dvlp_size,
        test_size=test_size,
    )
)

Y_test = get_submatrix(Y, ind_test)

# %%
from sklearn.model_selection import ParameterGrid

grid_dataset = ParameterGrid(
    {
        "train_size": np.arange(0.1, 0.9, 0.1),
        # "train_size": [0.2],
        "n_splits": [5],
    }
)

grid_model = ParameterGrid(
    {
        "c": [1, 3, 5, 7, 9],  # confidence level
        # "c": [5],  # confidence level
        "K1": [5],
        "K2": [5],
        "r": [50, 200],  # rank
        "lambda_d": [0.125],
        "lambda_t": [0.125],
        "alpha": [0.25],
        "beta": [0.125],
        "theta": [0.5],
        "max_iter": [100],
    }
)

# %%
from tqdm import tqdm
from sklearn.model_selection import ShuffleSplit, KFold
from sklearn.model_selection import train_test_split
from scipy.special import expit


results = []
for par_dtst in tqdm(grid_dataset):
    # prepare the train dataset: take the specified share from the beginnig of the index array
    ind_train_all, _ = train_test_split(
        ind_dvlp,
        shuffle=False,
        random_state=random_state,
        test_size=(1 - (par_dtst["train_size"] / dvlp_size)),
    )

    # Run the experiment: the model
    for par_mdl in grid_model:  # tqdm.tqdm(, desc="cv %02d" % (cv,))
        Y_train = get_submatrix(Y, ind_train_all)
        Y_train[Y_train == -1] = 0.0

        # set up the model
        model = NRLMF(
            cfix=par_mdl["c"],
            K1=par_mdl["K1"],
            K2=par_mdl["K2"],
            num_factors=par_mdl["r"],
            lambda_d=par_mdl["lambda_d"],
            lambda_t=par_mdl["lambda_t"],
            alpha=par_mdl["alpha"],
            beta=par_mdl["beta"],
            theta=par_mdl["theta"],
            max_iter=par_mdl["max_iter"],
        )

        # fit on the whole development dataset
        model.fix_model(
            np.ones((Y_train.shape[0], Y_train.shape[1])), Y_train.toarray(), simD, simT
        )
        est_A, est_B = model.U, model.V

        # get the score
        prob_full = expit(simD @ est_A @ est_B.T @ simT.T)
        prob_test = get_submatrix(prob_full, ind_test)
        scores_test = get_metrics((Y_test.data + 1) / 2, prob_test.data)
        d1_test = sum(abs(est_A).max(axis=1) > 0)
        d2_test = sum(abs(est_B).max(axis=1) > 0)

        # record the results
        results.append(
            {
                "train_size": par_dtst["train_size"],
                "lambda_d": par_mdl["lambda_d"],
                "lambda_t": par_mdl["lambda_t"],
                "c": par_mdl["c"],
                "r": par_mdl["r"],
                "test_score": scores_test,
                "test_d1": d1_test,
                "test_d2": d2_test,
            }
        )
# Out:
# 100%|██████████| 8/8 [01:46<00:00, 13.29s/it]

# %%
results
# Out:
# [{'train_size': 0.1,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 1,
#   'r': 50,
#   'test_score': [0.00873269016619658,
#    0.44991191607621867,
#    0.019769357495881382,
#    0.9336751755657118,
#    0.06818181818181818,
#    0.9422492401215805,
#    0.011560693641618497],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.1,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 1,
#   'r': 200,
#   'test_score': [0.008716353091162959,
#    0.45179228113625275,
#    0.02016498625114574,
#    0.960279418868205,
#    0.041666666666666664,
#    0.9693797140605651,
#    0.013301088270858524],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.1,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 3,
#   'r': 50,
#   'test_score': [0.5049046928993424,
#    0.5041277346241885,
#    0.019586749267351707,
#    0.017983873964255194,
#    1.0,
#    0.00825546924837705,
#    0.00989023339452291],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.1,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 3,
#   'r': 200,
#   'test_score': [0.5011678031698721,
#    0.5014428593033793,
#    0.019598381648788094,
#    0.018578382194478504,
#    1.0,
#    0.00885586701189538,
#    0.00989616523597106],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.1,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 5,
#   'r': 50,
#   'test_score': [0.5049046928993424,
#    0.5004502983226388,
#    0.019445365153021765,
#    0.010701148144019618,
#    1.0,
#    0.0009005966452774963,
#    0.009818141247350217],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.1,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 5,
#   'r': 200,
#   'test_score': [0.5049046928993424,
#    0.5004690607527488,
#    0.019446081319976428,
#    0.010738304908408576,
#    1.0,
#    0.000938121505497392,
#    0.009818506396905683],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.1,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 7,
#   'r': 50,
#   'test_score': [0.5049046928993424,
#    0.5002251491613193,
#    0.01943677526228603,
#    0.010255266971352135,
#    1.0,
#    0.00045029832263874815,
#    0.009813761570201852],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.1,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 7,
#   'r': 200,
#   'test_score': [0.5049046928993424,
#    0.5002251491613194,
#    0.01943677526228603,
#    0.010255266971352135,
#    1.0,
#    0.00045029832263874815,
#    0.009813761570201852],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.1,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 9,
#   'r': 50,
#   'test_score': [0.5049046928993424,
#    0.5001688618709895,
#    0.019434628975265017,
#    0.010143796678185263,
#    1.0,
#    0.00033772374197906115,
#    0.009812667261373774],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.1,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 9,
#   'r': 200,
#   'test_score': [0.5049046928993424,
#    0.5001688618709895,
#    0.019434628975265017,
#    0.010143796678185263,
#    1.0,
#    0.00033772374197906115,
#    0.009812667261373774],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.2,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 1,
#   'r': 50,
#   'test_score': [0.005309907126986533,
#    0.4649385615697673,
#    0.01995305164319249,
#    0.9379482034704418,
#    0.06439393939393939,
#    0.9466021239070884,
#    0.011805555555555555],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.2,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 1,
#   'r': 200,
#   'test_score': [0.004786190718219926,
#    0.4777951614535539,
#    0.01990632318501171,
#    0.9377995764128859,
#    0.06439393939393939,
#    0.9464520244662089,
#    0.011772853185595568],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.2,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 3,
#   'r': 50,
#   'test_score': [0.49742848008362534,
#    0.5045321929187176,
#    0.019649017549122544,
#    0.028573551815107942,
#    0.9924242424242424,
#    0.01902510413148711,
#    0.009922738978942584],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.2,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 3,
#   'r': 200,
#   'test_score': [0.4936862115246213,
#    0.5042058403465022,
#    0.019666942958330193,
#    0.03318099059933861,
#    0.9886363636363636,
#    0.02371571165897407,
#    0.009932262729279245],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.2,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 5,
#   'r': 50,
#   'test_score': [0.5049046928993424,
#    0.5009381215054973,
#    0.01946400265418218,
#    0.011667224018132501,
#    1.0,
#    0.001876243010994784,
#    0.009827643971261587],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.2,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 5,
#   'r': 200,
#   'test_score': [0.5049046928993424,
#    0.5016510938496754,
#    0.019491306434346045,
#    0.013079181064912867,
#    1.0,
#    0.0033021876993508197,
#    0.00984156570363467],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.2,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 7,
#   'r': 50,
#   'test_score': [0.5049046928993424,
#    0.5003001988817591,
#    0.01943963771584257,
#    0.010403894028907963,
#    1.0,
#    0.0006003977635183309,
#    0.009815221028367476],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.2,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 7,
#   'r': 200,
#   'test_score': [0.5049046928993424,
#    0.5004690607527488,
#    0.019446081319976428,
#    0.010738304908408576,
#    1.0,
#    0.000938121505497392,
#    0.009818506396905683],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.2,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 9,
#   'r': 50,
#   'test_score': [0.5049046928993424,
#    0.5002251491613193,
#    0.01943677526228603,
#    0.010255266971352135,
#    1.0,
#    0.00045029832263874815,
#    0.009813761570201852],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.2,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 9,
#   'r': 200,
#   'test_score': [0.5049046928993424,
#    0.5002439115914293,
#    0.019437490796642615,
#    0.010292423735741092,
#    1.0,
#    0.00048782318285864383,
#    0.009814126394052044],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.30000000000000004,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 1,
#   'r': 50,
#   'test_score': [0.005461400208152907,
#    0.5009693922223474,
#    0.01995305164319249,
#    0.9379482034704418,
#    0.06439393939393939,
#    0.9466021239070884,
#    0.011805555555555555],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.30000000000000004,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 1,
#   'r': 200,
#   'test_score': [0.006121801654953422,
#    0.5030786731436849,
#    0.01991798476859988,
#    0.9378367331772749,
#    0.06439393939393939,
#    0.9464895493264288,
#    0.01178101178101178],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.30000000000000004,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 3,
#   'r': 50,
#   'test_score': [0.4842514137074687,
#    0.4978836831673711,
#    0.019725202333897986,
#    0.032400698547170516,
#    0.9924242424242424,
#    0.022890164734136364,
#    0.009961598418311091],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.30000000000000004,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 3,
#   'r': 200,
#   'test_score': [0.48420956064287185,
#    0.49761980095904446,
#    0.019635028290928166,
#    0.027867573291717757,
#    0.9924242424242424,
#    0.018312131787309092,
#    0.009915603829996594],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.30000000000000004,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 5,
#   'r': 50,
#   'test_score': [0.5049046928993424,
#    0.5030770385380314,
#    0.019546144448969016,
#    0.0159030951584736,
#    1.0,
#    0.006154077076062892,
#    0.00986952783281618],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.30000000000000004,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 5,
#   'r': 200,
#   'test_score': [0.501203446868938,
#    0.5084170109288311,
#    0.019754948162111215,
#    0.033886969122728795,
#    0.9924242424242424,
#    0.024391159142932193,
#    0.009976771638551464],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.30000000000000004,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 7,
#   'r': 50,
#   'test_score': [0.5049046928993424,
#    0.500712972344178,
#    0.01945539629315745,
#    0.011221342845465016,
#    1.0,
#    0.001425944688356036,
#    0.00982325581395349],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.30000000000000004,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 7,
#   'r': 200,
#   'test_score': [0.5049046928993424,
#    0.5034147622800105,
#    0.0195591776254862,
#    0.016571916917474828,
#    1.0,
#    0.006829524560021014,
#    0.009876173730874266],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.30000000000000004,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 9,
#   'r': 50,
#   'test_score': [0.5049046928993424,
#    0.5002626740215392,
#    0.01943820638368369,
#    0.010329580500130048,
#    1.0,
#    0.0005253480430785396,
#    0.009814491245027696],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.30000000000000004,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 9,
#   'r': 200,
#   'test_score': [0.5049046928993424,
#    0.501069458516267,
#    0.019469026548672566,
#    0.0119273213688552,
#    1.0,
#    0.0021389170325340537,
#    0.009830205540661306],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.4,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 1,
#   'r': 50,
#   'test_score': [0.006069268175015759,
#    0.5032374431015092,
#    0.01967799642218247,
#    0.9592761862297031,
#    0.041666666666666664,
#    0.968366542834628,
#    0.01288056206088993],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.4,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 1,
#   'r': 200,
#   'test_score': [0.00615752960259153,
#    0.5028779719973574,
#    0.01924500370096225,
#    0.950767287184632,
#    0.04924242424242424,
#    0.9596983001238321,
#    0.011959521619135235],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.4,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 3,
#   'r': 50,
#   'test_score': [0.48425504769992045,
#    0.49809767436835983,
#    0.019933807585498536,
#    0.04273027904730056,
#    0.9924242424242424,
#    0.033322075875267365,
#    0.01006801675440956],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.4,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 3,
#   'r': 200,
#   'test_score': [0.016742115892061163,
#    0.47292538693247915,
#    0.03773584905660377,
#    0.9886300300969791,
#    0.022727272727272728,
#    0.998198806709445,
#    0.1111111111111111],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.4,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 5,
#   'r': 50,
#   'test_score': [0.5011943741270285,
#    0.5077930179880535,
#    0.01972965849617832,
#    0.03262363913350425,
#    0.9924242424242424,
#    0.02311531389545574,
#    0.009963871458452176],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.4,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 5,
#   'r': 200,
#   'test_score': [0.4842480212701044,
#    0.49802681776677027,
#    0.01970258830580215,
#    0.0275703191766061,
#    0.9962121212121212,
#    0.017974408045330032,
#    0.009949684106987478],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.4,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 7,
#   'r': 50,
#   'test_score': [0.5049046928993424,
#    0.5022514916131937,
#    0.01951435857633884,
#    0.014268197525359492,
#    1.0,
#    0.004502983226387482,
#    0.00985331989698802],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.4,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 7,
#   'r': 200,
#   'test_score': [0.49370382833914483,
#    0.5053920665622793,
#    0.019707397796081084,
#    0.03150893620183554,
#    0.9924242424242424,
#    0.02198956808885887,
#    0.009952516619183286],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.4,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 9,
#   'r': 50,
#   'test_score': [0.5049046928993424,
#    0.5006942099140681,
#    0.019454679439941048,
#    0.01118418608107606,
#    1.0,
#    0.0013884198281361403,
#    0.009822890311058194],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.4,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 9,
#   'r': 200,
#   'test_score': [0.4993332640479202,
#    0.5061935918909914,
#    0.019719887955182074,
#    0.02474640508304537,
#    1.0,
#    0.015084993808398063,
#    0.009958130587303384],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.5,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 1,
#   'r': 50,
#   'test_score': [0.006156060199854647,
#    0.5029385945461596,
#    0.019315188762071993,
#    0.958495894177535,
#    0.041666666666666664,
#    0.9675785207700102,
#    0.012571428571428572],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.5,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 1,
#   'r': 200,
#   'test_score': [0.006240272933446744,
#    0.5010988103482195,
#    0.018851756640959727,
#    0.9574555047746443,
#    0.041666666666666664,
#    0.966527824683853,
#    0.012181616832779624],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.5,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 3,
#   'r': 50,
#   'test_score': [0.009135371753887365,
#    0.47285161646863777,
#    0.02011173184357542,
#    0.9348270352617694,
#    0.06818181818181818,
#    0.9434125107883973,
#    0.011795543905635648],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.5,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 3,
#   'r': 200,
#   'test_score': [0.006185082318055302,
#    0.5042578634481708,
#    0.021119324181626188,
#    0.9655556794114368,
#    0.03787878787878788,
#    0.9747457690720102,
#    0.014641288433382138],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.5,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 5,
#   'r': 50,
#   'test_score': [0.48614825595761424,
#    0.4998683076401752,
#    0.01983045716015743,
#    0.03763980232601345,
#    0.9924242424242424,
#    0.028181170025141658,
#    0.010015290519877675],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.5,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 5,
#   'r': 200,
#   'test_score': [0.011043477600302005,
#    0.5043792506853972,
#    0.021321961620469083,
#    0.9658900902909374,
#    0.03787878787878788,
#    0.9750834928139893,
#    0.01483679525222552],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.5,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 7,
#   'r': 50,
#   'test_score': [0.5012140478365341,
#    0.5084137417175242,
#    0.019753458740151542,
#    0.03381265559395088,
#    0.9924242424242424,
#    0.0243161094224924,
#    0.00997601187983094],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.5,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 7,
#   'r': 200,
#   'test_score': [0.013100812093803168,
#    0.4893392440673764,
#    0.02538787023977433,
#    0.9743246758072307,
#    0.03409090909090909,
#    0.9836391609441255,
#    0.020224719101123594],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.5,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 9,
#   'r': 50,
#   'test_score': [0.5049046928993424,
#    0.5031896131186911,
#    0.019550486910800902,
#    0.01612603574480734,
#    1.0,
#    0.006379226237382266,
#    0.009871742138129604],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.5,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 9,
#   'r': 200,
#   'test_score': [0.051638884149487946,
#    0.5932804062236687,
#    0.02767763693452727,
#    0.6893322929439304,
#    0.45075757575757575,
#    0.691695748433337,
#    0.014277144571085783],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.6000000000000001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 1,
#   'r': 50,
#   'test_score': [0.00707914185844379,
#    0.5011270961330062,
#    0.02103049421661409,
#    0.965407052353881,
#    0.03787878787878788,
#    0.9745956696311306,
#    0.01455604075691412],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.6000000000000001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 1,
#   'r': 200,
#   'test_score': [0.006817149012036259,
#    0.5021255559080618,
#    0.020512820512820513,
#    0.9645152900085461,
#    0.03787878787878788,
#    0.9736950729858531,
#    0.014064697609001406],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.6000000000000001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 3,
#   'r': 50,
#   'test_score': [0.005166637602090891,
#    0.487858220275478,
#    0.023166023166023165,
#    0.9717980158287817,
#    0.03409090909090909,
#    0.9810874704491725,
#    0.017543859649122806],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.6000000000000001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 3,
#   'r': 200,
#   'test_score': [0.006453819291351451,
#    0.5020264845914965,
#    0.019550342130987292,
#    0.9627317653178761,
#    0.03787878787878788,
#    0.9718938796952982,
#    0.013175230566534914],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.6000000000000001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 5,
#   'r': 50,
#   'test_score': [0.02871744155637544,
#    0.5760432053280753,
#    0.05309734513274336,
#    0.9880726786311448,
#    0.03409090909090909,
#    0.9975233592254868,
#    0.12],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.6000000000000001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 5,
#   'r': 200,
#   'test_score': [0.009433113741417015,
#    0.5021706852380611,
#    0.030257186081694403,
#    0.9761825140266785,
#    0.03787878787878788,
#    0.9854778790949004,
#    0.02518891687657431],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.6000000000000001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 7,
#   'r': 50,
#   'test_score': [0.48614724772581663,
#    0.4997614897142083,
#    0.01990276511698572,
#    0.041206851707353324,
#    0.9924242424242424,
#    0.031783556606251644,
#    0.010052179251074279],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.6000000000000001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 7,
#   'r': 200,
#   'test_score': [0.017252595046966263,
#    0.5013085373605469,
#    0.03709949409780776,
#    0.9787834875339055,
#    0.041666666666666664,
#    0.9880670944500731,
#    0.03343465045592705],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.6000000000000001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 9,
#   'r': 50,
#   'test_score': [0.4993664681616229,
#    0.5093131301760143,
#    0.019840218090946955,
#    0.03812284026306989,
#    0.9924242424242424,
#    0.0286689932080003,
#    0.010020270011856045],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.6000000000000001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 9,
#   'r': 200,
#   'test_score': [0.006986924957214249,
#    0.5048279854721935,
#    0.031088082901554404,
#    0.9861033701185301,
#    0.022727272727272728,
#    0.9956471162144921,
#    0.04918032786885246],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.7000000000000001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 1,
#   'r': 50,
#   'test_score': [0.007146044979201447,
#    0.5020716139214958,
#    0.020892687559354226,
#    0.9616913759149853,
#    0.041666666666666664,
#    0.9708056587489211,
#    0.01394169835234474],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.7000000000000001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 1,
#   'r': 200,
#   'test_score': [0.011997431339380077,
#    0.5024818999405288,
#    0.021215043394406944,
#    0.9622858841452087,
#    0.041666666666666664,
#    0.9714060565124395,
#    0.014230271668822769],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.7000000000000001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 3,
#   'r': 50,
#   'test_score': [0.006272114545584416,
#    0.5037646389596744,
#    0.02252252252252252,
#    0.9677479285103853,
#    0.03787878787878788,
#    0.9769597358249841,
#    0.016025641025641024],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.7000000000000001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 3,
#   'r': 200,
#   'test_score': [0.01237956479703791,
#    0.502596251266464,
#    0.02250351617440225,
#    0.9741760487496749,
#    0.030303030303030304,
#    0.9835265863634658,
#    0.017897091722595078],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.7000000000000001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 5,
#   'r': 50,
#   'test_score': [0.006146838339435218,
#    0.5039824679304584,
#    0.02838709677419355,
#    0.9720209564151153,
#    0.041666666666666664,
#    0.9812375698900522,
#    0.021526418786692758],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.7000000000000001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 5,
#   'r': 200,
#   'test_score': [0.01462406996650793,
#    0.502841797463547,
#    0.03210272873194221,
#    0.9775944710734589,
#    0.03787878787878788,
#    0.9869038237832564,
#    0.027855153203342618],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.7000000000000001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 7,
#   'r': 50,
#   'test_score': [0.007501290664925717,
#    0.46241927890864054,
#    0.023404255319148935,
#    0.9658900902909374,
#    0.041666666666666664,
#    0.9750459679537694,
#    0.016272189349112426],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.7000000000000001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 7,
#   'r': 200,
#   'test_score': [0.017527296704934837,
#    0.5029310611461912,
#    0.03355704697986577,
#    0.9785977037119608,
#    0.03787878787878788,
#    0.9879169950091936,
#    0.030120481927710843],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.7000000000000001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 9,
#   'r': 50,
#   'test_score': [0.026507710678064483,
#    0.5315841347165224,
#    0.050955414012738856,
#    0.9889272842120909,
#    0.030303030303030304,
#    0.9984239558707644,
#    0.16],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.7000000000000001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 9,
#   'r': 200,
#   'test_score': [0.021625625848579036,
#    0.5029647482366159,
#    0.03666666666666667,
#    0.9785233901831828,
#    0.041666666666666664,
#    0.9878044204285339,
#    0.03273809523809524],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.8,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 1,
#   'r': 50,
#   'test_score': [0.011335363635154892,
#    0.5023920676993964,
#    0.020385050962627407,
#    0.9678593988035522,
#    0.03409090909090909,
#    0.9771098352658636,
#    0.014539579967689823],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.8,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 1,
#   'r': 200,
#   'test_score': [0.011702115673874023,
#    0.5026027186192671,
#    0.021739130434782608,
#    0.9665589120499387,
#    0.03787878787878788,
#    0.9757589402979474,
#    0.01524390243902439],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.8,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 3,
#   'r': 50,
#   'test_score': [0.006972639507315971,
#    0.5017468248851227,
#    0.021164021164021163,
#    0.9656299929402148,
#    0.03787878787878788,
#    0.97482081879245,
#    0.014684287812041116],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.8,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 3,
#   'r': 200,
#   'test_score': [0.013170995308093911,
#    0.5027113132905096,
#    0.02564102564102564,
#    0.9717608590643927,
#    0.03787878787878788,
#    0.9810124207287327,
#    0.01937984496124031],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.8,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 5,
#   'r': 50,
#   'test_score': [0.00603986765761708,
#    0.5009889364203785,
#    0.018487394957983194,
#    0.9566008991936982,
#    0.041666666666666664,
#    0.9656647528987955,
#    0.011879049676025918],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.8,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 5,
#   'r': 200,
#   'test_score': [0.011560861749362324,
#    0.5025815398155824,
#    0.02269861286254729,
#    0.9712035075985583,
#    0.03409090909090909,
#    0.9804870726856543,
#    0.017013232514177693],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.8,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 7,
#   'r': 50,
#   'test_score': [0.006219819893436608,
#    0.5043368930780279,
#    0.020484171322160148,
#    0.9609110838628172,
#    0.041666666666666664,
#    0.9700176366843033,
#    0.013580246913580247],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.8,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 7,
#   'r': 200,
#   'test_score': [0.014032906712489421,
#    0.5027838044977525,
#    0.02932551319648094,
#    0.9754022219745104,
#    0.03787878787878788,
#    0.9846898570302826,
#    0.023923444976076555],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.8,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 9,
#   'r': 50,
#   'test_score': [0.006640027961021843,
#    0.5042781894141233,
#    0.023980815347721823,
#    0.9848771968936945,
#    0.01893939393939394,
#    0.9944463206874554,
#    0.032679738562091505],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.8,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 9,
#   'r': 200,
#   'test_score': [0.018190399815378754,
#    0.5029245227235771,
#    0.03669724770642202,
#    0.9804926986957976,
#    0.03787878787878788,
#    0.9898307628804083,
#    0.03558718861209965],
#   'test_d1': 658,
#   'test_d2': 409}]

# %%
filename_output = "/Users/sijianfan/Documents/projects/BiSSGL/outputs/results/realAnalysis/cdataset/noisy/results_nrlmf_identity.gz"

# %%
with gzip.open(filename_output, "wb+", 4) as fout:
    pickle.dump(results, fout)

# %% [markdown]
# ---

# %% [markdown]
# ## With selection

# %%
from sgimc import SparseGroupIMCClassifier

C_lasso, C_group, C_ridge, rank = (0.0, 1.0, 1.0, 13)

imc = SparseGroupIMCClassifier(
    rank,
    n_threads=8,
    random_state=42,
    C_lasso=C_lasso,
    C_group=C_group,
    C_ridge=C_ridge,
)

# fit on the whole development dataset
Y_train = get_submatrix(Y, ind_train_all)
imc.fit(U, V, Y_train)

# get the score
prob_full = imc.predict_proba(U, V)
prob_test = get_submatrix(prob_full, ind_test)
scores_test = mc_get_scores(Y_test, prob_test)
d1_test = sum(abs(imc.coef_W_).max(axis=1) > 0)
d2_test = sum(abs(imc.coef_H_).max(axis=1) > 0)

print(scores_test, d1_test, d2_test)
# Out:
# {'tn': 5309, 'fn': 408, 'fp': 335, 'tp': 2982, 'auc': 0.9661509912633355} 1457 22

# %% [markdown]
# ### Prepare similarity matrix

# %%
# Jaccard distance → convert to similarity
from sklearn.metrics import pairwise_distances

simD = 1 - pairwise_distances(
    U[:, np.where(abs(imc.coef_W_).max(axis=1) > 0)[0]].toarray(), metric="jaccard"
)
simT = 1 - pairwise_distances(
    V[:, np.where(abs(imc.coef_H_).max(axis=1) > 0)[0]].toarray(), metric="jaccard"
)
# Out:
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/sklearn/metrics/pairwise.py:2182: DataConversionWarning: Data was converted to boolean for metric jaccard
#   warnings.warn(msg, DataConversionWarning)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/sklearn/metrics/pairwise.py:2182: DataConversionWarning: Data was converted to boolean for metric jaccard
#   warnings.warn(msg, DataConversionWarning)

# %% [markdown]
# ### Implementation

# %%
dvlp_size, test_size = 0.9, 0.1

ind_dvlp, ind_test = next(
    mc_split(
        Y,
        n_splits=1,
        random_state=random_state,
        train_size=dvlp_size,
        test_size=test_size,
    )
)

Y_test = get_submatrix(Y, ind_test)

# %%
from sklearn.model_selection import ParameterGrid

grid_dataset = ParameterGrid(
    {
        "train_size": np.arange(0.001, 0.2, 0.02),
        # "train_size": [0.2],
        "n_splits": [2],
    }
)

grid_model = ParameterGrid(
    {
        "c": [1, 3, 5, 7, 9],  # confidence level
        # "c": [1],  # confidence level
        "K1": [5],
        "K2": [5],
        "r": [50],  # rank
        "lambda_d": [0.125],
        "lambda_t": [0.125],
        "alpha": [0.25],
        "beta": [0.125],
        "theta": [0.5],
        "max_iter": [100],
    }
)

# %%
from tqdm import tqdm
from sklearn.model_selection import ShuffleSplit, KFold
from sklearn.model_selection import train_test_split
from scipy.special import expit


results = []
for par_dtst in tqdm(grid_dataset):
    # prepare the train dataset: take the specified share from the beginnig of the index array
    ind_train_all, _ = train_test_split(
        ind_dvlp,
        shuffle=False,
        random_state=random_state,
        test_size=(1 - (par_dtst["train_size"] / dvlp_size)),
    )

    # Run the experiment: the model
    for par_mdl in grid_model:  # tqdm.tqdm(, desc="cv %02d" % (cv,))
        Y_train = get_submatrix(Y, ind_train_all)

        Y_train[Y_train == 0] = 0.5
        Y_train[Y_train == -1] = 0.0

        # set up the model
        model = NRLMF(
            cfix=par_mdl["c"],
            K1=par_mdl["K1"],
            K2=par_mdl["K2"],
            num_factors=par_mdl["r"],
            lambda_d=par_mdl["lambda_d"],
            lambda_t=par_mdl["lambda_t"],
            alpha=par_mdl["alpha"],
            beta=par_mdl["beta"],
            theta=par_mdl["theta"],
            max_iter=par_mdl["max_iter"],
        )

        # fit on the whole development dataset
        model.fix_model(np.ones(Y_train.shape), Y_train.toarray(), simD, simT)
        est_A, est_B = model.U, model.V

        # get the score
        prob_full = expit(simD @ est_A @ est_B.T @ simT.T)
        prob_test = get_submatrix(prob_full, ind_test)
        scores_test = mc_get_scores(Y_test, prob_test)
        d1_test = sum(abs(est_A).max(axis=1) > 0)
        d2_test = sum(abs(est_B).max(axis=1) > 0)

        # record the results
        results.append(
            {
                "train_size": par_dtst["train_size"],
                "lambda_d": par_mdl["lambda_d"],
                "lambda_t": par_mdl["lambda_t"],
                "c": par_mdl["c"],
                "r": par_mdl["r"],
                "test_score": scores_test["auc"],
                "test_d1": d1_test,
                "test_d2": d2_test,
            }
        )
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]/Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
#  10%|█         | 1/10 [00:34<05:13, 34.86s/it]/Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
#  20%|██        | 2/10 [01:11<04:45, 35.68s/it]/Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
#  30%|███       | 3/10 [01:50<04:23, 37.59s/it]/Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
#  40%|████      | 4/10 [02:30<03:50, 38.36s/it]/Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
#  50%|█████     | 5/10 [03:09<03:12, 38.55s/it]/Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
#  60%|██████    | 6/10 [03:49<02:35, 38.99s/it]/Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
#  70%|███████   | 7/10 [04:28<01:56, 38.97s/it]/Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
#  80%|████████  | 8/10 [05:09<01:19, 39.61s/it]/Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
#  90%|█████████ | 9/10 [05:50<00:40, 40.22s/it]/Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# 100%|██████████| 10/10 [06:27<00:00, 38.78s/it]

# %%
results
# Out:
# [{'train_size': 0.001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 1,
#   'r': 50,
#   'test_score': 0.6974269223901604,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 3,
#   'r': 50,
#   'test_score': 0.5001759324419424,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 5,
#   'r': 50,
#   'test_score': 0.5001759324419424,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 7,
#   'r': 50,
#   'test_score': 0.5001759324419424,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 9,
#   'r': 50,
#   'test_score': 0.5001759324419424,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.021,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 1,
#   'r': 50,
#   'test_score': 0.7786309830159547,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.021,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 3,
#   'r': 50,
#   'test_score': 0.5001759324419424,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.021,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 5,
#   'r': 50,
#   'test_score': 0.5001759324419424,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.021,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 7,
#   'r': 50,
#   'test_score': 0.5001759324419424,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.021,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 9,
#   'r': 50,
#   'test_score': 0.5001759324419424,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.041,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 1,
#   'r': 50,
#   'test_score': 0.7799316751919502,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.041,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 3,
#   'r': 50,
#   'test_score': 0.5001759324419424,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.041,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 5,
#   'r': 50,
#   'test_score': 0.5001759324419424,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.041,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 7,
#   'r': 50,
#   'test_score': 0.5001759324419424,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.041,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 9,
#   'r': 50,
#   'test_score': 0.5001759324419424,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.061,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 1,
#   'r': 50,
#   'test_score': 0.7803930645855872,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.061,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 3,
#   'r': 50,
#   'test_score': 0.5001759324419424,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.061,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 5,
#   'r': 50,
#   'test_score': 0.5001759324419424,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.061,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 7,
#   'r': 50,
#   'test_score': 0.5001759324419424,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.061,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 9,
#   'r': 50,
#   'test_score': 0.5001759324419424,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.081,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 1,
#   'r': 50,
#   'test_score': 0.7572269108363878,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.081,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 3,
#   'r': 50,
#   'test_score': 0.5001759324419424,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.081,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 5,
#   'r': 50,
#   'test_score': 0.5001759324419424,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.081,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 7,
#   'r': 50,
#   'test_score': 0.5001759324419424,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.081,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 9,
#   'r': 50,
#   'test_score': 0.5001759324419424,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.101,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 1,
#   'r': 50,
#   'test_score': 0.7385303864211666,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.101,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 3,
#   'r': 50,
#   'test_score': 0.5001759324419424,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.101,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 5,
#   'r': 50,
#   'test_score': 0.5001759324419424,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.101,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 7,
#   'r': 50,
#   'test_score': 0.5001759324419424,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.101,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 9,
#   'r': 50,
#   'test_score': 0.5001759324419424,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.121,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 1,
#   'r': 50,
#   'test_score': 0.6984576501727813,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.121,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 3,
#   'r': 50,
#   'test_score': 0.5001759324419424,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.121,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 5,
#   'r': 50,
#   'test_score': 0.5001759324419424,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.121,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 7,
#   'r': 50,
#   'test_score': 0.5001759324419424,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.121,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 9,
#   'r': 50,
#   'test_score': 0.5001759324419424,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.14100000000000001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 1,
#   'r': 50,
#   'test_score': 0.6782890701313979,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.14100000000000001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 3,
#   'r': 50,
#   'test_score': 0.5001759324419424,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.14100000000000001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 5,
#   'r': 50,
#   'test_score': 0.5001759324419424,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.14100000000000001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 7,
#   'r': 50,
#   'test_score': 0.5001759324419424,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.14100000000000001,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 9,
#   'r': 50,
#   'test_score': 0.5001759324419424,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.161,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 1,
#   'r': 50,
#   'test_score': 0.6352313380318674,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.161,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 3,
#   'r': 50,
#   'test_score': 0.5001759324419424,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.161,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 5,
#   'r': 50,
#   'test_score': 0.5001759324419424,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.161,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 7,
#   'r': 50,
#   'test_score': 0.5001759324419424,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.161,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 9,
#   'r': 50,
#   'test_score': 0.5001759324419424,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.181,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 1,
#   'r': 50,
#   'test_score': 0.6020384005377756,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.181,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 3,
#   'r': 50,
#   'test_score': 0.5001759324419424,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.181,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 5,
#   'r': 50,
#   'test_score': 0.5001759324419424,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.181,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 7,
#   'r': 50,
#   'test_score': 0.5001759324419424,
#   'test_d1': 6949,
#   'test_d2': 13},
#  {'train_size': 0.181,
#   'lambda_d': 0.125,
#   'lambda_t': 0.125,
#   'c': 9,
#   'r': 50,
#   'test_score': 0.5001759324419424,
#   'test_d1': 6949,
#   'test_d2': 13}]

# %%
filename_output
# Out:
# '/Users/sijianfan/Documents/projects/BiSSGL/outputs/results/realAnalysis/tuberculosis/results_drimc.gz'

# %%
with gzip.open(filename_output, "wb+", 4) as fout:
    pickle.dump(results, fout)

# %% [markdown]
# ---

# %% [markdown]
# ## Quick check of the results

# %%
from collections import defaultdict


def get_test_results(results, param="train_size", hyp_param="C_group"):
    # grouping by validation
    id_result = {}
    param_ids = defaultdict(list)

    for _id, result in enumerate(results):
        comb = "{}|{}".format(result[param], result[hyp_param])
        param_ids[comb].append(_id)

        id_result[_id] = [
            result[param],
            result[hyp_param],
            # result["val_score"],
            result["test_score"],
        ]

    id_groups = list(param_ids.values())

    # averaging the cross-validation results
    results_avg = []

    for ids in id_groups:
        val_res = [id_result[_id] for _id in ids]
        avg_res = np.max(val_res, axis=0)
        results_avg.append(avg_res)

    results_avg = np.array(results_avg)

    # grouping by train_size
    id_result = {}
    param_ids = defaultdict(list)

    for _id, val_res in enumerate(results_avg):
        comb = "{}".format(val_res[0])
        param_ids[comb].append(_id)

        id_result[_id] = val_res[[0, 2]]

    id_groups = list(param_ids.values())

    results_final = []

    for ids in id_groups:
        param_res = results_avg[ids]
        val = [x[2] for x in param_res]
        chosen_result = param_res[np.argmax(val)]
        results_final.append(chosen_result[[0, 2]])

    results_final = np.array(results_final)

    return results_final.T


results_final = []

results_final.append(get_test_results(results, param="train_size", hyp_param="c"))
results_final = np.array(results_final)
results_nrlmf = np.mean(results_final, axis=0)

# %%
results_nrlmf
# Out:
# array([[0.001     , 0.021     , 0.041     , 0.061     , 0.081     ,
#         0.101     , 0.121     , 0.141     , 0.161     , 0.181     ],
#        [0.69742692, 0.77863098, 0.77993168, 0.78039306, 0.75722691,
#         0.73853039, 0.69845765, 0.67828907, 0.63523134, 0.6020384 ]])
