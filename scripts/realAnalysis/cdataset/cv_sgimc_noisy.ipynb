# %% [markdown]
# # Run SGIMC

# %%
import os
import time
import gzip
import pickle
import warnings

# %matplotlib inline
import matplotlib.pyplot as plt

import numpy as np

from tqdm import TqdmSynchronisationWarning
warnings.simplefilter("ignore", TqdmSynchronisationWarning)

# %%
PATH_ROOT = "/Users/sijianfan/Documents/projects/BiSSGL"
PATH_DATA = os.path.join(PATH_ROOT, "datasets/realAnalysis/cdataset/cv_data")

PATH_OUTPUT = os.path.join(PATH_ROOT, "outputs/results/realAnalysis/cdataset/noisy")
if not os.path.isdir(PATH_OUTPUT):
    os.makedirs(PATH_OUTPUT)

PATH_ARCHIVE = os.path.join(PATH_OUTPUT, "archived")
if not os.path.isdir(PATH_ARCHIVE):
    os.makedirs(PATH_ARCHIVE)

# %%
filename_staged = os.path.join(PATH_DATA, "staged_dataset.gz")

filenames = {"input": "staged_dataset.gz", "output": "results_sgimc.gz"}

# %%
filename_input = os.path.join(PATH_DATA, filenames["input"])

filename_output = os.path.join(PATH_OUTPUT, filenames["output"])

# if os.path.exists(filename_output):
#     mdttm = time.strftime("%Y%m%d_%H%M%S")
#     os.rename(
#         filename_output,
#         os.path.join(PATH_ARCHIVE, "%s%s" % (mdttm, filenames["output"])),
#     )

# %%
from sgimc.utils import mc_split

# %%
from sgimc.utils import get_submatrix

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_auc_score
from sgimc.utils import sparsify_with_mask


def mc_get_scores(R_true, R_prob):
    R_pred = np.where(R_prob.data > 0.5, 1, -1)

    # compute the confusion matrix for ±1 labels (`-1` is negative)
    ii, jj = ((R_pred + 1) // 2).astype(int), ((R_true.data + 1) // 2).astype(int)
    cnfsn = confusion_matrix(y_true=jj, y_pred=ii)

    return {
        "tn": cnfsn[0, 0],
        "fn": cnfsn[1, 0],
        "fp": cnfsn[0, 1],
        "tp": cnfsn[1, 1],
        "auc": roc_auc_score(R_true.data, R_prob.data),
    }


def combine_with_identity(X, return_sparse=True):
    """Concatenates X with the identity matrix on the right."""

    assert X.ndim == 2, "Input matrix should have ndim = 2"

    X_add = np.eye(X.shape[0])
    X_comb = np.concatenate((X.toarray(), X_add), axis=1)

    if return_sparse:
        X_comb = sparsify_with_mask(X_comb, X_comb != 0)

    return X_comb

# %%
import numpy as np


def get_metrics(real_score, predict_score):
    sorted_predict_score = np.array(
        sorted(list(set(np.array(predict_score).flatten())))
    )
    sorted_predict_score_num = len(sorted_predict_score)
    thresholds = sorted_predict_score[
        np.int32(sorted_predict_score_num * np.arange(1, 1000) / 1000)
    ]
    thresholds = np.mat(thresholds)
    thresholds_num = thresholds.shape[1]

    predict_score_matrix = np.tile(predict_score, (thresholds_num, 1))
    negative_index = np.where(predict_score_matrix < thresholds.T)
    positive_index = np.where(predict_score_matrix >= thresholds.T)
    predict_score_matrix[negative_index] = 0
    predict_score_matrix[positive_index] = 1
    TP = predict_score_matrix.dot(real_score.T)
    FP = predict_score_matrix.sum(axis=1) - TP
    FN = real_score.sum() - TP
    TN = len(real_score.T) - TP - FP - FN

    fpr = FP / (FP + TN)
    tpr = TP / (TP + FN)
    ROC_dot_matrix = np.mat(sorted(np.column_stack((fpr, tpr)).tolist())).T
    ROC_dot_matrix.T[0] = [0, 0]
    ROC_dot_matrix = np.c_[ROC_dot_matrix, [1, 1]]
    x_ROC = ROC_dot_matrix[0].T
    y_ROC = ROC_dot_matrix[1].T
    auc = 0.5 * (x_ROC[1:] - x_ROC[:-1]).T * (y_ROC[:-1] + y_ROC[1:])

    recall_list = tpr
    precision_list = TP / (TP + FP)
    PR_dot_matrix = np.mat(
        sorted(np.column_stack((recall_list, precision_list)).tolist())
    ).T
    PR_dot_matrix.T[0] = [0, 1]
    PR_dot_matrix = np.c_[PR_dot_matrix, [1, 0]]
    x_PR = PR_dot_matrix[0].T
    y_PR = PR_dot_matrix[1].T
    aupr = 0.5 * (x_PR[1:] - x_PR[:-1]).T * (y_PR[:-1] + y_PR[1:])

    f1_score_list = 2 * TP / (len(real_score.T) + TP - TN)
    accuracy_list = (TP + TN) / len(real_score.T)
    specificity_list = TN / (TN + FP)

    max_index = np.argmax(f1_score_list)
    f1_score = f1_score_list[max_index]
    accuracy = accuracy_list[max_index]
    specificity = specificity_list[max_index]
    recall = recall_list[max_index]
    precision = precision_list[max_index]
    return [aupr[0, 0], auc[0, 0], f1_score, accuracy, recall, specificity, precision]

# %%
random_state = np.random.RandomState(0x0BADCAFE)

# %%
from sgimc.utils import load, save

U, V, Y = load(filename_input)

# %%
print(U.shape, V.shape, Y.shape)
# Out:
# (658, 1888) (409, 797) (658, 409)

# %%
plt.imshow(Y, aspect="auto")

# %%
dvlp_size, test_size = 0.9, 0.1

ind_dvlp, ind_test = next(
    mc_split(
        Y,
        n_splits=1,
        random_state=random_state,
        train_size=dvlp_size,
        test_size=test_size,
    )
)

Y_test = get_submatrix(Y, ind_test)

# %%
from sklearn.model_selection import ParameterGrid

grid_dataset = ParameterGrid(
    {
        "train_size": np.arange(0.1, 0.9, 0.1),
        # "train_size": [0.81],
        "n_splits": [5],
    }
)

grid_model = ParameterGrid(
    {
        "C_lasso": [1.0, 1e-2, 1e-4],
        # "C_lasso": [1e-4],
        "C_group": [1.0, 1e-2, 1e-4],
        # "C_group": [1e-2],
        "C_ridge": [1.0, 1e-2, 1e-4],
        # "C_ridge": [1e-4],
        "rank": [50],
    }
)

# %%
from sgimc import SparseGroupIMCClassifier

# %%
from tqdm import tqdm
from sklearn.model_selection import ShuffleSplit, KFold
from sklearn.model_selection import train_test_split


results = []
for par_dtst in tqdm(grid_dataset):
    # prepare the train dataset: take the specified share from the beginnig of the index array
    ind_train_all, _ = train_test_split(
        ind_dvlp,
        shuffle=False,
        random_state=random_state,
        test_size=(1 - (par_dtst["train_size"] / dvlp_size)),
    )

    # Run the experiment: the model
    for par_mdl in grid_model:  # tqdm.tqdm(, desc="cv %02d" % (cv,))
        # set up the model
        C_lasso, C_group, C_ridge = (
            par_mdl["C_lasso"],
            par_mdl["C_group"],
            par_mdl["C_ridge"],
        )
        imc = SparseGroupIMCClassifier(
            par_mdl["rank"],
            n_threads=-1,
            random_state=42,
            C_lasso=C_lasso,
            C_group=C_group,
            C_ridge=C_ridge,
        )

        # fit on the whole development dataset
        Y_train = get_submatrix(Y, ind_train_all)
        Y_train[Y_train == 0] = -1

        imc.fit(U, V, Y_train)

        # get the score
        prob_full = imc.predict_proba(U, V)
        prob_test = get_submatrix(prob_full, ind_test)
        # scores_test = mc_get_scores(Y_test, prob_test)
        scores_test = get_metrics((Y_test.data + 1) / 2, prob_test.data)
        d1_test = sum(abs(imc.coef_W_).max(axis=1) > 0)
        d2_test = sum(abs(imc.coef_H_).max(axis=1) > 0)

        # run the k-fold CV
        # splt = ShuffleSplit(**par_dtst, random_state=random_state)
        splt = KFold(par_dtst["n_splits"], shuffle=True, random_state=random_state)
        for cv, (ind_train, ind_valid) in enumerate(splt.split(ind_train_all)):

            # prepare the train and test indices
            ind_train, ind_valid = ind_train_all[ind_train], ind_train_all[ind_valid]
            Y_train = get_submatrix(Y, ind_train)
            Y_valid = get_submatrix(Y, ind_valid)

            Y_train[Y_train == 0] = -1

            # fit the model
            imc = SparseGroupIMCClassifier(
                par_mdl["rank"],
                n_threads=-1,
                random_state=42,
                C_lasso=C_lasso,
                C_group=C_group,
                C_ridge=C_ridge,
            )
            imc.fit(U, V, Y_train)

            # compute the class probabilities
            prob_full = imc.predict_proba(U, V)  # uses own copies of W, H
            prob_valid = get_submatrix(prob_full, ind_valid)
            # scores_valid = mc_get_scores(Y_valid, prob_valid)
            scores_valid = get_metrics((Y_valid.data + 1) / 2, prob_valid.data)
            d1_valid = sum(abs(imc.coef_W_).max(axis=1) > 0)
            d2_valid = sum(abs(imc.coef_H_).max(axis=1) > 0)

            # record the results
            results.append(
                {
                    "train_size": par_dtst["train_size"],
                    "C_group": par_mdl["C_group"],
                    "cv": cv,
                    "rank": par_mdl["rank"],
                    "val_score": scores_valid,
                    "val_d1": d1_valid,
                    "val_d2": d2_valid,
                    "test_score": scores_test,
                    "test_d1": d1_test,
                    "test_d2": d2_test,
                }
            )
        # end for
    # end for
# end for
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]/Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
#  38%|███▊      | 3/8 [11:14:22<18:26:49, 13281.84s/it]/Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/numpy/core/_methods.py:48: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# 100%|██████████| 8/8 [31:01:52<00:00, 13964.12s/it]

# %%
# Save the results in a pickle
with gzip.open(filename_output, "wb+", 4) as fout:
    pickle.dump(results, fout)

# %% [markdown]
# ---

# %%
results
# Out:
# [{'train_size': 0.1,
#   'C_group': 1.0,
#   'cv': 0,
#   'rank': 50,
#   'val_score': [0.13175418990870863,
#    0.6020532533283329,
#    0.037460978147762745,
#    0.8281627345346461,
#    0.36,
#    0.8325520345021564,
#    0.019758507135016465],
#   'val_d1': 327,
#   'val_d2': 304,
#   'test_score': [0.12014916169295828,
#    0.6254622217868699,
#    0.031885818402672336,
#    0.7630884702560101,
#    0.42857142857142855,
#    0.7661616919154042,
#    0.016558902381327865],
#   'test_d1': 295,
#   'test_d2': 380},
#  {'train_size': 0.1,
#   'C_group': 1.0,
#   'cv': 1,
#   'rank': 50,
#   'val_score': [0

#  {'train_size': 0.1,
#   'C_group': 1.0,
#   'cv': 3,
#   'rank': 50,
#   'val_score': [0.14761865047853345,
#    0.6399101601962764,
#    0.03753351206434316,
#    0.7331846897064288,
#    0.5384615384615384,
#    0.7350844277673546,
#    0.019444444444444445],
#   'val_d1': 234,
#   'val_d2': 357,
#   'test_score': [0.1197728684271642,
#    0.6116854871542137,
#    0.03225306249030858,
#    0.7681046334485193,
#    0.42448979591836733,
#    0.7712614369281536,
#    0.016763378465506126],
#   'test_d1': 298,
#   'test_d2': 361},
#  {'train_size': 0.1,
#   'C_group': 1.0,
#   'cv': 4,
#   'rank': 50,
#   'val_score': [0.11330037850217936,
#    0.633798651184142,
#    0.04035874439461883,
#    0.7614269788182831,
#    0.4426229508196721,
#    0.7650817515504604,
#    0.021143304620203602],
#   'val_d1': 180,
#   'val_d2': 279,
#   'test_score': [0.1197728684271642,
#    0.6116854871542137,
#    0.03225306249030858,
#    0.7681046334485193,
#    0.42448979591836733,
#    0.7712614369281536,
#    0.016763378465506126],
#   'test_d1': 298,
#   'test_d2': 361},
#  {'train_size': 0.1,
#   'C_group': 1.0,
#   'cv': 0,
#   'rank': 50,
#   'val_score': [0.09988456737808946,
#    0.5318693180294457,
#    0.028925619834710745,
#    0.8253761842838566,
#    0.25,
#    0.831424816970152,
#    0.015350877192982455],
#   'val_d1': 168,
#   'val_d2': 323,
#   'test_score': [0.12204521455073553,
#    0.6249265342855306,
#    0.0312960235640648,
#    0.8044811057853082,
#    0.3469387755102041,
#    0.8086845657717114,
#    0.016387121650279547],
#   'test_d1': 211,
#   'test_d2': 375},
#  {'train_size': 0.1,
#   'C_group': 1.0,
#   'cv': 1,
#   'rank': 50,
#   'val_score': [0.14333393601092145,
#    0.6935486622986622,
#    0.045454545454545456,
#    0.8049414824447334,
#    0.45454545454545453,
#    0.8085585585585585,
#    0.023923444976076555],
#   'val_d1': 196,
#   'val_d2': 320,
#   'test_score': [0.12204521455073553,
#    0.6249265342855306,
#    0.0312960235640648,
#    0.8044811057853082,
#    0.3469387755102041,
#    0.8086845657717114,
#    0.016387121650279547],
#   'test_d1': 211,
#   'test_d2': 375},
#  {'train_size': 0.1,
#   'C_group': 1.0,
#   'cv': 2,
#   'rank': 50,
#   'val_score': [0.1151309893024441,
#    0.6096269216347957,
#    0.031865042174320526,
#    0.8080639167595689,
#    0.3541666666666667,
#    0.81214848143982,
#    0.016683022571148183],
#   'val_d1': 172,
#   'val_d2': 281,
#   'test_score': [0.12204521455073553,
#    0.6249265342855306,
#    0.0312960235640648,
#    0.8044811057853082,
#    0.3469387755102041,
#    0.8086845657717114,
#    0.016387121650279547],
#   'test_d1': 211,
#   'test_d2': 375},
#  {'train_size': 0.1,
#   'C_group': 1.0,
#   'cv': 3,
#   'rank': 50,
#   'val_score': [0.10638112446157777,
#    0.6600600706161729,
#    0.03431372549019608,
#    0.853586027499071,
#    0.2916666666666667,
#    0.8586426696662918,
#    0.018229166666666668],
#   'val_d1': 240,
#   'val_d2': 364,
#   'test_score': [0.12204521455073553,
#    0.6249265342855306,
#    0.0312960235640648,
#    0.8044811057853082,
#    0.3469387755102041,
#    0.8086845657717114,
#    0.016387121650279547],
#   'test_d1': 211,
#   'test_d2': 375},
#  {'train_size': 0.1,
#   'C_group': 1.0,
#   'cv': 4,
#   'rank': 50,
#   'val_score': [0.1365358799593036,
#    0.6268511654723664,
#    0.037069726390114736,
#    0.7972872538089929,
#    0.3684210526315789,
#    0.8018779342723005,
#    0.019516728624535316],
#   'val_d1': 179,
#   'val_d2': 310,
#   'test_score': [0.12204521455073553,
#    0.6249265342855306,
#    0.0312960235640648,
#    0.8044811057853082,
#    0.3469387755102041,
#    0.8086845657717114,
#    0.016387121650279547],
#   'test_d1': 211,
#   'test_d2': 375},
#  {'train_size': 0.1,
#   'C_group': 1.0,
#   'cv': 0,
#   'rank': 50,
#   'val_score': [0

#  {'train_size': 0.1,
#   'C_group': 1.0,
#   'cv': 2,
#   'rank': 50,
#   'val_score': [0.11726472515859651,
#    0.6572967441569804,
#    0.03904923599320883,
#    0.7896692679301375,
#    0.4791666666666667,
#    0.7924634420697413,
#    0.020353982300884955],
#   'val_d1': 296,
#   'val_d2': 745,
#   'test_score': [0.1190704678506731,
#    0.6495071674987679,
#    0.037333333333333336,
#    0.8256233047226248,
#    0.37142857142857144,
#    0.82979601019949,
#    0.019654427645788338],
#   'test_d1': 381,
#   'test_d2': 765},
#  {'train_size': 0.1,
#   'C_group': 1.0,
#   'cv': 3,
#   'rank': 50,
#   'val_score': [0.14744382030530512,
#    0.6180430191764025,
#    0.037037037037037035,
#    0.855072463768116,
#    0.3409090909090909,
#    0.8593106032221806,
#    0.0195822454308094],
#   'val_d1': 537,
#   'val_d2': 398,
#   'test_score': [0.1190704678506731,
#    0.6495071674987679,
#    0.037333333333333336,
#    0.8256233047226248,
#    0.37142857142857144,
#    0.82979601019949,
#    0.019654427645788338],
#   'test_d1': 381,
#   'test_d2': 765},
#  {'train_size': 0.1,
#   'C_group': 1.0,
#   'cv': 4,
#   'rank': 50,
#   'val_score': [0.14708004173458902,
#    0.6958560670167153,
#    0.04252199413489736,
#    0.7573392790784095,
#    0.5471698113207547,
#    0.759429536498405,
#    0.02212051868802441],
#   'val_d1': 537,
#   'val_d2': 419,
#   'test_score': [0.1190704678506731,
#    0.6495071674987679,
#    0.037333333333333336,
#    0.8256233047226248,
#    0.37142857142857144,
#    0.82979601019949,
#    0.019654427645788338],
#   'test_d1': 381,
#   'test_d2': 765},
#  {'train_size': 0.1,
#   'C_group': 1.0,
#   'cv': 0,
#   'rank': 50,
#   'val_score': [0.1260482826080808,
#    0.6069021399562637,
#    0.036756756756756756,
#    0.8344789151031023,
#    0.3541666666666667,
#    0.8388003748828491,
#    0.019384264538198404],
#   'val_d1': 383,
#   'val_d2': 377,
#   'test_score': [0.1276388662525914,
#    0.6615654931539137,
#    0.03756906077348066,
#    0.8058187493033107,
#    0.4163265306122449,
#    0.8093970301484926,
#    0.019672131147540985],
#   'test_d1': 455,
#   'test_d2': 693},
#  {'train_size': 0.1,
#   'C_group': 1.0,
#   'cv': 1,
#   'rank': 50,
#   'val_score': [0.15013683271309294,
#    0.7056173851921275,
#    0.04601479046836483,
#    0.7843210105888909,
#    0.5833333333333334,
#    0.7861293345829429,
#    0.023952095808383235],
#   'val_d1': 527,
#   'val_d2': 428,
#   'test_score': [0.1276388662525914,
#    0.6615654931539137,
#    0.03756906077348066,
#    0.8058187493033107,
#    0.4163265306122449,
#    0.8093970301484926,
#    0.019672131147540985],
#   'test_d1': 455,
#   'test_d2': 693},
#  {'train_size': 0.1,
#   'C_group': 1.0,
#   'cv': 2,
#   'rank': 50,
#   'val_score': [0.09739714398651964,
#    0.6489162773884996,
#    0.04231830726770929,
#    0.806577480490524,
#    0.42592592592592593,
#    0.8104354354354354,
#    0.022265246853823813],
#   'val_d1': 483,
#   'val_d2': 401,
#   'test_score': [0.1276388662525914,
#    0.6615654931539137,
#    0.03756906077348066,
#    0.8058187493033107,
#    0.4163265306122449,
#    0.8093970301484926,
#    0.019672131147540985],
#   'test_d1': 455,
#   'test_d2': 693},
#  {'train_size': 0.1,
#   'C_group': 1.0,
#   'cv': 3,
#   'rank': 50,
#   'val_score': [0.11875711740451729,
#    0.6716807642058229,
#    0.04499274310595065,
#    0.7554812337421033,
#    0.5849056603773585,
#    0.7571777068868456,
#    0.02339622641509434],
#   'val_d1': 498,
#   'val_d2': 428,
#   'test_score': [0.1276388662525914,
#    0.6615654931539137,
#    0.03756906077348066,
#    0.8058187493033107,
#    0.4163265306122449,
#    0.8093970301484926,
#    0.019672131147540985],
#   'test_d1': 455,
#   'test_d2': 693},
#  {'train_size': 0.1,
#   'C_group': 1.0,
#   'cv': 4,
#   'rank': 50,
#   'val_score': [0

#  {'train_size': 0.1,
#   'C_group': 1.0,
#   'cv': 3,
#   'rank': 50,
#   'val_score': [0.11205386919489407,
#    0.5924228202809018,
#    0.030915576694411414,
#    0.8485693050910442,
#    0.23636363636363636,
#    0.8548901820912334,
#    0.01653944020356234],
#   'val_d1': 506,
#   'val_d2': 381,
#   'test_score': [0.13977132264291958,
#    0.6570528616426322,
#    0.03794346423828496,
#    0.811578047783599,
#    0.40816326530612246,
#    0.8152842357882106,
#    0.019896538002387585],
#   'test_d1': 613,
#   'test_d2': 395},
#  {'train_size': 0.1,
#   'C_group': 1.0,
#   'cv': 4,
#   'rank': 50,
#   'val_score': [0.18810683975126474,
#    0.6727774570645115,
#    0.04523107177974434,
#    0.8195837978446674,
#    0.4423076923076923,
#    0.823264540337711,
#    0.02383419689119171],
#   'val_d1': 374,
#   'val_d2': 734,
#   'test_score': [0.13977132264291958,
#    0.6570528616426322,
#    0.03794346423828496,
#    0.811578047783599,
#    0.40816326530612246,
#    0.8152842357882106,
#    0.019896538002387585],
#   'test_d1': 613,
#   'test_d2': 395},
#  {'train_size': 0.1,
#   'C_group': 0.01,
#   'cv': 0,
#   'rank': 50,
#   'val_score': [0.12752775647314912,
#    0.6745159120676838,
#    0.039525691699604744,
#    0.819431543748839,
#    0.37735849056603776,
#    0.823827392120075,
#    0.020855057351407715],
#   'val_d1': 653,
#   'val_d2': 551,
#   'test_score': [0.12836141065595424,
#    0.6301041835663319,
#    0.03419147224456959,
#    0.8215732174042284,
#    0.3469387755102041,
#    0.8259337033148343,
#    0.017981806642690924],
#   'test_d1': 718,
#   'test_d2': 557},
#  {'train_size': 0.1,
#   'C_group': 0.01,
#   'cv': 1,
#   'rank': 50,
#   'val_score': [0.12254245474352793,
#    0.6343071441965122,
#    0.038267875125881166,
#    0.8225896340330671,
#    0.38,
#    0.8267391711981998,
#    0.02014846235418876],
#   'val_d1': 609,
#   'val_d2': 509,
#   'test_score': [0.12836141065595424,
#    0.6301041835663319,
#    0.03419147224456959,
#    0.8215732174042284,
#    0.3469387755102041,
#    0.8259337033148343,
#    0.017981806642690924],
#   'test_d1': 718,
#   'test_d2': 557},
#  {'train_size': 0.1,
#   'C_group': 0.01,
#   'cv': 2,
#   'rank': 50,
#   'val_score': [0.14536737521777732,
#    0.6453482265584685,
#    0.0354924578527063,
#    0.7980304719435154,
#    0.4878048780487805,
#    0.800411907882419,
#    0.01841620626151013],
#   'val_d1': 663,
#   'val_d2': 522,
#   'test_score': [0.12836141065595424,
#    0.6301041835663319,
#    0.03419147224456959,
#    0.8215732174042284,
#    0.3469387755102041,
#    0.8259337033148343,
#    0.017981806642690924],
#   'test_d1': 718,
#   'test_d2': 557},
#  {'train_size': 0.1,
#   'C_group': 0.01,
#   'cv': 3,
#   'rank': 50,
#   'val_score': [0.1206728663952849,
#    0.6453652911621777,
#    0.04742268041237113,
#    0.8283166109253066,
#    0.40350877192982454,
#    0.8328638497652582,
#    0.025191675794085433],
#   'val_d1': 542,
#   'val_d2': 560,
#   'test_score': [0.12836141065595424,
#    0.6301041835663319,
#    0.03419147224456959,
#    0.8215732174042284,
#    0.3469387755102041,
#    0.8259337033148343,
#    0.017981806642690924],
#   'test_d1': 718,
#   'test_d2': 557},
#  {'train_size': 0.1,
#   'C_group': 0.01,
#   'cv': 4,
#   'rank': 50,
#   'val_score': [0.12019004836926314,
#    0.6798419562096947,
#    0.045414847161572056,
#    0.7969156447417317,
#    0.4126984126984127,
#    0.8014664410603497,
#    0.024029574861367836],
#   'val_d1': 633,
#   'val_d2': 508,
#   'test_score': [0.12836141065595424,
#    0.6301041835663319,
#    0.03419147224456959,
#    0.8215732174042284,
#    0.3469387755102041,
#    0.8259337033148343,
#    0.017981806642690924],
#   'test_d1': 718,
#   'test_d2': 557},
#  {'train_size': 0.1,
#   'C_group': 0.01,
#   'cv': 0,
#   'rank': 50,
#   'val_score': [0.1186363909796102,
#    0.6617682639534439,
#    0.05394990366088632,
#    0.817573843581646,
#    0.4745762711864407,
#    0.8213749060856499,
#    0.028600612870275793],
#   'val_d1': 454,
#   'val_d2': 418,
#   'test_score': [0.12931939784068966,
#    0.6556726245320388,
#    0.03559870550161812,
#    0.822836547393453,
#    0.35918367346938773,
#    0.8270961451927403,
#    0.018727388806128963],
#   'test_d1': 399,
#   'test_d2': 490},
#  {'train_size': 0.1,
#   'C_group': 0.01,
#   'cv': 1,
#   'rank': 50,
#   'val_score': [0.13918635099995758,
#    0.6114451406969389,
#    0.03278688524590164,
#    0.846553966189857,
#    0.27450980392156865,
#    0.8520255063765941,
#    0.017434620174346202],
#   'val_d1': 402,
#   'val_d2': 523,
#   'test_score': [0.12931939784068966,
#    0.6556726245320388,
#    0.03559870550161812,
#    0.822836547393453,
#    0.35918367346938773,
#    0.8270961451927403,
#    0.018727388806128963],
#   'test_d1': 399,
#   'test_d2': 490},
#  {'train_size': 0.1,
#   'C_group': 0.01,
#   'cv': 2,
#   'rank': 50,
#   'val_score': [0.10290876337348069,
#    0.6320363102575607,
#    0.024350649350649352,
#    0.7766629505759941,
#    0.3488372093023256,
#    0.7801086345757633,
#    0.012615643397813289],
#   'val_d1': 420,
#   'val_d2': 517,
#   'test_score': [0.12931939784068966,
#    0.6556726245320388,
#    0.03559870550161812,
#    0.822836547393453,
#    0.35918367346938773,
#    0.8270961451927403,
#    0.018727388806128963],
#   'test_d1': 399,
#   'test_d2': 490},
#  {'train_size': 0.1,
#   'C_group': 0.01,
#   'cv': 3,
#   'rank': 50,
#   'val_score': [0.12212908567418716,
#    0.6559225586217308,
#    0.04124748490945674,
#    0.6458565589000371,
#    0.6721311475409836,
#    0.6455553467393347,
#    0.02127659574468085],
#   'val_d1': 379,
#   'val_d2': 612,
#   'test_score': [0.12931939784068966,
#    0.6556726245320388,
#    0.03559870550161812,
#    0.822836547393453,
#    0.35918367346938773,
#    0.8270961451927403,
#    0.018727388806128963],
#   'test_d1': 399,
#   'test_d2': 490},
#  {'train_size': 0.1,
#   'C_group': 0.01,
#   'cv': 4,
#   'rank': 50,
#   'val_score': [0.16405125092211686,
#    0.6811759189797449,
#    0.04460093896713615,
#    0.8487551096246748,
#    0.38,
#    0.8531507876969242,
#    0.02369077306733167],
#   'val_d1': 308,
#   'val_d2': 692,
#   'test_score': [0.12931939784068966,
#    0.6556726245320388,
#    0.03559870550161812,
#    0.822836547393453,
#    0.35918367346938773,
#    0.8270961451927403,
#    0.018727388806128963],
#   'test_d1': 399,
#   'test_d2': 490},
#  {'train_size': 0.1,
#   'C_group': 0.01,
#   'cv': 0,
#   'rank': 50,
#   'val_score': [0.12480341133009563,
#    0.6452221596713997,
#    0.03648068669527897,
#    0.8331785249860673,
#    0.3148148148148148,
#    0.8384312253706137,
#    0.0193621867881549],
#   'val_d1': 352,
#   'val_d2': 471,
#   'test_score': [0.12741065694069262,
#    0.6605114897316359,
#    0.03638747746271103,
#    0.7815553821573218,
#    0.4530612244897959,
#    0.7845732713364332,
#    0.018954918032786885],
#   'test_d1': 318,
#   'test_d2': 733},
#  {'train_size': 0.1,
#   'C_group': 0.01,
#   'cv': 1,
#   'rank': 50,
#   'val_score': [0.08918152627498878,
#    0.5791282841526333,
#    0.026490066225165563,
#    0.7815344603381015,
#    0.36363636363636365,
#    0.7849784603858401,
#    0.013745704467353952],
#   'val_d1': 395,
#   'val_d2': 797,
#   'test_score': [0.12741065694069262,
#    0.6605114897316359,
#    0.03638747746271103,
#    0.7815553821573218,
#    0.4530612244897959,
#    0.7845732713364332,
#    0.018954918032786885],
#   'test_d1': 318,
#   'test_d2': 733},
#  {'train_size': 0.1,
#   'C_group': 0.01,
#   'cv': 2,
#   'rank': 50,
#   'val_score': [0

#   'test_d1': 1888,
#   'test_d2': 797},
#  {'train_size': 0.1,
#   'C_group': 0.0001,
#   'cv': 0,
#   'rank': 50,
#   'val_score': [0.11027137571289024,
#    0.6308789717440428,
#    0.03666666666666667,
#    0.7852498606724875,
#    0.38596491228070173,
#    0.7895230942546001,
#    0.019247594050743656],
#   'val_d1': 677,
#   'val_d2': 460,
#   'test_score': [0.12077253772068378,
#    0.6460815989812754,
#    0.035260352603526036,
#    0.8251402667855683,
#    0.3510204081632653,
#    0.8294960251987401,
#    0.018562486509820852],
#   'test_d1': 613,
#   'test_d2': 579},
#  {'train_size': 0.1,
#   'C_group': 0.0001,
#   'cv': 1,
#   'rank': 50,
#   'val_score': [0.15653960678862688,
#    0.6398280016738093,
#    0.03671970624235006,
#    0.8537989968419097,
#    0.28846153846153844,
#    0.859313449634215,
#    0.0196078431372549],
#   'val_d1': 606,
#   'val_d2': 503,
#   'test_score': [0.12077253772068378,
#    0.6460815989812754,
#    0.035260352603526036,
#    0.8251402667855683,
#    0.3510204081632653,
#    0.8294960251987401,
#    0.018562486509820852],
#   'test_d1': 613,
#   'test_d2': 579},
#  {'train_size': 0.1,
#   'C_group': 0.0001,
#   'cv': 2,
#   'rank': 50,
#   'val_score': [0.08092703268736443,
#    0.5643183761237338,
#    0.030911901081916538,
#    0.6505016722408027,
#    0.5172413793103449,
#    0.6519534184823441,
#    0.015932023366967606],
#   'val_d1': 724,
#   'val_d2': 502,
#   'test_score': [0.12077253772068378,
#    0.6460815989812754,
#    0.035260352603526036,
#    0.8251402667855683,
#    0.3510204081632653,
#    0.8294960251987401,
#    0.018562486509820852],
#   'test_d1': 613,
#   'test_d2': 579},
#  {'train_size': 0.1,
#   'C_group': 0.0001,
#   'cv': 3,
#   'rank': 50,
#   'val_score': [0.18596370584059765,
#    0.7020836459114779,
#    0.05370569280343716,
#    0.8363062058714232,
#    0.5,
#    0.8394598649662416,
#    0.028376844494892167],
#   'val_d1': 648,
#   'val_d2': 509,
#   'test_score': [0.12077253772068378,
#    0.6460815989812754,
#    0.035260352603526036,
#    0.8251402667855683,
#    0.3510204081632653,
#    0.8294960251987401,
#    0.018562486509820852],
#   'test_d1': 613,
#   'test_d2': 579},
#  {'train_size': 0.1,
#   'C_group': 0.0001,
#   'cv': 4,
#   'rank': 50,
#   'val_score': [0.11783041630220113,
#    0.6248738758499672,
#    0.034274193548387094,
#    0.8219992567818655,
#    0.3617021276595745,
#    0.8260543580131209,
#    0.01798941798941799],
#   'val_d1': 776,
#   'val_d2': 481,
#   'test_score': [0.12077253772068378,
#    0.6460815989812754,
#    0.035260352603526036,
#    0.8251402667855683,
#    0.3510204081632653,
#    0.8294960251987401,
#    0.018562486509820852],
#   'test_d1': 613,
#   'test_d2': 579},
#  {'train_size': 0.1,
#   'C_group': 0.0001,
#   'cv': 0,
#   'rank': 50,
#   'val_score': [0.14477994221004434,
#    0.6352565527382152,
#    0.042988741044012284,
#    0.8263050343674531,
#    0.3181818181818182,
#    0.8326123753996615,
#    0.02305159165751921],
#   'val_d1': 376,
#   'val_d2': 501,
#   'test_score': [0.12867265115341892,
#    0.64048741440479,
#    0.034340659340659344,
#    0.8432727678073794,
#    0.30612244897959184,
#    0.848207589620519,
#    0.01819063788503517],
#   'test_d1': 360,
#   'test_d2': 523},
#  {'train_size': 0.1,
#   'C_group': 0.0001,
#   'cv': 1,
#   'rank': 50,
#   'val_score': [0.11137415306923142,
#    0.6402647683277132,
#    0.032816773017319965,
#    0.8028980122608211,
#    0.4,
#    0.8062944923192207,
#    0.017110266159695818],
#   'val_d1': 363,
#   'val_d2': 413,
#   'test_score': [0.12867265115341892,
#    0.64048741440479,
#    0.034340659340659344,
#    0.8432727678073794,
#    0.30612244897959184,
#    0.848207589620519,
#    0.01819063788503517],
#   'test_d1': 360,
#   'test_d2': 523},
#  {'train_size': 0.1,
#   'C_group': 0.0001,
#   'cv': 2,
#   'rank': 50,
#   'val_score': [0.12130464630435067,
#    0.6407297757631027,
#    0.03825136612021858,
#    0.8037904124860646,
#    0.375,
#    0.8082989110026286,
#    0.02015355086372361],
#   'val_d1': 429,
#   'val_d2': 451,
# ...
#   'val_d2': 617,
#   'test_score': [0.17855733992930065,
#    0.7979255118876709,
#    0.066167290886392,
#    0.833240441422361,
#    0.6489795918367347,
#    0.8349332533373331,
#    0.03486077614558211],
#   'test_d1': 977,
#   'test_d2': 565},
#  {'train_size': 0.8,
#   'C_group': 1.0,
#   'cv': 3,
#   'rank': 50,
#   'val_score': [0.1664889123539359,
#    0.7878833459771016,
#    0.06403269754768393,
#    0.8404514735595346,
#    0.6072351421188631,
#    0.8425665541807275,
#    0.033798360419962606],
#   'val_d1': 1107,
#   'val_d2': 786,
#   'test_score': [0.17855733992930065,
#    0.7979255118876709,
#    0.066167290886392,
#    0.833240441422361,
#    0.6489795918367347,
#    0.8349332533373331,
#    0.03486077614558211],
#   'test_d1': 977,
#   'test_d2': 565},
#  {'train_size': 0.8,
#   'C_group': 1.0,
#   'cv': 4,
#   'rank': 50,
#   'val_score': [0.16536157135323196,
#    0.7686190994536536,
#    0.05904761904761905,
#    0.8164379107735897,
#    0.6408268733850129,
#    0.8180305586801649,
#    0.030949706726569326],
#   'val_d1': 862,
#   'val_d2': 493,
#   'test_score': [0.17855733992930065,
#    0.7979255118876709,
#    0.066167290886392,
#    0.833240441422361,
#    0.6489795918367347,
#    0.8349332533373331,
#    0.03486077614558211],
#   'test_d1': 977,
#   'test_d2': 565},
#  {'train_size': 0.8,
#   'C_group': 1.0,
#   'cv': 0,
#   'rank': 50,
#   'val_score': [0.14336920009780743,
#    0.7735303397168027,
#    0.06075180356916846,
#    0.8276590803529958,
#    0.6266318537859008,
#    0.8294631768868477,
#    0.03192338387869114],
#   'val_d1': 1094,
#   'val_d2': 797,
#   'test_score': [0.17831200687788906,
#    0.7980887435220074,
#    0.06687965921192758,
#    0.8372162152119793,
#    0.6408163265306123,
#    0.8390205489725514,
#    0.035280898876404496],
#   'test_d1': 1469,
#   'test_d2': 786},
#  {'train_size': 0.8,
#   'C_group': 1.0,
#   'cv': 1,
#   'rank': 50,
#   'val_score': [0.15600113740064994,
#    0.7820483026626046,
#    0.06515837104072399,
#    0.8320676281381361,
#    0.6176470588235294,
#    0.8341187779887927,
#    0.03439333970247031],
#   'val_d1': 1015,
#   'val_d2': 628,
#   'test_score': [0.17831200687788906,
#    0.7980887435220074,
#    0.06687965921192758,
#    0.8372162152119793,
#    0.6408163265306123,
#    0.8390205489725514,
#    0.035280898876404496],
#   'test_d1': 1469,
#   'test_d2': 786},
#  {'train_size': 0.8,
#   'C_group': 1.0,
#   'cv': 2,
#   'rank': 50,
#   'val_score': [0.16637397396848047,
#    0.7800104975331668,
#    0.06133230253833269,
#    0.8308135349172067,
#    0.5891089108910891,
#    0.8331028015472981,
#    0.03235014272121789],
#   'val_d1': 1730,
#   'val_d2': 797,
#   'test_score': [0.17831200687788906,
#    0.7980887435220074,
#    0.06687965921192758,
#    0.8372162152119793,
#    0.6408163265306123,
#    0.8390205489725514,
#    0.035280898876404496],
#   'test_d1': 1469,
#   'test_d2': 786},
#  {'train_size': 0.8,
#   'C_group': 1.0,
#   'cv': 3,
#   'rank': 50,
#   'val_score': [0

#  {'train_size': 0.8,
#   'C_group': 1.0,
#   'cv': 0,
#   'rank': 50,
#   'val_score': [0.16941274294057454,
#    0.7756391388672416,
#    0.058440761203192144,
#    0.8218996748722712,
#    0.5935162094763092,
#    0.8240465083569704,
#    0.030733471074380167],
#   'val_d1': 1592,
#   'val_d2': 797,
#   'test_score': [0.18488298395135322,
#    0.8009260506362434,
#    0.06776341558950255,
#    0.8231338015085646,
#    0.7061224489795919,
#    0.824208789560522,
#    0.03558938490022629],
#   'test_d1': 1076,
#   'test_d2': 581},
#  {'train_size': 0.8,
#   'C_group': 1.0,
#   'cv': 1,
#   'rank': 50,
#   'val_score': [0.16902895398250306,
#    0.7842355842144668,
#    0.06654488517745302,
#    0.8338558721753873,
#    0.5795454545454546,
#    0.8364813815434431,
#    0.03529900332225914],
#   'val_d1': 1167,
#   'val_d2': 755,
#   'test_score': [0.18488298395135322,
#    0.8009260506362434,
#    0.06776341558950255,
#    0.8231338015085646,
#    0.7061224489795919,
#    0.824208789560522,
#    0.03558938490022629],
#   'test_d1': 1076,
#   'test_d2': 581},
#  {'train_size': 0.8,
#   'C_group': 1.0,
#   'cv': 2,
#   'rank': 50,
#   'val_score': [0.16698542556475654,
#    0.7905222011524417,
#    0.06678196088865239,
#    0.8370840010218538,
#    0.6419437340153452,
#    0.8388722227430393,
#    0.03522312657872579],
#   'val_d1': 1149,
#   'val_d2': 753,
#   'test_score': [0.18488298395135322,
#    0.8009260506362434,
#    0.06776341558950255,
#    0.8231338015085646,
#    0.7061224489795919,
#    0.824208789560522,
#    0.03558938490022629],
#   'test_d1': 1076,
#   'test_d2': 581},
#  {'train_size': 0.8,
#   'C_group': 1.0,
#   'cv': 3,
#   'rank': 50,
#   'val_score': [0.1610655876937499,
#    0.7988011827881221,
#    0.062000246032722355,
#    0.8229173924150585,
#    0.6829268292682927,
#    0.8241274303115483,
#    0.032474226804123714],
#   'val_d1': 989,
#   'val_d2': 587,
#   'test_score': [0.18488298395135322,
#    0.8009260506362434,
#    0.06776341558950255,
#    0.8231338015085646,
#    0.7061224489795919,
#    0.824208789560522,
#    0.03558938490022629],
#   'test_d1': 1076,
#   'test_d2': 581},
#  {'train_size': 0.8,
#   'C_group': 1.0,
#   'cv': 4,
#   'rank': 50,
#   'val_score': [0.162393504446328,
#    0.7931448784719553,
#    0.06894790602655772,
#    0.8306509672774565,
#    0.6323185011709602,
#    0.832637455432539,
#    0.03646185010128292],
#   'val_d1': 1096,
#   'val_d2': 737,
#   'test_score': [0.18488298395135322,
#    0.8009260506362434,
#    0.06776341558950255,
#    0.8231338015085646,
#    0.7061224489795919,
#    0.824208789560522,
#    0.03558938490022629],
#   'test_d1': 1076,
#   'test_d2': 581},
#  {'train_size': 0.8,
#   'C_group': 1.0,
#   'cv': 0,
#   'rank': 50,
#   'val_score': [0.16628913563619663,
#    0.7900093281233507,
#    0.06330049261083744,
#    0.8233627496516489,
#    0.6330049261083743,
#    0.8251746612275519,
#    0.03331604874254602],
#   'val_d1': 1130,
#   'val_d2': 709,
#   'test_score': [0.18080537782868136,
#    0.8025503316670899,
#    0.06775014685725475,
#    0.8230966447441757,
#    0.7061224489795919,
#    0.8241712914354282,
#    0.0355820649938297],
#   'test_d1': 1044,
#   'test_d2': 589},
#  {'train_size': 0.8,
#   'C_group': 1.0,
#   'cv': 1,
#   'rank': 50,
#   'val_score': [0.14552813011345123,
#    0.7882760980502543,
#    0.0636668262326472,
#    0.8182958266564482,
#    0.6785714285714286,
#    0.8195795345348864,
#    0.03340030135610246],
#   'val_d1': 981,
#   'val_d2': 534,
#   'test_score': [0.18080537782868136,
#    0.8025503316670899,
#    0.06775014685725475,
#    0.8230966447441757,
#    0.7061224489795919,
#    0.8241712914354282,
#    0.0355820649938297],
#   'test_d1': 1044,
#   'test_d2': 589},
#  {'train_size': 0.8,
#   'C_group': 1.0,
#   'cv': 2,
#   'rank': 50,
#   'val_score': [0.16365578781742116,
#    0.7988212558230914,
#    0.07322175732217573,
#    0.8353886527787454,
#    0.6796116504854369,
#    0.8368935681290595,
#    0.038695411829740185],
#   'val_d1': 1112,
#   'val_d2': 620,
#   'test_score': [0.18080537782868136,
#    0.8025503316670899,
#    0.06775014685725475,
#    0.8230966447441757,
#    0.7061224489795919,
#    0.8241712914354282,
#    0.0355820649938297],
#   'test_d1': 1044,
#   'test_d2': 589},
#  {'train_size': 0.8,
#   'C_group': 1.0,
#   'cv': 3,
#   'rank': 50,
#   'val_score': [0.1735234227042606,
#    0.7840267399731994,
#    0.06229888016475737,
#    0.8308135349172067,
#    0.618925831202046,
#    0.832755226399175,
#    0.032800216860937925],
#   'val_d1': 1114,
#   'val_d2': 751,
#   'test_score': [0.18080537782868136,
#    0.8025503316670899,
#    0.06775014685725475,
#    0.8230966447441757,
#    0.7061224489795919,
#    0.8241712914354282,
#    0.0355820649938297],
#   'test_d1': 1044,
#   'test_d2': 589},
#  {'train_size': 0.8,
#   'C_group': 1.0,
#   'cv': 4,
#   'rank': 50,
#   'val_score': [0.14586847316904833,
#    0.7526223828083972,
#    0.05629326977641584,
#    0.8068928679254047,
#    0.5807962529274004,
#    0.8091574404203415,
#    0.029580152671755726],
#   'val_d1': 1888,
#   'val_d2': 797,
#   'test_score': [0.18080537782868136,
#    0.8025503316670899,
#    0.06775014685725475,
#    0.8230966447441757,
#    0.7061224489795919,
#    0.8241712914354282,
#    0.0355820649938297],
#   'test_d1': 1044,
#   'test_d2': 589},
#  {'train_size': 0.8,
#   'C_group': 0.01,
#   'cv': 0,
#   'rank': 50,
#   'val_score': [0.1544547283757141,
#    0.751911880295264,
#    0.05503971361449827,
#    0.8038318625174176,
#    0.5578231292517006,
#    0.806377437293226,
#    0.028947987761826312],
#   'val_d1': 823,
#   'val_d2': 567,
#   'test_score': [0.15201001460573815,
#    0.771077083900907,
#    0.05851279967492889,
#    0.8278155538215732,
#    0.5877551020408164,
#    0.8300209989500525,
#    0.030788967286722257],
#   'test_d1': 917,
#   'test_d2': 593},
#  {'train_size': 0.8,
#   'C_group': 0.01,
#   'cv': 1,
#   'rank': 50,
#   'val_score': [0.13565149794010642,
#    0.7579889181923809,
#    0.054995417048579284,
#    0.8084488724772986,
#    0.5633802816901409,
#    0.8108976614359769,
#    0.02890869669959046],
#   'val_d1': 898,
#   'val_d2': 607,
#   'test_score': [0.15201001460573815,
#    0.771077083900907,
#    0.05851279967492889,
#    0.8278155538215732,
#    0.5877551020408164,
#    0.8300209989500525,
#    0.030788967286722257],
#   'test_d1': 917,
#   'test_d2': 593},
#  {'train_size': 0.8,
#   'C_group': 0.01,
#   'cv': 2,
#   'rank': 50,
#   'val_score': [0.14073428210012662,
#    0.7616652690700484,
#    0.050349362926428276,
#    0.7853642676327829,
#    0.6330749354005168,
#    0.786745406824147,
#    0.026217228464419477],
#   'val_d1': 937,
#   'val_d2': 611,
#   'test_score': [0.15201001460573815,
#    0.771077083900907,
#    0.05851279967492889,
#    0.8278155538215732,
#    0.5877551020408164,
#    0.8300209989500525,
#    0.030788967286722257],
#   'test_d1': 917,
#   'test_d2': 593},
#  {'train_size': 0.8,
#   'C_group': 0.01,
#   'cv': 3,
#   'rank': 50,
#   'val_score': [0.13795571877791374,
#    0.7659413372223318,
#    0.04767685685906633,
#    0.7996005480851854,
#    0.6171428571428571,
#    0.8010957877730689,
#    0.024796234645850075],
#   'val_d1': 952,
#   'val_d2': 558,
#   'test_score': [0.15201001460573815,
#    0.771077083900907,
#    0.05851279967492889,
#    0.8278155538215732,
#    0.5877551020408164,
#    0.8300209989500525,
#    0.030788967286722257],
#   'test_d1': 917,
#   'test_d2': 593},
#  {'train_size': 0.8,
#   'C_group': 0.01,
#   'cv': 4,
#   'rank': 50,
#   'val_score': [0.14237776929246462,
#    0.7557723136939046,
#    0.057034220532319393,
#    0.8156947444204463,
#    0.5660377358490566,
#    0.818177553653102,
#    0.03003003003003003],
#   'val_d1': 960,
#   'val_d2': 601,
#   'test_score': [0.15201001460573815,
#    0.771077083900907,
#    0.05851279967492889,
#    0.8278155538215732,
#    0.5877551020408164,
#    0.8300209989500525,
#    0.030788967286722257],
#   'test_d1': 917,
#   'test_d2': 593},
#  {'train_size': 0.8,
#   'C_group': 0.01,
#   'cv': 0,
#   'rank': 50,
#   'val_score': [0.13991762596066182,
#    0.7547985819051628,
#    0.052108330476516966,
#    0.807361820715281,
#    0.5801526717557252,
#    0.8094546136358309,
#    0.027279253409906678],
#   'val_d1': 1888,
#   'val_d2': 797,
#   'test_score': [0.14056103850957025,
#    0.7573478724022983,
#    0.053437833986462416,
#    0.8025489540370825,
#    0.6122448979591837,
#    0.8042972851357432,
#    0.02793816353138387],
#   'test_d1': 1888,
#   'test_d2': 797},
#  {'train_size': 0.8,
#   'C_group': 0.01,
#   'cv': 1,
#   'rank': 50,
#   'val_score': [0.1411245842299551,
#    0.7637805621322582,
#    0.06436781609195402,
#    0.9905478529459578,
#    0.035,
#    0.9995077240441642,
#    0.4],
#   'val_d1': 1888,
#   'val_d2': 797,
#   'test_score': [0.14056103850957025,
#    0.7573478724022983,
#    0.053437833986462416,
#    0.8025489540370825,
#    0.6122448979591837,
#    0.8042972851357432,
#    0.02793816353138387],
#   'test_d1': 1888,
#   'test_d2': 797},
#  {'train_size': 0.8,
#   'C_group': 0.01,
#   'cv': 2,
#   'rank': 50,
#   'val_score': [0.05435648810434588,
#    0.5323764032114344,
#    0.02565016031350196,
#    0.9364825007547783,
#    0.08591885441527446,
#    0.9448405253283302,
#    0.01507537688442211],
#   'val_d1': 1888,
#   'val_d2': 797,
#   'test_score': [0.14056103850957025,
#    0.7573478724022983,
#    0.053437833986462416,
#    0.8025489540370825,
#    0.6122448979591837,
#    0.8042972851357432,
#    0.02793816353138387],
#   'test_d1': 1888,
#   'test_d2': 797},
#  {'train_size': 0.8,
#   'C_group': 0.01,
#   'cv': 3,
#   'rank': 50,
#   'val_score': [0.1252509099860602,
#    0.7432812671728928,
#    0.05603448275862069,
#    0.9898279105413502,
#    0.030303030303030304,
#    0.9994839315036359,
#    0.37142857142857144],
#   'val_d1': 1888,
#   'val_d2': 797,
#   'test_score': [0.14056103850957025,
#    0.7573478724022983,
#    0.053437833986462416,
#    0.8025489540370825,
#    0.6122448979591837,
#    0.8042972851357432,
#    0.02793816353138387],
#   'test_d1': 1888,
#   'test_d2': 797},
#  {'train_size': 0.8,
#   'C_group': 0.01,
#   'cv': 4,
#   'rank': 50,
#   'val_score': [0.07321432885642945,
#    0.7510061424008045,
#    0.07423580786026202,
#    0.9901530458208505,
#    0.04392764857881137,
#    0.998734533183352,
#    0.23943661971830985],
#   'val_d1': 1888,
#   'val_d2': 797,
#   'test_score': [0.14056103850957025,
#    0.7573478724022983,
#    0.053437833986462416,
#    0.8025489540370825,
#    0.6122448979591837,
#    0.8042972851357432,
#    0.02793816353138387],
#   'test_d1': 1888,
#   'test_d2': 797},
#  ...]

# %% [markdown]
# Test on the one simple case without side information

# %%
dvlp_size, test_size = 0.9, 0.1

ind_dvlp, ind_test = next(
    mc_split(
        Y,
        n_splits=1,
        random_state=random_state,
        train_size=dvlp_size,
        test_size=test_size,
    )
)

Y_test = get_submatrix(Y, ind_test)

# %%
U = np.eye(Y.shape[0])
V = np.eye(Y.shape[1])

# %%
U, V, _ = load(filename_input)

# %%
from sklearn.model_selection import ParameterGrid

grid_dataset = ParameterGrid(
    {
        # "train_size": np.arange(0.1, 0.9, 0.1),
        "train_size": [0.81],
        "n_splits": [2],
    }
)

grid_model = ParameterGrid(
    {
        # "C_lasso": [1.0, 1e-2, 1e-4],
        "C_lasso": [0.1],
        # "C_group": [1.0, 1e-2, 1e-4],
        "C_group": [0.1],
        # "C_ridge": [1.0, 1e-2, 1e-4],
        "C_ridge": [1.0],
        "rank": [40],
    }
)

# %%
results = []

for par_mdl in grid_model:  # tqdm.tqdm(, desc="cv %02d" % (cv,))
    # set up the model
    C_lasso, C_group, C_ridge = (
        par_mdl["C_lasso"],
        par_mdl["C_group"],
        par_mdl["C_ridge"],
    )
    imc = SparseGroupIMCClassifier(
        par_mdl["rank"],
        n_threads=-1,
        random_state=42,
        C_lasso=C_lasso,
        C_group=C_group,
        C_ridge=C_ridge,
    )

# fit on the whole development dataset
Y_train = get_submatrix(Y, ind_train_all)
Y_train[Y_train == -1] = 0

imc.fit(U, V, Y_train)

# get the score
prob_full = imc.predict_proba(U, V)
prob_test = get_submatrix(prob_full, ind_test)
scores_test = get_metrics((Y_test.data + 1) / 2, prob_test.data)
d1_test = sum(abs(imc.coef_W_).max(axis=1) > 0)
d2_test = sum(abs(imc.coef_H_).max(axis=1) > 0)

results.append(
    {
        "train_size": par_dtst["train_size"],
        "C_lasso": par_mdl["C_lasso"],
        "C_group": par_mdl["C_group"],
        "C_ridge": par_mdl["C_ridge"],
        "cv": cv,
        "rank": par_mdl["rank"],
        "test_score": scores_test,
        "test_d1": d1_test,
        "test_d2": d2_test,
    }
)

# %%
results
# Out:
# [{'train_size': 0.81,
#   'C_lasso': 0.1,
#   'C_group': 0.1,
#   'C_ridge': 1.0,
#   'cv': 1,
#   'rank': 40,
#   'test_score': [0.010938613353015447,
#    0.555615872182425,
#    0.026223776223776224,
#    0.627466280236317,
#    0.54,
#    0.6282863893785395,
#    0.013438184351980888],
#   'test_d1': 322,
#   'test_d2': 173}]

# %%
plt.imshow(imc.coef_W_, aspect="auto")
# print(
#     scores_test,
#     "\n"
#     f"rank: {imc.rank}, C_lasso: {imc.C_lasso}, C_group: {imc.C_group}, C_ridge: {imc.C_ridge}\n"
#     f"d1: {d1_test}/{X.shape[1]}, d2: {d2_test}/{Y.shape[1]}",
# )

# %%
plt.matshow(U.toarray())
plt.matshow(V.toarray())
