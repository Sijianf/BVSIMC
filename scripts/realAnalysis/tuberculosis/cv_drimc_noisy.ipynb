# %% [markdown]
# # Run DRIMC

# %%
import os
import time
import gzip
import pickle
import warnings

# %matplotlib inline
import matplotlib.pyplot as plt

import numpy as np

from tqdm import TqdmSynchronisationWarning
warnings.simplefilter("ignore", TqdmSynchronisationWarning)

# %%
PATH_ROOT = "/Users/sijianfan/Documents/projects/BiSSGL"
PATH_DATA = os.path.join(PATH_ROOT, "datasets/realAnalysis/tuberculosis/cv_data")

PATH_OUTPUT = os.path.join(PATH_ROOT, "outputs/realAnalysis/tuberculosis/noisy")
if not os.path.isdir(PATH_OUTPUT):
    os.makedirs(PATH_OUTPUT)

PATH_ARCHIVE = os.path.join(PATH_OUTPUT, "archived")
if not os.path.isdir(PATH_ARCHIVE):
    os.makedirs(PATH_ARCHIVE)

# %%
filename_staged = os.path.join(PATH_DATA, "staged_dataset.gz")

filenames = {"input": "staged_dataset.gz", "output": "results_drimc.gz"}

# %%
filename_input = os.path.join(PATH_DATA, filenames["input"])

filename_output = os.path.join(PATH_OUTPUT, filenames["output"])

if os.path.exists(filename_output):
    mdttm = time.strftime("%Y%m%d_%H%M%S")
    os.rename(
        filename_output,
        os.path.join(PATH_ARCHIVE, "%s%s" % (mdttm, filenames["output"])),
    )

# %%
from sgimc.utils import mc_split

# %%
from sgimc.utils import get_submatrix

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_auc_score
from sgimc.utils import sparsify_with_mask


def mc_get_scores(R_true, R_prob):
    R_pred = np.where(R_prob.data > 0.5, 1, -1)

    # compute the confusion matrix for ±1 labels (`-1` is negative)
    ii, jj = ((R_pred + 1) // 2).astype(int), ((R_true.data + 1) // 2).astype(int)
    cnfsn = confusion_matrix(y_true=jj, y_pred=ii)

    return {
        "tn": cnfsn[0, 0],
        "fn": cnfsn[1, 0],
        "fp": cnfsn[0, 1],
        "tp": cnfsn[1, 1],
        "auc": roc_auc_score(R_true.data, R_prob.data),
    }

# %%
random_state = np.random.RandomState(0x0BADCAFE)

# %% [markdown]
# ## Import model

# %%
import rpy2.robjects as robjects

r = robjects.r

DRIMC_path = "/Users/sijianfan/Documents/projects/BiSSGL/scripts/methods/DRIMC"
r(f'setwd("{DRIMC_path}")')
print(r("getwd()"))
# Out:
# [1] "/Users/sijianfan/Documents/projects/BiSSGL/scripts/methods/DRIMC"

# %%
pkgs = ["matrixcalc", "data.table", "Rcpp", "ROCR", "Bolstad2", "MESS"]
rPkgs = [r(f'require("{pkg}", character.only=TRUE)') for pkg in pkgs]
# Out:
# R callback write-console: Loading required package: matrixcalc
#
# R callback write-console: Loading required package: data.table
#
# R callback write-console: data.table 1.17.8 using 6 threads (see ?getDTthreads).
# R callback write-console: Latest news: r-datatable.com
#
# R callback write-console: Loading required package: Rcpp
#
# R callback write-console: Loading required package: ROCR
#
# R callback write-console: Loading required package: Bolstad2
#
# R callback write-console: Loading required package: MESS

# %%
rSourceNames = [
    "doCrossValidationByPairwise.R",
    "doCrossValidationByRow.R",
    "constrNeig.R",
    "inferZeros.R",
    "calcLogLik.R",
    "calcDeriv.R",
    "updateUV.R",
    "calcPredScore.R",
    "calcAUPR.R",
]
rSN = [r(f'source("{r_file}")') for r_file in rSourceNames]

# %%
r("library(Rcpp)")
cppSourceNames = [
    "fastKF2.cpp",
    "fastKF4.cpp",
    "fastKgipMat.cpp",
    "log1pexp.cpp",
    "sigmoid.cpp",
]
cppSN = [r(f'sourceCpp("{cpp_file}")') for cpp_file in cppSourceNames]

# %%
updateUV = r["updateUV"]

# %% [markdown]
# ## Load data

# %%
from sgimc.utils import load, save

U, V, Y = load(filename_input)

Y = Y.astype(float)

# %% [markdown]
# ## Prepare similarity matrix

# %%
# Quick prepare of similarity matrix
from sklearn.metrics.pairwise import cosine_similarity

simD = cosine_similarity(U[:, :])
simT = cosine_similarity(V[:, :])

# %%
from sklearn.metrics import pairwise_distances

# Jaccard distance → convert to similarity
simD = 1 - pairwise_distances(U.toarray(), metric="jaccard")
simT = 1 - pairwise_distances(V.toarray(), metric="jaccard")
# Out:
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/sklearn/metrics/pairwise.py:2182: DataConversionWarning: Data was converted to boolean for metric jaccard
#   warnings.warn(msg, DataConversionWarning)

# %%
simD = np.eye(U.shape[0])
simT = np.eye(V.shape[0])

simD_Robj = r.matrix(
    robjects.FloatVector(simD.flatten()),
    byrow=True,
    nrow=simD.shape[0],
    ncol=simD.shape[0],
)
simT_Robj = r.matrix(
    robjects.FloatVector(simT.flatten()),
    byrow=True,
    nrow=simT.shape[0],
    ncol=simT.shape[0],
)

# %%
constrNeig = r["constrNeig"]

# %%
# Use default neighorhood size = 20
lap = constrNeig(simD_Robj, simT_Robj, K=5)
simD_Robj, simT_Robj = lap[2], lap[3]
simD, simT = np.array(simD), np.array(simT)

# %%
simD.shape, simT.shape
# Out:
# ((6949, 6949), (13, 13))

# %%
dvlp_size, test_size = 0.9, 0.1

ind_dvlp, ind_test = next(
    mc_split(
        Y,
        n_splits=1,
        random_state=random_state,
        train_size=dvlp_size,
        test_size=test_size,
    )
)

Y_test = get_submatrix(Y, ind_test)

# %%
from sklearn.model_selection import ParameterGrid

grid_dataset = ParameterGrid(
    {
        "train_size": np.arange(0.001, 0.2, 0.02),
        # "train_size": [0.2],
        "n_splits": [2],
    }
)

grid_model = ParameterGrid(
    {
        "lamU": [0.09],
        "lamV": [0.09],
        "cc": [1, 2, 3, 4, 5, 6, 8, 10],  # confidence parameter
        # "cc": [1],
        "iterpara": [0.09],  # learning rate
        "numLat": [200],  # rank
    }
)

# %%
from tqdm import tqdm
from sklearn.model_selection import ShuffleSplit, KFold
from sklearn.model_selection import train_test_split
from scipy.special import expit


results = []
for par_dtst in tqdm(grid_dataset):
    # prepare the train dataset: take the specified share from the beginnig of the index array
    ind_train_all, _ = train_test_split(
        ind_dvlp,
        shuffle=False,
        random_state=random_state,
        test_size=(1 - (par_dtst["train_size"] / dvlp_size)),
    )

    # Run the experiment: the model
    for par_mdl in grid_model:  # tqdm.tqdm(, desc="cv %02d" % (cv,))
        Y_train = get_submatrix(Y, ind_train_all)

        # Y_train[Y_train == 0] = 0.5
        Y_train[Y_train == -1] = 0

        Y_train_Robj = r.matrix(
            robjects.FloatVector(Y_train.toarray().flatten()),
            byrow=True,
            nrow=Y_train.shape[0],
            ncol=Y_train.shape[1],
        )

        # set up the model
        lamU, lamV, cc, iterpara, numLat = (
            par_mdl["lamU"],
            par_mdl["lamV"],
            par_mdl["cc"],
            par_mdl["iterpara"],
            par_mdl["numLat"],
        )

        out = updateUV(
            cc=cc,
            inMat=Y_train_Robj,
            Sd=simD_Robj,
            St=simT_Robj,
            lamU=lamU,
            lamV=lamV,
            numLat=numLat,
            initMethod="useSeed",
            thisSeed=123,
            iterpara=iterpara,
            maxIter=100,
        )

        # fit on the whole development dataset
        est_A, est_B = np.array(out[0]), np.array(out[1])

        # get the score
        prob_full = expit(simD @ est_A @ est_B.T @ simT.T)
        prob_test = get_submatrix(prob_full, ind_test)
        scores_test = mc_get_scores(Y_test, prob_test)
        d1_test = sum(abs(est_A).max(axis=1) > 0)
        d2_test = sum(abs(est_B).max(axis=1) > 0)

        # record the results
        results.append(
            {
                "train_size": par_dtst["train_size"],
                "lamU": par_mdl["lamU"],
                "lamV": par_mdl["lamV"],
                "cc": par_mdl["cc"],
                "iterpara": par_mdl["iterpara"],
                "numLat": par_mdl["numLat"],
                "test_score": scores_test["auc"],
                "test_d1": d1_test,
                "test_d2": d2_test,
            }
        )
# Out:
# 100%|██████████| 10/10 [31:47<00:00, 190.77s/it]

# %%
plt.plot(out[3]), results
# Out:
# ([<matplotlib.lines.Line2D at 0x12f567910>],
#  [{'train_size': 0.001,
#    'lamU': 0.09,
#    'lamV': 0.09,
#    'cc': 1,
#    'iterpara': 0.09,
#    'numLat': 200,
#    'test_score': 0.6155782933794616,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.001,
#    'lamU': 0.09,
#    'lamV': 0.09,
#    'cc': 2,
#    'iterpara': 0.09,
#    'numLat': 200,
#    'test_score': 0.6162397924816343,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.001,
#    'lamU': 0.09,
#    'lamV': 0.09,
#    'cc': 3,
#    'iterpara': 0.09,
#    'numLat': 200,
#    'test_score': 0.6168300499953562,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.001,
#    'lamU': 0.09,
#    'lamV': 0.09,
#    'cc': 4,
#    'iterpara': 0.09,
#    'numLat': 200,
#    'test_score': 0.6173183691773687,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.001,
#    'lamU': 0.09,
#    'lamV': 0.09,
#    'cc': 5,
#    'iterpara': 0.09,
#    'numLat': 200,
#    'test_score': 0.6176541475464633,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.001,
#    'lamU': 0.09,
#    'lamV': 0.09,
#    'cc': 6,
#    'iterpara': 0.09,
#    'numLat': 200,
#    'test_score': 0.618031466047647,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.001,
#    'lamU': 0.09,
#    'lamV': 0.09,
#    'cc': 8,
#    'iterpara': 0.09,
#    'numLat': 200,
#    'test_score': 0.6186254951748754,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.001,
#    'lamU': 0.09,
#    'lamV': 0.09,
#    'cc': 10,
#    'iterpara': 0.09,
#    'numLat': 200,
#    'test_score': 0.6190131856132013,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.021,
#    'lamU': 0.09,
#    'lamV': 0.09,
#    'cc': 1,
#    'iterpara': 0.09,
#    'numLat': 200,
#    'test_score': 0.7278034913930994,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.021,
#    'lamU': 0.09,
#    'lamV': 0.09,
#    'cc': 2,
#    'iterpara': 0.09,
#    'numLat': 200,
#    'test_score': 0.7319038114930807,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.021,
#    'lamU': 0.09,
#    'lamV': 0.09,
#    'cc': 3,
#    'iterpara': 0.09,
#    'numLat': 200,
#    'test_score': 0.7304061142464686,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.021,
#    'lamU': 0.09,
#    'lamV': 0.09,
#    'cc': 4,
#    'iterpara': 0.09,
#    'numLat': 200,
#    'test_score': 0.7305777750445221,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.021,
#    'lamU': 0.09,
#    'lamV': 0.09,
#    'cc': 5,
#    'iterpara': 0.09,
#    'numLat': 200,
#    'test_score': 0.730729530104626,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.021,
#    'lamU': 0.09,
#    'lamV': 0.09,
#    'cc': 6,
#    'iterpara': 0.09,
#    'numLat': 200,
#    'test_score': 0.730792233179167,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.021,
#    'lamU': 0.09,
#    'lamV': 0.09,
#    'cc': 8,
#    'iterpara': 0.09,
#    'numLat': 200,
#    'test_score': 0.7308799755767071,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.021,
#    'lamU': 0.09,
#    'lamV': 0.09,
#    'cc': 10,
#    'iterpara': 0.09,
#    'numLat': 200,
#    'test_score': 0.7305641553290829,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.041,
#    'lamU': 0.09,
#    'lamV': 0.09,
#    'cc': 1,
#    'iterpara': 0.09,
#    'numLat': 200,
#    'test_score': 0.7307078957104862,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.041,
#    'lamU': 0.09,
#    'lamV': 0.09,
#    'cc': 2,
#    'iterpara': 0.09,
#    'numLat': 200,
#    'test_score': 0.729426018570063,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.041,
#    'lamU': 0.09,
#    'lamV': 0.09,
#    'cc': 3,
#    'iterpara': 0.09,
#    'numLat': 200,
#    'test_score': 0.7294508483589789,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.041,
#    'lamU': 0.09,
#    'lamV': 0.09,
#    'cc': 4,
#    'iterpara': 0.09,
#    'numLat': 200,
#    'test_score': 0.7292755730979819,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.041,
#    'lamU': 0.09,
#    'lamV': 0.09,
#    'cc': 5,
#    'iterpara': 0.09,
#    'numLat': 200,
#    'test_score': 0.7289030738807226,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.041,
#    'lamU': 0.09,
#    'lamV': 0.09,
#    'cc': 6,
#    'iterpara': 0.09,
#    'numLat': 200,
#    'test_score': 0.7289032310312854,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.041,
#    'lamU': 0.09,
#    'lamV': 0.09,
#    'cc': 8,
#    'iterpara': 0.09,
#    'numLat': 200,
#    'test_score': 0.7287840585211933,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.041,
#    'lamU': 0.09,
#    'lamV': 0.09,
#    'cc': 10,
#    'iterpara': 0.09,
#    'numLat': 200,
#    'test_score': 0.7291181082340976,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.061,
#    'lamU': 0.09,
#    'lamV': 0.09,
#    'cc': 1,
#    'iterpara': 0.09,
#    'numLat': 200,
#    'test_score': 0.7285836391701549,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.061,
#    'lamU': 0.09,
#    'lamV': 0.09,
#    'cc': 2,
#    'iterpara': 0.09,
#    'numLat': 200,
#    'test_score': 0.7280874100764836,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.061,
#    'lamU': 0.09,
#    'lamV': 0.09,
#    'cc': 3,
#    'iterpara': 0.09,
#    'numLat': 200,
#    'test_score': 0.728723607938052,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.061,
#    'lamU': 0.09,
#    'lamV': 0.09,
#    'cc': 4,
#    'iterpara': 0.09,
#    'numLat': 200,
#    'test_score': 0.7291721680276866,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.061,
#    'lamU': 0.09,
#    'lamV': 0.09,
#    'cc': 5,
#    'iterpara': 0.09,
#    'numLat': 200,
#    'test_score': 0.7298293716811438,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.061,
#    'lamU': 0.09,
#    'lamV': 0.09,
#    'cc': 6,
#    'iterpara': 0.09,
#    'numLat': 200,
#    'test_score': 0.7305883565157477,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.061,
#    'lamU': 0.09,
#    'lamV': 0.09,
#    'cc': 8,
#    'iterpara': 0.09,
#    'numLat': 200,
#    'test_score': 0.7320515330220738,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.061,
#    'lamU': 0.09,
#    'lamV': 0.09,
#    'cc': 10,
#    'iterpara': 0.09,
#    'numLat': 200,
#    'test_score': 0.7328132941832868,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.081,
#    'lamU': 0.09,
#    'lamV': 0.09,
#    'cc': 1,
#    'iterpara': 0.09,
#    'numLat': 200,
#    'test_score': 0.735930480362649,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.081,
#    'lamU': 0.09,
#    'lamV': 0.09,
#    'cc': 2,
#    'iterpara': 0.09,
#    'numLat': 200,
#    'test_score': 0.7346761569542294,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.081,
#    'lamU': 0.09,
#    'lamV': 0.09,
#    'cc': 3,
#    'iterpara': 0.09,
#    'numLat': 200,
#    'test_score': 0.736303870099764,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.081,
#    'lamU': 0.09,
#    'lamV': 0.09,
#    'cc': 4,
#    'iterpara': 0.09,
#    'numLat': 200,
#    'test_score': 0.7371525355221822,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.081,
#    'lamU': 0.09,
#    'lamV': 0.09,
#    'cc': 5,
#    'iterpara': 0.09,
#    'numLat': 200,
#    'test_score': 0.7392787826363085,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.081,
#    'lamU': 0.09,
#    'lamV': 0.09,
#    'cc': 6,
#    'iterpara': 0.09,
#    'numLat': 200,
#    'test_score': 0.7415605564240453,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.081,
#    'lamU': 0.09,
#    'lamV': 0.09,
#    'cc': 8,
#    'iterpara': 0.09,
#    'numLat': 200,
#    'test_score': 0.7451116353071846,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.081,
#    'lamU': 0.09,
#    'lamV': 0.09,
#    'cc': 10,
#    'iterpara': 0.09,
#    'numLat': 200,
#    'test_score': 0.7483182925402776,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.101,
#    'lamU': 0.09,
#    'lamV': 0.09,
#    'cc': 1,
#    'iterpara': 0.09,
#    'numLat': 200,
#    'test_score': 0.7464938792736899,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.101,
#    'lamU': 0.09,
#    'lamV': 0.09,
#    'cc': 2,
#    'iterpara': 0.09,
#    'numLat': 200,
#    'test_score': 0.7470285054881953,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.101,
#    'lamU': 0.09,
#    'lamV': 0.09,
#    'cc': 3,
#    'iterpara': 0.09,
#    'numLat': 200,
#    'test_score': 0.7492204939210758,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.101,
#    'lamU': 0.09,
#    'lamV': 0.09,
#    'cc': 4,
#    'iterpara': 0.09,
#    'numLat': 200,
#    'test_score': 0.7518399842681809,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.101,
#    'lamU': 0.09,
#    'lamV': 0.09,
#    'cc': 5,
#    'iterpara': 0.09,
#    'numLat': 200,
#    'test_score': 0.754533963982034,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.101,
#    'lamU': 0.09,
#    'lamV': 0.09,
#    'cc': 6,
#    'iterpara': 0.09,
#    'numLat': 200,
#    'test_score': 0.7590153218131844,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.101,
#    'lamU': 0.09,
#    'lamV': 0.09,
#    'cc': 8,
#    'iterpara': 0.09,
#    'numLat': 200,
#    'test_score': 0.7649407361655253,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.101,
#    'lamU': 0.09,
#    'lamV': 0.09,
#    'cc': 10,
#    'iterpara': 0.09,
#    'numLat': 200,
#    'test_score': 0.770420681055966,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.121,
#    'lamU': 0.09,
#    'lamV': 0.09,
#    'cc': 1,
#    'iterpara': 0.09,
#    'numLat': 200,
#    'test_score': 0.753689646391852,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.121,
#    'lamU': 0.09,
#    'lamV': 0.09,
#    'cc': 2,
#    'iterpara': 0.09,
#    'numLat': 200,
#    'test_score': 0.7578760326167041,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.121,
#    'lamU': 0.09,
#    'lamV': 0.09,
#    'cc': 3,
#    'iterpara': 0.09,
#    'numLat': 200,
#    'test_score': 0.7625670816820955,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.121,
#    'lamU': 0.09,
#    'lamV': 0.09,
#    'cc': 4,
#    'iterpara': 0.09,
#    'numLat': 200,
#    'test_score': 0.7667417339982618,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.121,
#    'lamU': 0.09,
#    'lamV': 0.09,
#    'cc': 5,
#    'iterpara': 0.09,
#    'numLat': 200,
#    'test_score': 0.7714734850594077,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.121,
#    'lamU': 0.09,
#    'lamV': 0.09,
#    'cc': 6,
#    'iterpara': 0.09,
#    'numLat': 200,
#    'test_score': 0.776966735364162,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.121,
#    'lamU': 0.09,
#    'lamV': 0.09,
#    'cc': 8,
#    'iterpara': 0.09,
#    'numLat': 200,
#    'test_score': 0.7841341106139856,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.121,
#    'lamU': 0.09,
#    'lamV': 0.09,
#    'cc': 10,
#    'iterpara': 0.09,
#    'numLat': 200,
#    'test_score': 0.788924269300957,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.14100000000000001,
#    'lamU': 0.09,
#    'lamV': 0.09,
#    'cc': 1,
#    'iterpara': 0.09,
#    'numLat': 200,
#    'test_score': 0.7700190042175544,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.14100000000000001,
#    'lamU': 0.09,
#    'lamV': 0.09,
#    'cc': 2,
#    'iterpara': 0.09,
#    'numLat': 200,
#    'test_score': 0.7760738058665667,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.14100000000000001,
#    'lamU': 0.09,
#    'lamV': 0.09,
#    'cc': 3,
#    'iterpara': 0.09,
#    'numLat': 200,
#    'test_score': 0.781722059009722,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.14100000000000001,
#    'lamU': 0.09,
#    'lamV': 0.09,
#    'cc': 4,
#    'iterpara': 0.09,
#    'numLat': 200,
#    'test_score': 0.7874987565461722,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.14100000000000001,
#    'lamU': 0.09,
#    'lamV': 0.09,
#    'cc': 5,
#    'iterpara': 0.09,
#    'numLat': 200,
#    'test_score': 0.7924849343684247,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.14100000000000001,
#    'lamU': 0.09,
#    'lamV': 0.09,
#    'cc': 6,
#    'iterpara': 0.09,
#    'numLat': 200,
#    'test_score': 0.7970252236606097,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.14100000000000001,
#    'lamU': 0.09,
#    'lamV': 0.09,
#    'cc': 8,
#    'iterpara': 0.09,
#    'numLat': 200,
#    'test_score': 0.8012354967710013,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.14100000000000001,
#    'lamU': 0.09,
#    'lamV': 0.09,
#    'cc': 10,
#    'iterpara': 0.09,
#    'numLat': 200,
#    'test_score': 0.8010189432955196,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.161,
#    'lamU': 0.09,
#    'lamV': 0.09,
#    'cc': 1,
#    'iterpara': 0.09,
#    'numLat': 200,
#    'test_score': 0.7826716150934314,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.161,
#    'lamU': 0.09,
#    'lamV': 0.09,
#    'cc': 2,
#    'iterpara': 0.09,
#    'numLat': 200,
#    'test_score': 0.788655908523286,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.161,
#    'lamU': 0.09,
#    'lamV': 0.09,
#    'cc': 3,
#    'iterpara': 0.09,
#    'numLat': 200,
#    'test_score': 0.7964257990307269,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.161,
#    'lamU': 0.09,
#    'lamV': 0.09,
#    'cc': 4,
#    'iterpara': 0.09,
#    'numLat': 200,
#    'test_score': 0.801971799541047,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.161,
#    'lamU': 0.09,
#    'lamV': 0.09,
#    'cc': 5,
#    'iterpara': 0.09,
#    'numLat': 200,
#    'test_score': 0.8058473419527623,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.161,
#    'lamU': 0.09,
#    'lamV': 0.09,
#    'cc': 6,
#    'iterpara': 0.09,
#    'numLat': 200,
#    'test_score': 0.8085579796262677,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.161,
#    'lamU': 0.09,
#    'lamV': 0.09,
#    'cc': 8,
#    'iterpara': 0.09,
#    'numLat': 200,
#    'test_score': 0.810641900855491,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.161,
#    'lamU': 0.09,
#    'lamV': 0.09,
#    'cc': 10,
#    'iterpara': 0.09,
#    'numLat': 200,
#    'test_score': 0.8070436768035241,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.181,
#    'lamU': 0.09,
#    'lamV': 0.09,
#    'cc': 1,
#    'iterpara': 0.09,
#    'numLat': 200,
#    'test_score': 0.7927370038710897,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.181,
#    'lamU': 0.09,
#    'lamV': 0.09,
#    'cc': 2,
#    'iterpara': 0.09,
#    'numLat': 200,
#    'test_score': 0.799531932287175,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.181,
#    'lamU': 0.09,
#    'lamV': 0.09,
#    'cc': 3,
#    'iterpara': 0.09,
#    'numLat': 200,
#    'test_score': 0.8070790356801447,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.181,
#    'lamU': 0.09,
#    'lamV': 0.09,
#    'cc': 4,
#    'iterpara': 0.09,
#    'numLat': 200,
#    'test_score': 0.8116347257274801,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.181,
#    'lamU': 0.09,
#    'lamV': 0.09,
#    'cc': 5,
#    'iterpara': 0.09,
#    'numLat': 200,
#    'test_score': 0.8144259816396806,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.181,
#    'lamU': 0.09,
#    'lamV': 0.09,
#    'cc': 6,
#    'iterpara': 0.09,
#    'numLat': 200,
#    'test_score': 0.817123523432956,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.181,
#    'lamU': 0.09,
#    'lamV': 0.09,
#    'cc': 8,
#    'iterpara': 0.09,
#    'numLat': 200,
#    'test_score': 0.8163860682254501,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.181,
#    'lamU': 0.09,
#    'lamV': 0.09,
#    'cc': 10,
#    'iterpara': 0.09,
#    'numLat': 200,
#    'test_score': 0.801570594154324,
#    'test_d1': 6949,
#    'test_d2': 13}])

# %%
filename_output
# Out:
# '/Users/sijianfan/Documents/projects/BiSSGL/outputs/realAnalysis/tuberculosis/noisy/results_drimc.gz'

# %%
with gzip.open(filename_output, "wb+", 4) as fout:
    pickle.dump(results, fout)

# %% [markdown]
# ---

# %%
from tqdm import tqdm
from sklearn.model_selection import ShuffleSplit, KFold
from sklearn.model_selection import train_test_split
from scipy.special import expit


results = []
for par_dtst in tqdm(grid_dataset):
    # prepare the train dataset: take the specified share from the beginnig of the index array
    ind_train_all, _ = train_test_split(
        ind_dvlp,
        shuffle=False,
        random_state=random_state,
        test_size=(1 - (par_dtst["train_size"] / dvlp_size)),
    )

    # Run the experiment: the model
    for par_mdl in grid_model:  # tqdm.tqdm(, desc="cv %02d" % (cv,))
        Y_train = get_submatrix(Y, ind_train_all)

        Y_train[Y_train == 0] = 0.5
        Y_train[Y_train == -1] = 0

        # set up the model
        xi, eta, tilde_lambda0, tilde_lambda1, lambda0, lambda1, K = (
            par_mdl["xi"],
            par_mdl["eta"],
            par_mdl["tilde_lambda0"],
            par_mdl["tilde_lambda1"],
            par_mdl["lambda0"],
            par_mdl["lambda1"],
            par_mdl["K"],
        )

        model = BiSSGL(
            Y=Y_train.toarray(),
            U=U,
            V=V,
            xi=xi,
            eta=eta,
            tilde_lambda0=tilde_lambda0,
            tilde_lambda1=tilde_lambda1,
            tilde_alpha=1 / K,
            tilde_beta=1,
            lambda0=lambda0,
            lambda1=lambda1,
            alpha=1 / K,
            beta=1,
            K=K,
            max_iter=10000,
            tol=1e-8,
        )

        # fit on the whole development dataset
        est_mu, est_A, est_B, logLik = model.optimization()

        # get the score
        prob_full = expit(U @ est_A @ est_B.T @ V.T)
        prob_test = get_submatrix(prob_full, ind_test)
        scores_test = mc_get_scores(Y_test, prob_test)
        d1_test = sum(abs(est_A).max(axis=1) > 0)
        d2_test = sum(abs(est_B).max(axis=1) > 0)

        # run the k-fold CV
        # splt = ShuffleSplit(**par_dtst, random_state=random_state)
        splt = KFold(par_dtst["n_splits"], shuffle=True, random_state=random_state)
        for cv, (ind_train, ind_valid) in enumerate(splt.split(ind_train_all)):

            # prepare the train and test indices
            ind_train, ind_valid = ind_train_all[ind_train], ind_train_all[ind_valid]
            Y_train = get_submatrix(Y, ind_train)
            Y_valid = get_submatrix(Y, ind_valid)

            Y_train[Y_train == 0] = 0.5
            Y_train[Y_train == -1] = 0

            # fit the model
            model = BiSSGL(
                Y=Y_train.toarray(),
                U=U,
                V=V,
                xi=xi,
                eta=eta,
                tilde_lambda0=tilde_lambda0,
                tilde_lambda1=tilde_lambda1,
                tilde_alpha=1 / K,
                tilde_beta=1,
                lambda0=lambda0,
                lambda1=lambda1,
                alpha=1 / K,
                beta=1,
                K=K,
                max_iter=10000,
                tol=1e-8,
            )

            # fit on the cv dataset
            est_mu, est_A, est_B, logLik = model.optimization()

            # compute the class probabilities
            prob_full = expit(U @ est_A @ est_B.T @ V.T)
            prob_valid = get_submatrix(prob_full, ind_valid)
            scores_valid = mc_get_scores(Y_valid, prob_valid)
            d1_valid = sum(abs(est_A).max(axis=1) > 0)
            d2_valid = sum(abs(est_B).max(axis=1) > 0)

            # record the results
            results.append(
                {
                    "train_size": par_dtst["train_size"],
                    "xi": par_mdl["xi"],
                    "eta": par_mdl["eta"],
                    "tilde_lambda0": par_mdl["tilde_lambda0"],
                    "tilde_lambda1": par_mdl["tilde_lambda1"],
                    "lambda0": par_mdl["lambda0"],
                    "lambda1": par_mdl["lambda1"],
                    "K": par_mdl["K"],
                    "cv": cv,
                    "val_score": scores_valid["auc"],
                    "val_d1": d1_valid,
                    "val_d2": d2_valid,
                    "test_score": scores_test["auc"],
                    "test_d1": d1_test,
                    "test_d2": d2_test,
                }
            )
        # end for
    # end for
# end for

# Save the results in a pickle

with gzip.open(filename_output, "wb+", 4) as fout:
    pickle.dump(results, fout)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# Finished with iterations of 9999
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# Finished with iterations of 9999
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# 100%|██████████| 1/1 [1:53:35<00:00, 6815.72s/it]
# Finished with iterations of 9999

# %%
filename_output
# Out:
# '/Users/sijianfan/Documents/projects/BiSSGL/outputs/realAnalysis/tuberculosis/results_bissgl.gz'

# %%
plt.stem(sorted(abs(est_A).max(axis=1), reverse=True))
plt.show()
