# %%
#!/usr/bin/env python
# coding: utf-8
"""
DRIMC — real-application cross-validation script (LOCAL).

Outer CV : 5 trials × 10-fold pairwise CV  (R's doCrossValidationByPairwise)
Inner CV : 3 × 80/20 ShuffleSplit at natural ratio (HP tuning)
Metrics  : AUPR, AUC, F1, Accuracy, Recall, Specificity, Precision

DRIMC pipeline:
  1. Load U, V, Y from staged_dataset.gz  (same as other methods)
  2. Jaccard similarity from U and V
  3. constrNeig → simD, simT              (constrained similarity, computed once)
  4. updateUV per fold/HP combo            (fit latent factors)
  5. Predict via simD @ est_U @ (simT @ est_V).T → sigmoid
"""

import os
import sys
import gzip
import pickle
import warnings
import logging

import numpy as np

from tqdm import TqdmSynchronisationWarning

warnings.simplefilter("ignore", TqdmSynchronisationWarning)

# single-threaded per HPC process — rpy2/R manages its own threading
# os.environ.setdefault("OMP_NUM_THREADS", "1")
# os.environ.setdefault("MKL_NUM_THREADS", "1")

# ====== user paths ======
PATH_ROOT = "/Users/sijianfan/projects/BiSSGL"
DRIMC_PATH = os.path.join(PATH_ROOT, "scripts/methods/DRIMC")

# --- dataset selection (override with env var DATASET) ---
DATASET = os.environ.get("DATASET", "cdataset")
PATH_DATA = os.path.join(PATH_ROOT, "datasets/realAnalysis", DATASET)
PATH_OUTPUT = os.path.join(
    PATH_ROOT, "outputs/results/realAnalysis", DATASET, "fold_cv/origin"
)
PATH_ARCHIVE = os.path.join(PATH_OUTPUT, "archived")

for p in (PATH_OUTPUT, PATH_ARCHIVE):
    os.makedirs(p, exist_ok=True)

filenames = {"output": "results_drimc"}

# %%
# ====== Python imports ======
sys.path.append(PATH_ROOT)

from sgimc.utils import load
from sklearn.metrics import pairwise_distances
from sklearn.model_selection import ParameterGrid, ShuffleSplit
from scipy.special import expit

# ====== R setup via rpy2 ======
import rpy2.robjects as robjects

r = robjects.r

r(f'setwd("{DRIMC_PATH}")')

# attach R packages
for pkg in ["matrixcalc", "data.table", "Rcpp", "ROCR", "Bolstad2", "MESS"]:
    r(f"library({pkg})")

# source R helper files (only what's needed)
for r_file in [
    "doCrossValidationByPairwise.R",
    "constrNeig.R",
    "calcLogLik.R",
    "calcDeriv.R",
    "updateUV.R",
]:
    r(f'source("{r_file}")')

# source C++ extensions needed by updateUV
r("library(Rcpp)")
for cpp_file in ["log1pexp.cpp", "sigmoid.cpp"]:
    r(f'sourceCpp("{cpp_file}")')

# bind R functions to Python
doCrossValidationByPairwise_R = r["doCrossValidationByPairwise"]
updateUV_R = r["updateUV"]
constrNeig_R = r["constrNeig"]


# ====== scoring helper (matches simulation scripts) ======
def get_metrics(real_score, predict_score):
    sorted_predict_score = np.array(
        sorted(list(set(np.array(predict_score).flatten())))
    )
    sorted_predict_score_num = len(sorted_predict_score)
    thresholds = sorted_predict_score[
        np.int32(sorted_predict_score_num * np.arange(1, 1000) / 1000)
    ]
    thresholds = np.mat(thresholds)
    thresholds_num = thresholds.shape[1]

    predict_score_matrix = np.tile(predict_score, (thresholds_num, 1))
    negative_index = np.where(predict_score_matrix < thresholds.T)
    positive_index = np.where(predict_score_matrix >= thresholds.T)
    predict_score_matrix[negative_index] = 0
    predict_score_matrix[positive_index] = 1
    TP = predict_score_matrix.dot(real_score.T)
    FP = predict_score_matrix.sum(axis=1) - TP
    FN = real_score.sum() - TP
    TN = len(real_score.T) - TP - FP - FN

    fpr = FP / (FP + TN)
    tpr = TP / (TP + FN)
    ROC_dot_matrix = np.mat(sorted(np.column_stack((fpr, tpr)).tolist())).T
    ROC_dot_matrix.T[0] = [0, 0]
    ROC_dot_matrix = np.c_[ROC_dot_matrix, [1, 1]]
    x_ROC = ROC_dot_matrix[0].T
    y_ROC = ROC_dot_matrix[1].T
    auc = 0.5 * (x_ROC[1:] - x_ROC[:-1]).T * (y_ROC[:-1] + y_ROC[1:])

    recall_list = tpr
    precision_list = TP / (TP + FP)
    PR_dot_matrix = np.mat(
        sorted(np.column_stack((recall_list, precision_list)).tolist())
    ).T
    PR_dot_matrix.T[0] = [0, 1]
    PR_dot_matrix = np.c_[PR_dot_matrix, [1, 0]]
    x_PR = PR_dot_matrix[0].T
    y_PR = PR_dot_matrix[1].T
    aupr = 0.5 * (x_PR[1:] - x_PR[:-1]).T * (y_PR[:-1] + y_PR[1:])

    f1_score_list = 2 * TP / (len(real_score.T) + TP - TN)
    accuracy_list = (TP + TN) / len(real_score.T)
    specificity_list = TN / (TN + FP)

    max_index = np.argmax(f1_score_list)
    f1_score = f1_score_list[max_index]
    accuracy = accuracy_list[max_index]
    specificity = specificity_list[max_index]
    recall = recall_list[max_index]
    precision = precision_list[max_index]
    return [aupr[0, 0], auc[0, 0], f1_score, accuracy, recall, specificity, precision]


# ====== helpers ======
def to_r_matrix(arr):
    return r.matrix(
        robjects.FloatVector(arr.flatten()),
        byrow=True,
        nrow=arr.shape[0],
        ncol=arr.shape[1],
    )


def extract_fold(savedFolds, trial, fold):
    fold_data = savedFolds.rx2(trial + 1).rx2(fold + 1)
    Y_train = np.array(fold_data.rx2(7))
    test_label = np.array(fold_data.rx2(1)).flatten()
    test_row = np.array(fold_data.rx2(3)).flatten().astype(int) - 1
    test_col = np.array(fold_data.rx2(4)).flatten().astype(int) - 1
    known_drug_idx = np.array(fold_data.rx2(5)).flatten().astype(int)
    known_target_idx = np.array(fold_data.rx2(6)).flatten().astype(int)
    return Y_train, test_row, test_col, test_label, known_drug_idx, known_target_idx


def sample_cv_entries(Y_train, rng, max_samples=None):
    """
    Randomly sample matrix entries preserving the natural class ratio.
    If max_samples is None or >= n*m, all entries are used.
    """
    n, m = Y_train.shape
    total = n * m
    if max_samples is None or max_samples >= total:
        flat_idx = np.arange(total)
    else:
        flat_idx = rng.choice(total, size=max_samples, replace=False)
    cv_rows = flat_idx // m
    cv_cols = flat_idx % m
    cv_labels = Y_train[cv_rows, cv_cols].astype(float)
    return cv_rows, cv_cols, cv_labels


# ====== load dataset ======
logging.basicConfig(level=logging.INFO, format="%(asctime)s %(levelname)s: %(message)s")
logging.info("Loading dataset: %s", DATASET)

filename_input = os.path.join(PATH_DATA, "cv_data", "staged_dataset.gz")
U, V, Y = load(filename_input)

# densify
U = np.asarray(U.toarray() if hasattr(U, "toarray") else U, dtype=float)
V = np.asarray(V.toarray() if hasattr(V, "toarray") else V, dtype=float)

# adjacency matrix for R's CV function
Y_dense = Y.toarray() if hasattr(Y, "toarray") else np.asarray(Y)
Y_adj = (Y_dense > 0).astype(float)

# ====== build similarity matrices (Jaccard, computed once) ======
logging.info("Computing Jaccard similarity matrices ...")
simD = 1 - pairwise_distances(U, metric="jaccard")
simT = 1 - pairwise_distances(V, metric="jaccard")

# handle NaN from all-zero rows (Jaccard is undefined → set self-sim = 1, rest = 0)
simD = np.nan_to_num(simD, nan=0.0)
simT = np.nan_to_num(simT, nan=0.0)
np.fill_diagonal(simD, 1.0)
np.fill_diagonal(simT, 1.0)

logging.info("simD: %s,  simT: %s", simD.shape, simT.shape)

# apply neighbourhood constraint via constrNeig (K=3, same as simulation)
K_neig = 3
simD_Robj = to_r_matrix(simD)
simT_Robj = to_r_matrix(simT)

logging.info("Applying constrNeig (K=%d) ...", K_neig)
lap = constrNeig_R(simD_Robj, simT_Robj, K=K_neig)
simD_R = lap.rx2("simD")
simT_R = lap.rx2("simT")
simD_np = np.array(simD_R)
simT_np = np.array(simT_R)
logging.info("Constrained simD: %s,  simT: %s", simD_np.shape, simT_np.shape)

# ====== create outer CV folds via R ======
kfold = 10
numSplit = 5
seeds_R = robjects.IntVector([7771, 8367, 22, 1812, 4659])

logging.info(
    "Creating %d trials × %d-fold pairwise CV splits via R ...", numSplit, kfold
)
savedFolds = doCrossValidationByPairwise_R(
    to_r_matrix(Y_adj), kfold=kfold, numSplit=numSplit, seeds=seeds_R
)
# Out:
# R callback write-console: data.table 1.17.8 using 6 threads (see ?getDTthreads).
# R callback write-console: Latest news: r-datatable.com
#
# 2026-04-24 15:58:17,331 INFO: Loading dataset: cdataset
# 2026-04-24 15:58:17,352 INFO: Computing Jaccard similarity matrices ...
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/sklearn/metrics/pairwise.py:2182: DataConversionWarning: Data was converted to boolean for metric jaccard
#   warnings.warn(msg, DataConversionWarning)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/sklearn/metrics/pairwise.py:2182: DataConversionWarning: Data was converted to boolean for metric jaccard
#   warnings.warn(msg, DataConversionWarning)
# 2026-04-24 15:58:17,729 INFO: simD: (658, 658),  simT: (409, 409)
# 2026-04-24 15:58:17,735 INFO: Applying constrNeig (K=3) ...
# 2026-04-24 15:58:17,920 INFO: Constrained simD: (658, 658),  simT: (409, 409)
# 2026-04-24 15:58:17,920 INFO: Creating 5 trials × 10-fold pairwise CV splits via R ...

# %%
# ====== parameter grid ======
grid_model = ParameterGrid(
    {
        "lamU": [2],
        "lamV": [2],
        "cc": [1, 5, 10],
        "iterpara": [0.125],
        "numLat": [50, 100, 150, 200],
    }
)

N_INNER_SPLITS = 3
INNER_VAL_SIZE = 0.20

# ====== flatten combinations ======
combos = []
for trial in range(numSplit):
    for fold in range(kfold):
        for i_m, par_mdl in enumerate(grid_model):
            combos.append((trial, fold, i_m, par_mdl))
n_combos = len(combos)

# %%
# ====== local (notebook) run — loops over ALL combos ======
BASE_SEED = int(os.environ.get("BASE_SEED", str(0x0BADCAFE)))

logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s [local] %(levelname)s: %(message)s",
    datefmt="%Y-%m-%d %H:%M:%S",
)

logging.info("LOCAL mode — running all %d combos", n_combos)

task_results = []

# optional tqdm progress bar
try:
    from tqdm.auto import tqdm

    _iter = tqdm(range(n_combos), desc="combos", total=n_combos)
except ImportError:
    _iter = range(n_combos)

# ====== run all combos ======
for combo_idx in _iter:
    trial, fold, i_m, par_mdl = combos[combo_idx]
    logging.info(
        "Running combo_idx=%d (trial=%d, fold=%d, lamU=%s, lamV=%s, cc=%s)",
        combo_idx,
        trial,
        fold,
        par_mdl["lamU"],
        par_mdl["lamV"],
        par_mdl["cc"],
    )

    split_seed = BASE_SEED + trial * 100 + fold
    rng_split = np.random.RandomState(split_seed)
    model_seed = BASE_SEED + combo_idx

    try:
        # ====== extract fold data ======
        Y_train_dense, test_row, test_col, test_label, _, _ = extract_fold(
            savedFolds, trial, fold
        )

        Y_train_Robj = to_r_matrix(Y_train_dense)

        # extract model params
        lamU = par_mdl["lamU"]
        lamV = par_mdl["lamV"]
        cc = par_mdl["cc"]
        iterpara = par_mdl["iterpara"]
        numLat = par_mdl["numLat"]

        # ====== fit on full training → test scores ======
        out = updateUV_R(
            cc=cc,
            inMat=Y_train_Robj,
            Sd=simD_R,
            St=simT_R,
            lamU=lamU,
            lamV=lamV,
            numLat=numLat,
            initMethod="useSeed",
            thisSeed=model_seed % (2**31 - 1),
            iterpara=iterpara,
            maxIter=1000,
        )
        est_U = np.array(out.rx2("U"))
        est_V = np.array(out.rx2("V"))

        # predict: simD @ est_U @ (simT @ est_V).T → sigmoid
        SA = simD_np @ est_U
        STB = simT_np @ est_V
        prob_full = expit(SA @ STB.T)
        prob_test = prob_full[test_row, test_col]

        scores_test = get_metrics(
            np.asarray(test_label, dtype=float),
            np.asarray(prob_test, dtype=float),
        )
        d1_test = int(sum(abs(est_U).max(axis=1) > 0))
        d2_test = int(sum(abs(est_V).max(axis=1) > 0))

        # ====== inner CV — ShuffleSplit at natural ratio ======
        cv_rows, cv_cols, cv_labels = sample_cv_entries(Y_train_dense, rng_split)

        splt = ShuffleSplit(
            n_splits=N_INNER_SPLITS,
            test_size=INNER_VAL_SIZE,
            random_state=rng_split,
        )
        for cv, (ind_train, ind_valid) in enumerate(
            splt.split(np.arange(len(cv_labels)))
        ):
            # build inner training matrix: zero out validation positives
            Y_inner = Y_train_dense.copy()
            valid_pos_mask = cv_labels[ind_valid] == 1
            Y_inner[
                cv_rows[ind_valid[valid_pos_mask]],
                cv_cols[ind_valid[valid_pos_mask]],
            ] = 0

            Y_inner_Robj = to_r_matrix(Y_inner)

            out_cv = updateUV_R(
                cc=cc,
                inMat=Y_inner_Robj,
                Sd=simD_R,
                St=simT_R,
                lamU=lamU,
                lamV=lamV,
                numLat=numLat,
                initMethod="useSeed",
                thisSeed=model_seed % (2**31 - 1),
                iterpara=iterpara,
                maxIter=1000,
            )
            est_U_cv = np.array(out_cv.rx2("U"))
            est_V_cv = np.array(out_cv.rx2("V"))

            SA_cv = simD_np @ est_U_cv
            STB_cv = simT_np @ est_V_cv
            prob_full_cv = expit(SA_cv @ STB_cv.T)
            prob_valid = prob_full_cv[cv_rows[ind_valid], cv_cols[ind_valid]]
            scores_valid = get_metrics(
                np.asarray(cv_labels[ind_valid], dtype=float),
                np.asarray(prob_valid, dtype=float),
            )
            d1_valid = int(sum(abs(est_U_cv).max(axis=1) > 0))
            d2_valid = int(sum(abs(est_V_cv).max(axis=1) > 0))

            task_results.append(
                {
                    "trial": trial,
                    "fold": fold,
                    "lamU": lamU,
                    "lamV": lamV,
                    "cc": cc,
                    "iterpara": iterpara,
                    "numLat": numLat,
                    "cv": int(cv),
                    "val_score": scores_valid,
                    "val_d1": d1_valid,
                    "val_d2": d2_valid,
                    "test_score": scores_test,
                    "test_d1": d1_test,
                    "test_d2": d2_test,
                }
            )

    except Exception as e:
        logging.exception("Error at combo_idx=%d: %s", combo_idx, str(e))
# Out:
# 2026-04-24 16:01:29,902 INFO: LOCAL mode — running all 600 combos
# combos:   0%|          | 0/600 [00:00<?, ?it/s]2026-04-24 16:01:29,905 INFO: Running combo_idx=0 (trial=0, fold=0, lamU=2, lamV=2, cc=1)
# combos:   0%|          | 1/600 [00:14<2:23:07, 14.34s/it]2026-04-24 16:01:44,243 INFO: Running combo_idx=1 (trial=0, fold=0, lamU=2, lamV=2, cc=1)
# combos:   0%|          | 2/600 [00:29<2:29:30, 15.00s/it]2026-04-24 16:01:59,708 INFO: Running combo_idx=2 (trial=0, fold=0, lamU=2, lamV=2, cc=1)
# combos:   0%|          | 3/600 [00:46<2:36:52, 15.77s/it]2026-04-24 16:02:16,392 INFO: Running combo_idx=3 (trial=0, fold=0, lamU=2, lamV=2, cc=1)
# combos:   1%|          | 4/600 [00:59<2:27:22, 14.84s/it]2026-04-24 16:02:29,798 INFO: Running combo_idx=4 (trial=0, fold=0, lamU=2, lamV=2, cc=5)
# combos:   1%|          | 5/600 [01:11<2:16:19, 13.75s/it]2026-04-24 16:02:41,617 INFO: Running combo_idx=5 (trial=0, fold=0, lamU=2, lamV=2, cc=5)
# combos:   1%|          | 6/600 [01:24<2:14:27, 13.58s/it]2026-04-24 16:02:54,873 INFO: Running combo_idx=6 (trial=0, fold=0, lamU=2, lamV=2, cc=5)
# combos:   1%|          | 7/600 [01:39<2:17:21, 13.90s/it]2026-04-24 16:03:09,422 INFO: Running combo_idx=7 (trial=0, fold=0, lamU=2, lamV=2, cc=5)
# combos:   1%|▏         | 8/600 [01:54<2:19:21, 14.12s/it]2026-04-24 16:03:24,031 INFO: Running combo_idx=8 (trial=0, fold=0, lamU=2, lamV=2, cc=10)
# combos:   2%|▏         | 9/600 [02:07<2:17:10, 13.93s/it]2026-04-24 16:03:37,521 INFO: Running combo_idx=9 (trial=0, fold=0, lamU=2, lamV=2, cc=10)
# combos:   2%|▏         | 10/600 [02:20<2:13:46, 13.60s/it]2026-04-24 16:03:50,407 INFO: Running combo_idx=10 (trial=0, fold=0, lamU=2, lamV=2, cc=10)
# combos:   2%|▏         | 11/600 [02:31<2:07:01, 12.94s/it]2026-04-24 16:04:01,842 INFO: Running combo_idx=11 (trial=0, fold=0, lamU=2, lamV=2, cc=10)
# combos:   2%|▏         | 12/600 [02:44<2:05:04, 12.76s/it]2026-04-24 16:04:14,201 INFO: Running combo_idx=12 (trial=0, fold=1, lamU=2, lamV=2, cc=1)
# combos:   2%|▏         | 13/600 [02:57<2:04:51, 12.76s/it]2026-04-24 16:04:26,956 INFO: Running combo_idx=13 (trial=0, fold=1, lamU=2, lamV=2, cc=1)
# combos:   2%|▏         | 14/600 [03:10<2:05:21, 12.83s/it]2026-04-24 16:04:39,965 INFO: Running combo_idx=14 (trial=0, fold=1, lamU=2, lamV=2, cc=1)
# combos:   2%|▎         | 15/600 [03:23<2:06:00, 12.92s/it]2026-04-24 16:04:53,090 INFO: Running combo_idx=15 (trial=0, fold=1, lamU=2, lamV=2, cc=1)
# combos:   3%|▎         | 16/600 [03:37<2:08:38, 13.22s/it]2026-04-24 16:05:06,987 INFO: Running combo_idx=16 (trial=0, fold=1, lamU=2, lamV=2, cc=5)
# combos:   3%|▎         | 17/600 [03:49<2:05:04, 12.87s/it]2026-04-24 16:05:19,055 INFO: Running combo_idx=17 (trial=0, fold=1, lamU=2, lamV=2, cc=5)
# combos:   3%|▎         | 18/600 [04:01<2:03:44, 12.76s/it]2026-04-24 16:05:31,545 INFO: Running combo_idx=18 (trial=0, fold=1, lamU=2, lamV=2, cc=5)
# combos:   3%|▎         | 19/600 [04:12<1:59:01, 12.29s/it]2026-04-24 16:05:42,753 INFO: Running combo_idx=19 (trial=0, fold=1, lamU=2, lamV=2, cc=5)
# combos:   3%|▎         | 20/600 [04:24<1:57:44, 12.18s/it]2026-04-24 16:05:54,673 INFO: Running combo_idx=20 (trial=0, fold=1, lamU=2, lamV=2, cc=10)
# combos:   4%|▎         | 21/600 [04:38<2:01:09, 12.56s/it]2026-04-24 16:06:08,104 INFO: Running combo_idx=21 (trial=0, fold=1, lamU=2, lamV=2, cc=10)
# combos:   4%|▎         | 22/600 [04:52<2:05:44, 13.05s/it]2026-04-24 16:06:22,315 INFO: Running combo_idx=22 (trial=0, fold=1, lamU=2, lamV=2, cc=10)
# combos:   4%|▍         | 23/600 [05:06<2:08:25, 13.35s/it]2026-04-24 16:06:36,374 INFO: Running combo_idx=23 (trial=0, fold=1, lamU=2, lamV=2, cc=10)
# combos:   4%|▍         | 24/600 [05:19<2:08:22, 13.37s/it]2026-04-24 16:06:49,789 INFO: Running combo_idx=24 (trial=0, fold=2, lamU=2, lamV=2, cc=1)
# combos:   4%|▍         | 25/600 [05:30<2:01:02, 12.63s/it]2026-04-24 16:07:00,691 INFO: Running combo_idx=25 (trial=0, fold=2, lamU=2, lamV=2, cc=1)
# combos:   4%|▍         | 26/600 [05:41<1:56:32, 12.18s/it]2026-04-24 16:07:11,825 INFO: Running combo_idx=26 (trial=0, fold=2, lamU=2, lamV=2, cc=1)
# combos:   4%|▍         | 27/600 [05:54<1:58:39, 12.42s/it]2026-04-24 16:07:24,816 INFO: Running combo_idx=27 (trial=0, fold=2, lamU=2, lamV=2, cc=1)
# combos:   7%|▋         | 44/600 [09:35<1:56:01, 12.52s/it]2026-04-24 16:11:04,978 INFO: Running combo_idx=44 (trial=0, fold=3, lamU=2, lamV=2, cc=10)
# combos:   8%|▊         | 45/600 [09:48<1:59:38, 12.93s/it]2026-04-24 16:11:18,874 INFO: Running combo_idx=45 (trial=0, fold=3, lamU=2, lamV=2, cc=10)
# combos:   8%|▊         | 46/600 [10:02<2:01:20, 13.14s/it]2026-04-24 16:11:32,499 INFO: Running combo_idx=46 (trial=0, fold=3, lamU=2, lamV=2, cc=10)
# combos:   8%|▊         | 47/600 [10:15<2:01:09, 13.15s/it]2026-04-24 16:11:45,655 INFO: Running combo_idx=47 (trial=0, fold=3, lamU=2, lamV=2, cc=10)
# combos:   8%|▊         | 48/600 [10:28<1:59:45, 13.02s/it]2026-04-24 16:11:58,375 INFO: Running combo_idx=48 (trial=0, fold=4, lamU=2, lamV=2, cc=1)
# combos:   8%|▊         | 49/600 [10:39<1:53:23, 12.35s/it]2026-04-24 16:12:09,160 INFO: Running combo_idx=49 (trial=0, fold=4, lamU=2, lamV=2, cc=1)
# combos:   8%|▊         | 50/600 [10:53<1:57:55, 12.86s/it]2026-04-24 16:12:23,229 INFO: Running combo_idx=50 (trial=0, fold=4, lamU=2, lamV=2, cc=1)
# combos:   8%|▊         | 51/600 [11:08<2:05:12, 13.68s/it]2026-04-24 16:12:38,834 INFO: Running combo_idx=51 (trial=0, fold=4, lamU=2, lamV=2, cc=1)
# combos:   9%|▊         | 52/600 [11:23<2:07:37, 13.97s/it]2026-04-24 16:12:53,476 INFO: Running combo_idx=52 (trial=0, fold=4, lamU=2, lamV=2, cc=5)
# combos:   9%|▉         | 53/600 [11:36<2:04:50, 13.69s/it]2026-04-24 16:13:06,518 INFO: Running combo_idx=53 (trial=0, fold=4, lamU=2, lamV=2, cc=5)
# combos:   9%|▉         | 54/600 [11:49<2:03:35, 13.58s/it]2026-04-24 16:13:19,834 INFO: Running combo_idx=54 (trial=0, fold=4, lamU=2, lamV=2, cc=5)
# combos:   9%|▉         | 55/600 [12:04<2:07:05, 13.99s/it]2026-04-24 16:13:34,784 INFO: Running combo_idx=55 (trial=0, fold=4, lamU=2, lamV=2, cc=5)
# combos:   9%|▉         | 56/600 [12:20<2:10:01, 14.34s/it]2026-04-24 16:13:49,942 INFO: Running combo_idx=56 (trial=0, fold=4, lamU=2, lamV=2, cc=10)
# combos:  10%|▉         | 57/600 [12:34<2:09:44, 14.34s/it]2026-04-24 16:14:04,264 INFO: Running combo_idx=57 (trial=0, fold=4, lamU=2, lamV=2, cc=10)
# combos:  10%|▉         | 58/600 [12:49<2:10:23, 14.43s/it]2026-04-24 16:14:18,930 INFO: Running combo_idx=58 (trial=0, fold=4, lamU=2, lamV=2, cc=10)
# combos:  10%|▉         | 59/600 [13:02<2:08:29, 14.25s/it]2026-04-24 16:14:32,751 INFO: Running combo_idx=59 (trial=0, fold=4, lamU=2, lamV=2, cc=10)
# combos:  24%|██▎       | 141/600 [30:26<1:34:36, 12.37s/it]2026-04-24 16:31:56,244 INFO: Running combo_idx=141 (trial=1, fold=1, lamU=2, lamV=2, cc=10)
# combos:  24%|██▎       | 142/600 [30:38<1:33:04, 12.19s/it]2026-04-24 16:32:08,021 INFO: Running combo_idx=142 (trial=1, fold=1, lamU=2, lamV=2, cc=10)
# combos:  24%|██▍       | 143/600 [30:51<1:35:56, 12.60s/it]2026-04-24 16:32:21,557 INFO: Running combo_idx=143 (trial=1, fold=1, lamU=2, lamV=2, cc=10)
# combos:  24%|██▍       | 144/600 [31:04<1:37:22, 12.81s/it]2026-04-24 16:32:34,875 INFO: Running combo_idx=144 (trial=1, fold=2, lamU=2, lamV=2, cc=1)
# combos:  24%|██▍       | 145/600 [31:17<1:37:10, 12.81s/it]2026-04-24 16:32:47,691 INFO: Running combo_idx=145 (trial=1, fold=2, lamU=2, lamV=2, cc=1)
# combos:  24%|██▍       | 146/600 [31:30<1:36:56, 12.81s/it]2026-04-24 16:33:00,499 INFO: Running combo_idx=146 (trial=1, fold=2, lamU=2, lamV=2, cc=1)
# combos:  24%|██▍       | 147/600 [31:41<1:32:42, 12.28s/it]2026-04-24 16:33:11,540 INFO: Running combo_idx=147 (trial=1, fold=2, lamU=2, lamV=2, cc=1)
# combos:  25%|██▍       | 148/600 [31:53<1:31:12, 12.11s/it]2026-04-24 16:33:23,241 INFO: Running combo_idx=148 (trial=1, fold=2, lamU=2, lamV=2, cc=5)
# combos:  25%|██▍       | 149/600 [32:06<1:33:13, 12.40s/it]2026-04-24 16:33:36,333 INFO: Running combo_idx=149 (trial=1, fold=2, lamU=2, lamV=2, cc=5)
# combos:  25%|██▌       | 150/600 [32:19<1:34:17, 12.57s/it]2026-04-24 16:33:49,303 INFO: Running combo_idx=150 (trial=1, fold=2, lamU=2, lamV=2, cc=5)
# combos:  25%|██▌       | 151/600 [32:31<1:34:02, 12.57s/it]2026-04-24 16:34:01,874 INFO: Running combo_idx=151 (trial=1, fold=2, lamU=2, lamV=2, cc=5)
# combos:  25%|██▌       | 152/600 [32:44<1:32:43, 12.42s/it]2026-04-24 16:34:13,938 INFO: Running combo_idx=152 (trial=1, fold=2, lamU=2, lamV=2, cc=10)
# combos:  26%|██▌       | 153/600 [32:55<1:29:58, 12.08s/it]2026-04-24 16:34:25,214 INFO: Running combo_idx=153 (trial=1, fold=2, lamU=2, lamV=2, cc=10)
# combos:  26%|██▌       | 154/600 [33:08<1:32:25, 12.43s/it]2026-04-24 16:34:38,481 INFO: Running combo_idx=154 (trial=1, fold=2, lamU=2, lamV=2, cc=10)
# combos:  26%|██▌       | 155/600 [33:22<1:35:12, 12.84s/it]2026-04-24 16:34:52,259 INFO: Running combo_idx=155 (trial=1, fold=2, lamU=2, lamV=2, cc=10)
# combos:  26%|██▌       | 156/600 [33:35<1:35:31, 12.91s/it]2026-04-24 16:35:05,333 INFO: Running combo_idx=156 (trial=1, fold=3, lamU=2, lamV=2, cc=1)
# combos:  32%|███▏      | 189/600 [40:20<1:22:25, 12.03s/it]2026-04-24 16:41:50,317 INFO: Running combo_idx=189 (trial=1, fold=5, lamU=2, lamV=2, cc=10)
# combos:  32%|███▏      | 190/600 [40:33<1:25:06, 12.45s/it]2026-04-24 16:42:03,757 INFO: Running combo_idx=190 (trial=1, fold=5, lamU=2, lamV=2, cc=10)
# combos:  32%|███▏      | 191/600 [40:46<1:25:11, 12.50s/it]2026-04-24 16:42:16,356 INFO: Running combo_idx=191 (trial=1, fold=5, lamU=2, lamV=2, cc=10)
# combos:  32%|███▏      | 192/600 [40:58<1:23:40, 12.31s/it]2026-04-24 16:42:28,219 INFO: Running combo_idx=192 (trial=1, fold=6, lamU=2, lamV=2, cc=1)
# combos:  32%|███▏      | 193/600 [41:09<1:21:43, 12.05s/it]2026-04-24 16:42:39,660 INFO: Running combo_idx=193 (trial=1, fold=6, lamU=2, lamV=2, cc=1)
# combos:  32%|███▏      | 194/600 [41:21<1:21:04, 11.98s/it]2026-04-24 16:42:51,485 INFO: Running combo_idx=194 (trial=1, fold=6, lamU=2, lamV=2, cc=1)
# combos:  32%|███▎      | 195/600 [41:35<1:24:04, 12.46s/it]2026-04-24 16:43:05,048 INFO: Running combo_idx=195 (trial=1, fold=6, lamU=2, lamV=2, cc=1)
# combos:  33%|███▎      | 196/600 [41:48<1:26:27, 12.84s/it]2026-04-24 16:43:18,787 INFO: Running combo_idx=196 (trial=1, fold=6, lamU=2, lamV=2, cc=5)
# combos:  33%|███▎      | 197/600 [42:02<1:27:20, 13.00s/it]2026-04-24 16:43:32,167 INFO: Running combo_idx=197 (trial=1, fold=6, lamU=2, lamV=2, cc=5)
# combos:  33%|███▎      | 198/600 [42:14<1:25:21, 12.74s/it]2026-04-24 16:43:44,294 INFO: Running combo_idx=198 (trial=1, fold=6, lamU=2, lamV=2, cc=5)
# combos:  33%|███▎      | 199/600 [42:26<1:22:58, 12.41s/it]2026-04-24 16:43:55,949 INFO: Running combo_idx=199 (trial=1, fold=6, lamU=2, lamV=2, cc=5)
# combos:  33%|███▎      | 200/600 [42:37<1:21:04, 12.16s/it]2026-04-24 16:44:07,520 INFO: Running combo_idx=200 (trial=1, fold=6, lamU=2, lamV=2, cc=10)
# combos:  34%|███▎      | 201/600 [42:50<1:22:47, 12.45s/it]2026-04-24 16:44:20,644 INFO: Running combo_idx=201 (trial=1, fold=6, lamU=2, lamV=2, cc=10)
# combos:  34%|███▎      | 202/600 [43:03<1:23:53, 12.65s/it]2026-04-24 16:44:33,754 INFO: Running combo_idx=202 (trial=1, fold=6, lamU=2, lamV=2, cc=10)
# combos:  34%|███▍      | 203/600 [43:18<1:26:43, 13.11s/it]2026-04-24 16:44:47,932 INFO: Running combo_idx=203 (trial=1, fold=6, lamU=2, lamV=2, cc=10)
# combos:  34%|███▍      | 204/600 [43:31<1:27:23, 13.24s/it]2026-04-24 16:45:01,487 INFO: Running combo_idx=204 (trial=1, fold=7, lamU=2, lamV=2, cc=1)
# combos:  37%|███▋      | 221/600 [46:56<1:15:34, 11.96s/it]2026-04-24 16:48:26,487 INFO: Running combo_idx=221 (trial=1, fold=8, lamU=2, lamV=2, cc=5)
# combos:  37%|███▋      | 222/600 [47:09<1:17:37, 12.32s/it]2026-04-24 16:48:39,637 INFO: Running combo_idx=222 (trial=1, fold=8, lamU=2, lamV=2, cc=5)
# combos:  37%|███▋      | 223/600 [47:23<1:20:32, 12.82s/it]2026-04-24 16:48:53,621 INFO: Running combo_idx=223 (trial=1, fold=8, lamU=2, lamV=2, cc=5)
# combos:  37%|███▋      | 224/600 [47:36<1:21:02, 12.93s/it]2026-04-24 16:49:06,818 INFO: Running combo_idx=224 (trial=1, fold=8, lamU=2, lamV=2, cc=10)
# combos:  38%|███▊      | 225/600 [47:49<1:19:32, 12.73s/it]2026-04-24 16:49:19,064 INFO: Running combo_idx=225 (trial=1, fold=8, lamU=2, lamV=2, cc=10)
# combos:  38%|███▊      | 226/600 [48:01<1:17:42, 12.47s/it]2026-04-24 16:49:30,925 INFO: Running combo_idx=226 (trial=1, fold=8, lamU=2, lamV=2, cc=10)
# combos:  38%|███▊      | 227/600 [48:11<1:14:37, 12.00s/it]2026-04-24 16:49:41,851 INFO: Running combo_idx=227 (trial=1, fold=8, lamU=2, lamV=2, cc=10)
# combos:  38%|███▊      | 228/600 [48:24<1:14:56, 12.09s/it]2026-04-24 16:49:54,128 INFO: Running combo_idx=228 (trial=1, fold=9, lamU=2, lamV=2, cc=1)
# combos:  38%|███▊      | 229/600 [48:37<1:16:52, 12.43s/it]2026-04-24 16:50:07,364 INFO: Running combo_idx=229 (trial=1, fold=9, lamU=2, lamV=2, cc=1)
# combos:  38%|███▊      | 230/600 [48:50<1:18:20, 12.70s/it]2026-04-24 16:50:20,701 INFO: Running combo_idx=230 (trial=1, fold=9, lamU=2, lamV=2, cc=1)
# combos:  38%|███▊      | 231/600 [49:03<1:18:38, 12.79s/it]2026-04-24 16:50:33,682 INFO: Running combo_idx=231 (trial=1, fold=9, lamU=2, lamV=2, cc=1)
# combos:  39%|███▊      | 232/600 [49:16<1:18:21, 12.78s/it]2026-04-24 16:50:46,435 INFO: Running combo_idx=232 (trial=1, fold=9, lamU=2, lamV=2, cc=5)
# combos:  39%|███▉      | 233/600 [49:27<1:15:28, 12.34s/it]2026-04-24 16:50:57,760 INFO: Running combo_idx=233 (trial=1, fold=9, lamU=2, lamV=2, cc=5)
# combos:  39%|███▉      | 234/600 [49:40<1:15:05, 12.31s/it]2026-04-24 16:51:09,999 INFO: Running combo_idx=234 (trial=1, fold=9, lamU=2, lamV=2, cc=5)
# combos:  39%|███▉      | 235/600 [49:52<1:15:54, 12.48s/it]2026-04-24 16:51:22,864 INFO: Running combo_idx=235 (trial=1, fold=9, lamU=2, lamV=2, cc=5)
# combos:  39%|███▉      | 236/600 [50:05<1:16:33, 12.62s/it]2026-04-24 16:51:35,818 INFO: Running combo_idx=236 (trial=1, fold=9, lamU=2, lamV=2, cc=10)
# combos:  50%|█████     | 301/600 [1:03:20<1:00:16, 12.09s/it]2026-04-24 17:04:50,579 INFO: Running combo_idx=301 (trial=2, fold=5, lamU=2, lamV=2, cc=1)
# combos:  50%|█████     | 302/600 [1:03:33<1:01:39, 12.41s/it]2026-04-24 17:05:03,742 INFO: Running combo_idx=302 (trial=2, fold=5, lamU=2, lamV=2, cc=1)
# combos:  50%|█████     | 303/600 [1:03:47<1:02:45, 12.68s/it]2026-04-24 17:05:17,037 INFO: Running combo_idx=303 (trial=2, fold=5, lamU=2, lamV=2, cc=1)
# combos:  51%|█████     | 304/600 [1:04:01<1:04:19, 13.04s/it]2026-04-24 17:05:30,918 INFO: Running combo_idx=304 (trial=2, fold=5, lamU=2, lamV=2, cc=5)
# combos:  51%|█████     | 305/600 [1:04:13<1:03:00, 12.82s/it]2026-04-24 17:05:43,212 INFO: Running combo_idx=305 (trial=2, fold=5, lamU=2, lamV=2, cc=5)
# combos:  51%|█████     | 306/600 [1:04:24<1:00:42, 12.39s/it]2026-04-24 17:05:54,604 INFO: Running combo_idx=306 (trial=2, fold=5, lamU=2, lamV=2, cc=5)
# combos:  51%|█████     | 307/600 [1:04:37<1:00:32, 12.40s/it]2026-04-24 17:06:07,021 INFO: Running combo_idx=307 (trial=2, fold=5, lamU=2, lamV=2, cc=5)
# combos:  51%|█████▏    | 308/600 [1:04:50<1:01:53, 12.72s/it]2026-04-24 17:06:20,490 INFO: Running combo_idx=308 (trial=2, fold=5, lamU=2, lamV=2, cc=10)
# combos:  52%|█████▏    | 309/600 [1:05:03<1:01:17, 12.64s/it]2026-04-24 17:06:32,939 INFO: Running combo_idx=309 (trial=2, fold=5, lamU=2, lamV=2, cc=10)
# combos:  52%|█████▏    | 310/600 [1:05:15<1:00:40, 12.55s/it]2026-04-24 17:06:45,301 INFO: Running combo_idx=310 (trial=2, fold=5, lamU=2, lamV=2, cc=10)
# combos:  52%|█████▏    | 311/600 [1:05:27<1:00:30, 12.56s/it]2026-04-24 17:06:57,879 INFO: Running combo_idx=311 (trial=2, fold=5, lamU=2, lamV=2, cc=10)
# combos:  52%|█████▏    | 312/600 [1:05:40<1:00:13, 12.55s/it]2026-04-24 17:07:10,397 INFO: Running combo_idx=312 (trial=2, fold=6, lamU=2, lamV=2, cc=1)
# combos:  52%|█████▏    | 313/600 [1:05:53<1:00:42, 12.69s/it]2026-04-24 17:07:23,426 INFO: Running combo_idx=313 (trial=2, fold=6, lamU=2, lamV=2, cc=1)
# combos:  52%|█████▏    | 314/600 [1:06:06<1:01:06, 12.82s/it]2026-04-24 17:07:36,542 INFO: Running combo_idx=314 (trial=2, fold=6, lamU=2, lamV=2, cc=1)
# combos:  52%|█████▎    | 315/600 [1:06:19<1:00:31, 12.74s/it]2026-04-24 17:07:49,107 INFO: Running combo_idx=315 (trial=2, fold=6, lamU=2, lamV=2, cc=1)
# combos:  53%|█████▎    | 316/600 [1:06:31<59:36, 12.59s/it]  2026-04-24 17:08:01,356 INFO: Running combo_idx=316 (trial=2, fold=6, lamU=2, lamV=2, cc=5)
# ...
# combos:  82%|████████▎ | 495/600 [1:44:00<21:58, 12.56s/it]2026-04-24 17:45:30,424 INFO: Running combo_idx=495 (trial=4, fold=1, lamU=2, lamV=2, cc=1)
# combos:  83%|████████▎ | 496/600 [1:44:12<21:26, 12.37s/it]2026-04-24 17:45:42,346 INFO: Running combo_idx=496 (trial=4, fold=1, lamU=2, lamV=2, cc=5)
# combos:  83%|████████▎ | 497/600 [1:44:25<21:35, 12.58s/it]2026-04-24 17:45:55,408 INFO: Running combo_idx=497 (trial=4, fold=1, lamU=2, lamV=2, cc=5)
# combos:  83%|████████▎ | 498/600 [1:44:38<21:39, 12.74s/it]2026-04-24 17:46:08,521 INFO: Running combo_idx=498 (trial=4, fold=1, lamU=2, lamV=2, cc=5)
# combos:  83%|████████▎ | 499/600 [1:44:52<22:08, 13.15s/it]2026-04-24 17:46:22,644 INFO: Running combo_idx=499 (trial=4, fold=1, lamU=2, lamV=2, cc=5)
# combos:  83%|████████▎ | 500/600 [1:45:06<22:08, 13.28s/it]2026-04-24 17:46:36,235 INFO: Running combo_idx=500 (trial=4, fold=1, lamU=2, lamV=2, cc=10)
# combos:  84%|████████▎ | 501/600 [1:45:18<21:33, 13.07s/it]2026-04-24 17:46:48,804 INFO: Running combo_idx=501 (trial=4, fold=1, lamU=2, lamV=2, cc=10)
# combos:  84%|████████▎ | 502/600 [1:45:30<20:29, 12.54s/it]2026-04-24 17:47:00,125 INFO: Running combo_idx=502 (trial=4, fold=1, lamU=2, lamV=2, cc=10)
# combos:  84%|████████▍ | 503/600 [1:45:42<20:01, 12.39s/it]2026-04-24 17:47:12,138 INFO: Running combo_idx=503 (trial=4, fold=1, lamU=2, lamV=2, cc=10)
# combos:  84%|████████▍ | 504/600 [1:45:54<19:54, 12.44s/it]2026-04-24 17:47:24,714 INFO: Running combo_idx=504 (trial=4, fold=2, lamU=2, lamV=2, cc=1)
# combos:  84%|████████▍ | 505/600 [1:46:08<20:08, 12.73s/it]2026-04-24 17:47:38,100 INFO: Running combo_idx=505 (trial=4, fold=2, lamU=2, lamV=2, cc=1)
# combos:  84%|████████▍ | 506/600 [1:46:21<20:25, 13.04s/it]2026-04-24 17:47:51,861 INFO: Running combo_idx=506 (trial=4, fold=2, lamU=2, lamV=2, cc=1)
# combos:  84%|████████▍ | 507/600 [1:46:36<20:52, 13.47s/it]2026-04-24 17:48:06,353 INFO: Running combo_idx=507 (trial=4, fold=2, lamU=2, lamV=2, cc=1)
# combos:  85%|████████▍ | 508/600 [1:46:50<20:46, 13.55s/it]2026-04-24 17:48:20,071 INFO: Running combo_idx=508 (trial=4, fold=2, lamU=2, lamV=2, cc=5)
# combos:  85%|████████▍ | 509/600 [1:47:02<19:52, 13.10s/it]2026-04-24 17:48:32,141 INFO: Running combo_idx=509 (trial=4, fold=2, lamU=2, lamV=2, cc=5)
# combos:  85%|████████▌ | 510/600 [1:47:13<18:49, 12.55s/it]2026-04-24 17:48:43,415 INFO: Running combo_idx=510 (trial=4, fold=2, lamU=2, lamV=2, cc=5)
# combos:  85%|████████▌ | 511/600 [1:47:25<18:28, 12.45s/it]2026-04-24 17:48:55,635 INFO: Running combo_idx=511 (trial=4, fold=2, lamU=2, lamV=2, cc=5)
# combos:  85%|████████▌ | 512/600 [1:47:39<18:51, 12.85s/it]2026-04-24 17:49:09,419 INFO: Running combo_idx=512 (trial=4, fold=2, lamU=2, lamV=2, cc=10)
# combos:  86%|████████▌ | 513/600 [1:47:52<18:52, 13.02s/it]2026-04-24 17:49:22,834 INFO: Running combo_idx=513 (trial=4, fold=2, lamU=2, lamV=2, cc=10)
# combos:  86%|████████▌ | 514/600 [1:48:06<18:48, 13.13s/it]2026-04-24 17:49:36,208 INFO: Running combo_idx=514 (trial=4, fold=2, lamU=2, lamV=2, cc=10)
# combos:  86%|████████▌ | 515/600 [1:48:19<18:36, 13.13s/it]2026-04-24 17:49:49,349 INFO: Running combo_idx=515 (trial=4, fold=2, lamU=2, lamV=2, cc=10)
# combos:  86%|████████▌ | 516/600 [1:48:31<18:07, 12.94s/it]2026-04-24 17:50:01,845 INFO: Running combo_idx=516 (trial=4, fold=3, lamU=2, lamV=2, cc=1)
# combos:  86%|████████▌ | 517/600 [1:48:42<16:52, 12.20s/it]2026-04-24 17:50:12,314 INFO: Running combo_idx=517 (trial=4, fold=3, lamU=2, lamV=2, cc=1)
# combos:  86%|████████▋ | 518/600 [1:48:53<16:08, 11.81s/it]2026-04-24 17:50:23,212 INFO: Running combo_idx=518 (trial=4, fold=3, lamU=2, lamV=2, cc=1)
# combos:  86%|████████▋ | 519/600 [1:49:05<15:58, 11.83s/it]2026-04-24 17:50:35,099 INFO: Running combo_idx=519 (trial=4, fold=3, lamU=2, lamV=2, cc=1)
# combos:  87%|████████▋ | 520/600 [1:49:18<16:24, 12.31s/it]2026-04-24 17:50:48,515 INFO: Running combo_idx=520 (trial=4, fold=3, lamU=2, lamV=2, cc=5)
# combos:  87%|████████▋ | 521/600 [1:49:32<16:39, 12.65s/it]2026-04-24 17:51:01,952 INFO: Running combo_idx=521 (trial=4, fold=3, lamU=2, lamV=2, cc=5)
# combos:  87%|████████▋ | 522/600 [1:49:44<16:33, 12.74s/it]2026-04-24 17:51:14,897 INFO: Running combo_idx=522 (trial=4, fold=3, lamU=2, lamV=2, cc=5)
# combos:  87%|████████▋ | 523/600 [1:49:57<16:13, 12.65s/it]2026-04-24 17:51:27,332 INFO: Running combo_idx=523 (trial=4, fold=3, lamU=2, lamV=2, cc=5)
# combos:  87%|████████▋ | 524/600 [1:50:09<15:43, 12.42s/it]2026-04-24 17:51:39,216 INFO: Running combo_idx=524 (trial=4, fold=3, lamU=2, lamV=2, cc=10)
# combos:  88%|████████▊ | 525/600 [1:50:20<15:07, 12.10s/it]2026-04-24 17:51:50,592 INFO: Running combo_idx=525 (trial=4, fold=3, lamU=2, lamV=2, cc=10)
# combos:  88%|████████▊ | 526/600 [1:50:34<15:26, 12.52s/it]2026-04-24 17:52:04,066 INFO: Running combo_idx=526 (trial=4, fold=3, lamU=2, lamV=2, cc=10)
# combos:  88%|████████▊ | 527/600 [1:50:47<15:34, 12.80s/it]2026-04-24 17:52:17,545 INFO: Running combo_idx=527 (trial=4, fold=3, lamU=2, lamV=2, cc=10)
# combos:  88%|████████▊ | 528/600 [1:51:01<15:39, 13.05s/it]2026-04-24 17:52:31,171 INFO: Running combo_idx=528 (trial=4, fold=4, lamU=2, lamV=2, cc=1)
# combos:  88%|████████▊ | 529/600 [1:51:12<14:47, 12.50s/it]2026-04-24 17:52:42,385 INFO: Running combo_idx=529 (trial=4, fold=4, lamU=2, lamV=2, cc=1)
# combos:  88%|████████▊ | 530/600 [1:51:23<13:58, 11.98s/it]2026-04-24 17:52:53,163 INFO: Running combo_idx=530 (trial=4, fold=4, lamU=2, lamV=2, cc=1)
# combos:  88%|████████▊ | 531/600 [1:51:34<13:35, 11.82s/it]2026-04-24 17:53:04,609 INFO: Running combo_idx=531 (trial=4, fold=4, lamU=2, lamV=2, cc=1)
# combos:  89%|████████▊ | 532/600 [1:51:47<13:51, 12.22s/it]2026-04-24 17:53:17,769 INFO: Running combo_idx=532 (trial=4, fold=4, lamU=2, lamV=2, cc=5)
# combos:  89%|████████▉ | 533/600 [1:52:01<14:05, 12.61s/it]2026-04-24 17:53:31,294 INFO: Running combo_idx=533 (trial=4, fold=4, lamU=2, lamV=2, cc=5)
# combos:  89%|████████▉ | 534/600 [1:52:14<13:57, 12.69s/it]2026-04-24 17:53:44,169 INFO: Running combo_idx=534 (trial=4, fold=4, lamU=2, lamV=2, cc=5)
# combos:  89%|████████▉ | 535/600 [1:52:27<13:54, 12.84s/it]2026-04-24 17:53:57,357 INFO: Running combo_idx=535 (trial=4, fold=4, lamU=2, lamV=2, cc=5)
# combos:  89%|████████▉ | 536/600 [1:52:40<13:41, 12.84s/it]2026-04-24 17:54:10,199 INFO: Running combo_idx=536 (trial=4, fold=4, lamU=2, lamV=2, cc=10)
# combos:  90%|████████▉ | 537/600 [1:52:51<12:55, 12.31s/it]2026-04-24 17:54:21,270 INFO: Running combo_idx=537 (trial=4, fold=4, lamU=2, lamV=2, cc=10)
# combos:  90%|████████▉ | 538/600 [1:53:03<12:39, 12.25s/it]2026-04-24 17:54:33,379 INFO: Running combo_idx=538 (trial=4, fold=4, lamU=2, lamV=2, cc=10)
# combos:  90%|████████▉ | 539/600 [1:53:17<12:59, 12.78s/it]2026-04-24 17:54:47,405 INFO: Running combo_idx=539 (trial=4, fold=4, lamU=2, lamV=2, cc=10)
# combos:  90%|█████████ | 540/600 [1:53:31<13:05, 13.09s/it]2026-04-24 17:55:01,224 INFO: Running combo_idx=540 (trial=4, fold=5, lamU=2, lamV=2, cc=1)
# combos:  90%|█████████ | 541/600 [1:53:44<12:48, 13.02s/it]2026-04-24 17:55:14,067 INFO: Running combo_idx=541 (trial=4, fold=5, lamU=2, lamV=2, cc=1)
# combos:  90%|█████████ | 542/600 [1:53:56<12:26, 12.88s/it]2026-04-24 17:55:26,610 INFO: Running combo_idx=542 (trial=4, fold=5, lamU=2, lamV=2, cc=1)
# combos:  90%|█████████ | 543/600 [1:54:09<12:09, 12.80s/it]2026-04-24 17:55:39,226 INFO: Running combo_idx=543 (trial=4, fold=5, lamU=2, lamV=2, cc=1)
# combos:  91%|█████████ | 544/600 [1:54:21<11:41, 12.52s/it]2026-04-24 17:55:51,115 INFO: Running combo_idx=544 (trial=4, fold=5, lamU=2, lamV=2, cc=5)
# combos:  91%|█████████ | 545/600 [1:54:33<11:26, 12.48s/it]2026-04-24 17:56:03,482 INFO: Running combo_idx=545 (trial=4, fold=5, lamU=2, lamV=2, cc=5)
# combos:  91%|█████████ | 546/600 [1:54:46<11:28, 12.74s/it]2026-04-24 17:56:16,839 INFO: Running combo_idx=546 (trial=4, fold=5, lamU=2, lamV=2, cc=5)
# combos:  91%|█████████ | 547/600 [1:54:59<11:17, 12.79s/it]2026-04-24 17:56:29,732 INFO: Running combo_idx=547 (trial=4, fold=5, lamU=2, lamV=2, cc=5)
# combos:  91%|█████████▏| 548/600 [1:55:12<10:56, 12.63s/it]2026-04-24 17:56:41,994 INFO: Running combo_idx=548 (trial=4, fold=5, lamU=2, lamV=2, cc=10)
# combos:  92%|█████████▏| 549/600 [1:55:22<10:10, 11.96s/it]2026-04-24 17:56:52,401 INFO: Running combo_idx=549 (trial=4, fold=5, lamU=2, lamV=2, cc=10)
# combos:  92%|█████████▏| 550/600 [1:55:33<09:46, 11.74s/it]2026-04-24 17:57:03,608 INFO: Running combo_idx=550 (trial=4, fold=5, lamU=2, lamV=2, cc=10)
# combos:  92%|█████████▏| 551/600 [1:55:46<09:45, 11.96s/it]2026-04-24 17:57:16,082 INFO: Running combo_idx=551 (trial=4, fold=5, lamU=2, lamV=2, cc=10)
# combos:  92%|█████████▏| 552/600 [1:55:59<09:55, 12.41s/it]2026-04-24 17:57:29,539 INFO: Running combo_idx=552 (trial=4, fold=6, lamU=2, lamV=2, cc=1)
# combos:  92%|█████████▏| 553/600 [1:56:12<09:51, 12.58s/it]2026-04-24 17:57:42,537 INFO: Running combo_idx=553 (trial=4, fold=6, lamU=2, lamV=2, cc=1)
# combos:  92%|█████████▏| 554/600 [1:56:25<09:42, 12.66s/it]2026-04-24 17:57:55,379 INFO: Running combo_idx=554 (trial=4, fold=6, lamU=2, lamV=2, cc=1)
# combos:  92%|█████████▎| 555/600 [1:56:37<09:19, 12.43s/it]2026-04-24 17:58:07,264 INFO: Running combo_idx=555 (trial=4, fold=6, lamU=2, lamV=2, cc=1)
# combos:  93%|█████████▎| 556/600 [1:56:48<08:52, 12.11s/it]2026-04-24 17:58:18,625 INFO: Running combo_idx=556 (trial=4, fold=6, lamU=2, lamV=2, cc=5)
# combos:  93%|█████████▎| 557/600 [1:56:59<08:27, 11.81s/it]2026-04-24 17:58:29,732 INFO: Running combo_idx=557 (trial=4, fold=6, lamU=2, lamV=2, cc=5)
# combos:  93%|█████████▎| 558/600 [1:57:12<08:22, 11.97s/it]2026-04-24 17:58:42,098 INFO: Running combo_idx=558 (trial=4, fold=6, lamU=2, lamV=2, cc=5)
# combos:  93%|█████████▎| 559/600 [1:57:26<08:33, 12.54s/it]2026-04-24 17:58:55,938 INFO: Running combo_idx=559 (trial=4, fold=6, lamU=2, lamV=2, cc=5)
# combos:  93%|█████████▎| 560/600 [1:57:40<08:48, 13.22s/it]2026-04-24 17:59:10,754 INFO: Running combo_idx=560 (trial=4, fold=6, lamU=2, lamV=2, cc=10)
# combos:  94%|█████████▎| 561/600 [1:57:53<08:26, 12.99s/it]2026-04-24 17:59:23,208 INFO: Running combo_idx=561 (trial=4, fold=6, lamU=2, lamV=2, cc=10)
# combos:  94%|█████████▎| 562/600 [1:58:04<07:50, 12.37s/it]2026-04-24 17:59:34,143 INFO: Running combo_idx=562 (trial=4, fold=6, lamU=2, lamV=2, cc=10)
# combos:  94%|█████████▍| 563/600 [1:58:16<07:36, 12.33s/it]2026-04-24 17:59:46,373 INFO: Running combo_idx=563 (trial=4, fold=6, lamU=2, lamV=2, cc=10)
# combos:  94%|█████████▍| 564/600 [1:58:30<07:41, 12.83s/it]2026-04-24 18:00:00,370 INFO: Running combo_idx=564 (trial=4, fold=7, lamU=2, lamV=2, cc=1)
# combos:  94%|█████████▍| 565/600 [1:58:42<07:21, 12.61s/it]2026-04-24 18:00:12,478 INFO: Running combo_idx=565 (trial=4, fold=7, lamU=2, lamV=2, cc=1)
# combos:  94%|█████████▍| 566/600 [1:58:54<06:59, 12.35s/it]2026-04-24 18:00:24,206 INFO: Running combo_idx=566 (trial=4, fold=7, lamU=2, lamV=2, cc=1)
# combos:  94%|█████████▍| 567/600 [1:59:06<06:45, 12.28s/it]2026-04-24 18:00:36,320 INFO: Running combo_idx=567 (trial=4, fold=7, lamU=2, lamV=2, cc=1)
# combos:  95%|█████████▍| 568/600 [1:59:18<06:28, 12.13s/it]2026-04-24 18:00:48,101 INFO: Running combo_idx=568 (trial=4, fold=7, lamU=2, lamV=2, cc=5)
# combos:  95%|█████████▍| 569/600 [1:59:31<06:26, 12.46s/it]2026-04-24 18:01:01,317 INFO: Running combo_idx=569 (trial=4, fold=7, lamU=2, lamV=2, cc=5)
# combos:  95%|█████████▌| 570/600 [1:59:45<06:25, 12.84s/it]2026-04-24 18:01:15,060 INFO: Running combo_idx=570 (trial=4, fold=7, lamU=2, lamV=2, cc=5)
# combos:  95%|█████████▌| 571/600 [1:59:58<06:12, 12.85s/it]2026-04-24 18:01:27,937 INFO: Running combo_idx=571 (trial=4, fold=7, lamU=2, lamV=2, cc=5)
# combos:  95%|█████████▌| 572/600 [2:00:09<05:51, 12.56s/it]2026-04-24 18:01:39,822 INFO: Running combo_idx=572 (trial=4, fold=7, lamU=2, lamV=2, cc=10)
# combos:  96%|█████████▌| 573/600 [2:00:21<05:31, 12.27s/it]2026-04-24 18:01:51,427 INFO: Running combo_idx=573 (trial=4, fold=7, lamU=2, lamV=2, cc=10)
# combos:  96%|█████████▌| 574/600 [2:00:34<05:26, 12.55s/it]2026-04-24 18:02:04,615 INFO: Running combo_idx=574 (trial=4, fold=7, lamU=2, lamV=2, cc=10)
# combos:  96%|█████████▌| 575/600 [2:00:48<05:23, 12.95s/it]2026-04-24 18:02:18,515 INFO: Running combo_idx=575 (trial=4, fold=7, lamU=2, lamV=2, cc=10)
# combos:  96%|█████████▌| 576/600 [2:01:01<05:10, 12.93s/it]2026-04-24 18:02:31,387 INFO: Running combo_idx=576 (trial=4, fold=8, lamU=2, lamV=2, cc=1)
# combos:  96%|█████████▌| 577/600 [2:01:12<04:45, 12.43s/it]2026-04-24 18:02:42,645 INFO: Running combo_idx=577 (trial=4, fold=8, lamU=2, lamV=2, cc=1)
# combos:  96%|█████████▋| 578/600 [2:01:24<04:29, 12.27s/it]2026-04-24 18:02:54,542 INFO: Running combo_idx=578 (trial=4, fold=8, lamU=2, lamV=2, cc=1)
# combos:  96%|█████████▋| 579/600 [2:01:38<04:28, 12.77s/it]2026-04-24 18:03:08,486 INFO: Running combo_idx=579 (trial=4, fold=8, lamU=2, lamV=2, cc=1)
# combos:  97%|█████████▋| 580/600 [2:01:52<04:19, 12.98s/it]2026-04-24 18:03:21,948 INFO: Running combo_idx=580 (trial=4, fold=8, lamU=2, lamV=2, cc=5)
# combos:  97%|█████████▋| 581/600 [2:02:04<04:05, 12.92s/it]2026-04-24 18:03:34,713 INFO: Running combo_idx=581 (trial=4, fold=8, lamU=2, lamV=2, cc=5)
# combos:  97%|█████████▋| 582/600 [2:02:16<03:46, 12.57s/it]2026-04-24 18:03:46,483 INFO: Running combo_idx=582 (trial=4, fold=8, lamU=2, lamV=2, cc=5)
# combos:  97%|█████████▋| 583/600 [2:02:28<03:27, 12.23s/it]2026-04-24 18:03:57,924 INFO: Running combo_idx=583 (trial=4, fold=8, lamU=2, lamV=2, cc=5)
# combos:  97%|█████████▋| 584/600 [2:02:39<03:14, 12.15s/it]2026-04-24 18:04:09,896 INFO: Running combo_idx=584 (trial=4, fold=8, lamU=2, lamV=2, cc=10)
# combos:  98%|█████████▊| 585/600 [2:02:52<03:05, 12.39s/it]2026-04-24 18:04:22,842 INFO: Running combo_idx=585 (trial=4, fold=8, lamU=2, lamV=2, cc=10)
# combos:  98%|█████████▊| 586/600 [2:03:06<03:00, 12.86s/it]2026-04-24 18:04:36,787 INFO: Running combo_idx=586 (trial=4, fold=8, lamU=2, lamV=2, cc=10)
# combos:  98%|█████████▊| 587/600 [2:03:20<02:50, 13.08s/it]2026-04-24 18:04:50,389 INFO: Running combo_idx=587 (trial=4, fold=8, lamU=2, lamV=2, cc=10)
# combos:  98%|█████████▊| 588/600 [2:03:33<02:37, 13.09s/it]2026-04-24 18:05:03,507 INFO: Running combo_idx=588 (trial=4, fold=9, lamU=2, lamV=2, cc=1)
# combos:  98%|█████████▊| 589/600 [2:03:44<02:16, 12.39s/it]2026-04-24 18:05:14,251 INFO: Running combo_idx=589 (trial=4, fold=9, lamU=2, lamV=2, cc=1)
# combos:  98%|█████████▊| 590/600 [2:03:55<02:00, 12.05s/it]2026-04-24 18:05:25,498 INFO: Running combo_idx=590 (trial=4, fold=9, lamU=2, lamV=2, cc=1)
# combos:  98%|█████████▊| 591/600 [2:04:08<01:51, 12.39s/it]2026-04-24 18:05:38,676 INFO: Running combo_idx=591 (trial=4, fold=9, lamU=2, lamV=2, cc=1)
# combos:  99%|█████████▊| 592/600 [2:04:22<01:41, 12.65s/it]2026-04-24 18:05:51,939 INFO: Running combo_idx=592 (trial=4, fold=9, lamU=2, lamV=2, cc=5)
# combos:  99%|█████████▉| 593/600 [2:04:33<01:26, 12.31s/it]2026-04-24 18:06:03,466 INFO: Running combo_idx=593 (trial=4, fold=9, lamU=2, lamV=2, cc=5)
# combos:  99%|█████████▉| 594/600 [2:04:45<01:13, 12.32s/it]2026-04-24 18:06:15,804 INFO: Running combo_idx=594 (trial=4, fold=9, lamU=2, lamV=2, cc=5)
# combos:  99%|█████████▉| 595/600 [2:04:57<01:00, 12.12s/it]2026-04-24 18:06:27,448 INFO: Running combo_idx=595 (trial=4, fold=9, lamU=2, lamV=2, cc=5)
# combos:  99%|█████████▉| 596/600 [2:05:12<00:51, 12.95s/it]2026-04-24 18:06:42,354 INFO: Running combo_idx=596 (trial=4, fold=9, lamU=2, lamV=2, cc=10)
# combos: 100%|█████████▉| 597/600 [2:05:25<00:38, 12.91s/it]2026-04-24 18:06:55,156 INFO: Running combo_idx=597 (trial=4, fold=9, lamU=2, lamV=2, cc=10)
# combos: 100%|█████████▉| 598/600 [2:05:37<00:25, 12.59s/it]2026-04-24 18:07:07,017 INFO: Running combo_idx=598 (trial=4, fold=9, lamU=2, lamV=2, cc=10)
# combos: 100%|█████████▉| 599/600 [2:05:48<00:12, 12.28s/it]2026-04-24 18:07:18,568 INFO: Running combo_idx=599 (trial=4, fold=9, lamU=2, lamV=2, cc=10)
# combos: 100%|██████████| 600/600 [2:06:00<00:00, 12.60s/it]

# %%
# ====== save results ======
outfile = os.path.join(PATH_OUTPUT, f"{filenames['output']}.gz")

# archive any existing file so we don't silently overwrite a previous run
if os.path.exists(outfile):
    import time as _time

    mdttm = _time.strftime("%Y%m%d_%H%M%S")
    archived = os.path.join(PATH_ARCHIVE, f"{mdttm}_{os.path.basename(outfile)}")
    os.rename(outfile, archived)
    logging.info("Archived existing output to %s", archived)

logging.info("Saving %d result rows to %s", len(task_results), outfile)
with gzip.open(outfile, "wb+", 4) as fout:
    pickle.dump(task_results, fout)

logging.info("Local run finished.")
# Out:
# 2026-04-25 17:23:11,509 INFO: Archived existing output to /Users/sijianfan/projects/BiSSGL/outputs/results/realAnalysis/cdataset/fold_cv/origin/archived/20260425_172311_results_drimc.gz
# 2026-04-25 17:23:11,510 INFO: Saving 1800 result rows to /Users/sijianfan/projects/BiSSGL/outputs/results/realAnalysis/cdataset/fold_cv/origin/results_drimc.gz
# 2026-04-25 17:23:11,540 INFO: Local run finished.
