# %% [markdown]
# # Run DRIMC

# %%
import os
import time
import gzip
import pickle
import warnings

# %matplotlib inline
import matplotlib.pyplot as plt

import numpy as np

from tqdm import TqdmSynchronisationWarning
warnings.simplefilter("ignore", TqdmSynchronisationWarning)

# %%
PATH_ROOT = "/Users/sijianfan/Documents/projects/BiSSGL"
PATH_DATA = os.path.join(PATH_ROOT, "datasets/realAnalysis/cdataset/cv_data")

PATH_OUTPUT = os.path.join(PATH_ROOT, "outputs/results/realAnalysis/cdataset/separate")
if not os.path.isdir(PATH_OUTPUT):
    os.makedirs(PATH_OUTPUT)

PATH_ARCHIVE = os.path.join(PATH_OUTPUT, "archived")
if not os.path.isdir(PATH_ARCHIVE):
    os.makedirs(PATH_ARCHIVE)

# %%
filename_staged = os.path.join(PATH_DATA, "staged_dataset.gz")

filenames = {"input": "staged_dataset.gz", "output": "results_drimc.gz"}

# %%
filename_input = os.path.join(PATH_DATA, filenames["input"])

filename_output = os.path.join(PATH_OUTPUT, filenames["output"])

if os.path.exists(filename_output):
    mdttm = time.strftime("%Y%m%d_%H%M%S")
    os.rename(
        filename_output,
        os.path.join(PATH_ARCHIVE, "%s%s" % (mdttm, filenames["output"])),
    )

# %%
from sgimc.utils import mc_split

# %%
from sgimc.utils import get_submatrix

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_auc_score
from sgimc.utils import sparsify_with_mask


def mc_get_scores(R_true, R_prob):
    R_pred = np.where(R_prob.data > 0.5, 1, -1)

    # compute the confusion matrix for ±1 labels (`-1` is negative)
    ii, jj = ((R_pred + 1) // 2).astype(int), ((R_true.data + 1) // 2).astype(int)
    cnfsn = confusion_matrix(y_true=jj, y_pred=ii)

    return {
        "tn": cnfsn[0, 0],
        "fn": cnfsn[1, 0],
        "fp": cnfsn[0, 1],
        "tp": cnfsn[1, 1],
        "auc": roc_auc_score(R_true.data, R_prob.data),
    }

# %%
import numpy as np


def get_metrics(real_score, predict_score):
    sorted_predict_score = np.array(
        sorted(list(set(np.array(predict_score).flatten())))
    )
    sorted_predict_score_num = len(sorted_predict_score)
    thresholds = sorted_predict_score[
        np.int32(sorted_predict_score_num * np.arange(1, 1000) / 1000)
    ]
    thresholds = np.mat(thresholds)
    thresholds_num = thresholds.shape[1]

    predict_score_matrix = np.tile(predict_score, (thresholds_num, 1))
    negative_index = np.where(predict_score_matrix < thresholds.T)
    positive_index = np.where(predict_score_matrix >= thresholds.T)
    predict_score_matrix[negative_index] = 0
    predict_score_matrix[positive_index] = 1
    TP = predict_score_matrix.dot(real_score.T)
    FP = predict_score_matrix.sum(axis=1) - TP
    FN = real_score.sum() - TP
    TN = len(real_score.T) - TP - FP - FN

    fpr = FP / (FP + TN)
    tpr = TP / (TP + FN)
    ROC_dot_matrix = np.mat(sorted(np.column_stack((fpr, tpr)).tolist())).T
    ROC_dot_matrix.T[0] = [0, 0]
    ROC_dot_matrix = np.c_[ROC_dot_matrix, [1, 1]]
    x_ROC = ROC_dot_matrix[0].T
    y_ROC = ROC_dot_matrix[1].T
    auc = 0.5 * (x_ROC[1:] - x_ROC[:-1]).T * (y_ROC[:-1] + y_ROC[1:])

    recall_list = tpr
    precision_list = TP / (TP + FP)
    PR_dot_matrix = np.mat(
        sorted(np.column_stack((recall_list, precision_list)).tolist())
    ).T
    PR_dot_matrix.T[0] = [0, 1]
    PR_dot_matrix = np.c_[PR_dot_matrix, [1, 0]]
    x_PR = PR_dot_matrix[0].T
    y_PR = PR_dot_matrix[1].T
    aupr = 0.5 * (x_PR[1:] - x_PR[:-1]).T * (y_PR[:-1] + y_PR[1:])

    f1_score_list = 2 * TP / (len(real_score.T) + TP - TN)
    accuracy_list = (TP + TN) / len(real_score.T)
    specificity_list = TN / (TN + FP)

    max_index = np.argmax(f1_score_list)
    f1_score = f1_score_list[max_index]
    accuracy = accuracy_list[max_index]
    specificity = specificity_list[max_index]
    recall = recall_list[max_index]
    precision = precision_list[max_index]
    return [aupr[0, 0], auc[0, 0], f1_score, accuracy, recall, specificity, precision]

# %%
random_state = np.random.RandomState(0x0BADCAFE)

# %% [markdown]
# ## Import model

# %%
import rpy2.robjects as robjects

r = robjects.r

DRIMC_path = "/Users/sijianfan/Documents/projects/BiSSGL/scripts/methods/DRIMC"
r(f'setwd("{DRIMC_path}")')
print(r("getwd()"))
# Out:
# [1] "/Users/sijianfan/Documents/projects/BiSSGL/scripts/methods/DRIMC"

# %%
pkgs = ["matrixcalc", "data.table", "Rcpp", "ROCR", "Bolstad2", "MESS"]
rPkgs = [r(f'require("{pkg}", character.only=TRUE)') for pkg in pkgs]
# Out:
# R callback write-console: Loading required package: matrixcalc
#
# R callback write-console: Loading required package: data.table
#
# R callback write-console: data.table 1.17.8 using 6 threads (see ?getDTthreads).
# R callback write-console: Latest news: r-datatable.com
#
# R callback write-console: Loading required package: Rcpp
#
# R callback write-console: Loading required package: ROCR
#
# R callback write-console: Loading required package: Bolstad2
#
# R callback write-console: Loading required package: MESS

# %%
rSourceNames = [
    "doCrossValidationByPairwise.R",
    "doCrossValidationByRow.R",
    "constrNeig.R",
    "inferZeros.R",
    "calcLogLik.R",
    "calcDeriv.R",
    "updateUV.R",
    "calcPredScore.R",
    "calcAUPR.R",
]
rSN = [r(f'source("{r_file}")') for r_file in rSourceNames]

# %%
r("library(Rcpp)")
cppSourceNames = [
    "fastKF2.cpp",
    "fastKF4.cpp",
    "fastKgipMat.cpp",
    "log1pexp.cpp",
    "sigmoid.cpp",
]
cppSN = [r(f'sourceCpp("{cpp_file}")') for cpp_file in cppSourceNames]

# %%
updateUV = r["updateUV"]

# %% [markdown]
# ## Load data

# %%
from sgimc.utils import load, save

U, V, Y = load(filename_input)

Y = Y.astype(float)

# %% [markdown]
# ## Without selection

# %% [markdown]
# ### Prepare similarity matrix

# %%
# Quick prepare of similarity matrix
from sklearn.metrics.pairwise import cosine_similarity

simD = cosine_similarity(U[:, :])
simT = cosine_similarity(V[:, :])

# %%
# Jaccard distance → convert to similarity
from sklearn.metrics import pairwise_distances

simD = 1 - pairwise_distances(U.toarray(), metric="jaccard")
simT = 1 - pairwise_distances(V.toarray(), metric="jaccard")
# Out:
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/sklearn/metrics/pairwise.py:2182: DataConversionWarning: Data was converted to boolean for metric jaccard
#   warnings.warn(msg, DataConversionWarning)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/sklearn/metrics/pairwise.py:2182: DataConversionWarning: Data was converted to boolean for metric jaccard
#   warnings.warn(msg, DataConversionWarning)

# %%
simD_Robj = r.matrix(
    robjects.FloatVector(simD.flatten()),
    byrow=True,
    nrow=simD.shape[0],
    ncol=simD.shape[0],
)
simT_Robj = r.matrix(
    robjects.FloatVector(simT.flatten()),
    byrow=True,
    nrow=simT.shape[0],
    ncol=simT.shape[0],
)

# %%
constrNeig = r["constrNeig"]

# %%
# Use neighorhood size K = 3
lap = constrNeig(simD_Robj, simT_Robj, K=3)
simD_Robj, simT_Robj = lap[2], lap[3]
simD, simT = np.array(simD), np.array(simT)

# %%
simD.shape, simT.shape
# Out:
# ((658, 658), (409, 409))

# %% [markdown]
# ### Implementation

# %%
dvlp_size, test_size = 0.9, 0.1

ind_dvlp, ind_test = next(
    mc_split(
        Y,
        n_splits=1,
        random_state=random_state,
        train_size=dvlp_size,
        test_size=test_size,
    )
)

Y_test = get_submatrix(Y, ind_test)

# %%
from sklearn.model_selection import ParameterGrid

grid_dataset = ParameterGrid(
    {
        "train_size": np.arange(0.1, 0.9, 0.1),
        # "train_size": [0.8],
        "n_splits": [5],
    }
)

grid_model = ParameterGrid(
    {
        "lamU": [2],
        "lamV": [2],
        "cc": [1, 3, 5, 7, 9],  # confidence parameter
        # "cc": [1],
        "iterpara": [0.125],  # learning rate
        "numLat": [200],  # rank
    }
)

# %%
from tqdm import tqdm
from sklearn.model_selection import ShuffleSplit, KFold
from sklearn.model_selection import train_test_split
from scipy.special import expit


results = []
for par_dtst in tqdm(grid_dataset):
    # prepare the train dataset: take the specified share from the beginnig of the index array
    ind_train_all, _ = train_test_split(
        ind_dvlp,
        shuffle=False,
        random_state=random_state,
        test_size=(1 - (par_dtst["train_size"] / dvlp_size)),
    )

    # Run the experiment: the model
    for par_mdl in grid_model:  # tqdm.tqdm(, desc="cv %02d" % (cv,))
        Y_train = get_submatrix(Y, ind_train_all)

        # Y_train[Y_train == 0] = 0.5
        Y_train[Y_train == -1] = 0.0

        Y_train_Robj = r.matrix(
            robjects.FloatVector(Y_train.toarray().flatten()),
            byrow=True,
            nrow=Y_train.shape[0],
            ncol=Y_train.shape[1],
        )

        # set up the model
        lamU, lamV, cc, iterpara, numLat = (
            par_mdl["lamU"],
            par_mdl["lamV"],
            par_mdl["cc"],
            par_mdl["iterpara"],
            par_mdl["numLat"],
        )

        out = updateUV(
            cc=cc,
            inMat=Y_train_Robj,
            Sd=simD_Robj,
            St=simT_Robj,
            lamU=lamU,
            lamV=lamV,
            numLat=numLat,
            initMethod="useSeed",
            thisSeed=123,
            iterpara=iterpara,
            maxIter=1000,
        )

        # fit on the whole development dataset
        est_A, est_B = np.array(out[0]), np.array(out[1])

        # get the score
        prob_full = expit(simD @ est_A @ est_B.T @ simT.T)
        prob_test = get_submatrix(prob_full, ind_test)
        # scores_test = mc_get_scores(Y_test, prob_test)
        scores_test = get_metrics((Y_test.data + 1) / 2, prob_test.data)
        d1_test = sum(abs(est_A).max(axis=1) > 0)
        d2_test = sum(abs(est_B).max(axis=1) > 0)

        # record the results
        results.append(
            {
                "train_size": par_dtst["train_size"],
                "lamU": par_mdl["lamU"],
                "lamV": par_mdl["lamV"],
                "cc": par_mdl["cc"],
                "iterpara": par_mdl["iterpara"],
                "numLat": par_mdl["numLat"],
                "test_score": scores_test,
                "test_d1": d1_test,
                "test_d2": d2_test,
            }
        )
# Out:
# 100%|██████████| 8/8 [01:10<00:00,  8.82s/it]

# %%
plt.plot(out[3])

# %%
results
# Out:
# [{'train_size': 0.1,
#   'lamU': 2,
#   'lamV': 2,
#   'cc': 1,
#   'iterpara': 0.125,
#   'numLat': 200,
#   'test_score': [0.005671498743792416,
#    0.5116635977007958,
#    0.019397651863195507,
#    0.8572437112176272,
#    0.16593886462882096,
#    0.8631764353170439,
#    0.010300894551368935],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.1,
#   'lamU': 2,
#   'lamV': 2,
#   'cc': 3,
#   'iterpara': 0.125,
#   'numLat': 200,
#   'test_score': [0.005678995419160208,
#    0.5117355214743605,
#    0.019432773109243698,
#    0.8612566417716345,
#    0.1615720524017467,
#    0.8672612801678908,
#    0.010338083263481419],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.1,
#   'lamU': 2,
#   'lamV': 2,
#   'cc': 5,
#   'iterpara': 0.125,
#   'numLat': 200,
#   'test_score': [0.0056761503697964144,
#    0.5117537683475173,
#    0.01955085865257596,
#    0.8621112473525805,
#    0.1615720524017467,
#    0.8681232199070604,
#    0.010404949381327334],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.1,
#   'lamU': 2,
#   'lamV': 2,
#   'cc': 7,
#   'iterpara': 0.125,
#   'numLat': 200,
#   'test_score': [0.005678917060530964,
#    0.5117652237835799,
#    0.01956636700158646,
#    0.8622227176457474,
#    0.1615720524017467,
#    0.8682356468295608,
#    0.010413734871939206],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.1,
#   'lamU': 2,
#   'lamV': 2,
#   'cc': 9,
#   'iterpara': 0.125,
#   'numLat': 200,
#   'test_score': [0.005676661038204427,
#    0.5117786430086818,
#    0.019576719576719578,
#    0.8622970311745253,
#    0.1615720524017467,
#    0.8683105981112277,
#    0.010419600112644326],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.2,
#   'lamU': 2,
#   'lamV': 2,
#   'cc': 1,
#   'iterpara': 0.125,
#   'numLat': 200,
#   'test_score': [0.005728453327878887,
#    0.5115531345673345,
#    0.01970954356846473,
#    0.8595474306097425,
#    0.16593886462882096,
#    0.8654999250487183,
#    0.010476978218913703],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.2,
#   'lamU': 2,
#   'lamV': 2,
#   'cc': 3,
#   'iterpara': 0.125,
#   'numLat': 200,
#   'test_score': [0.005792200815444931,
#    0.5116326680234267,
#    0.0199632256369845,
#    0.8613681120648014,
#    0.16593886462882096,
#    0.8673362314495577,
#    0.010620458356623811],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.2,
#   'lamU': 2,
#   'lamV': 2,
#   'cc': 5,
#   'iterpara': 0.125,
#   'numLat': 200,
#   'test_score': [0.005793406470204406,
#    0.5116996004998496,
#    0.01993704092339979,
#    0.8611823282428566,
#    0.16593886462882096,
#    0.8671488532453905,
#    0.010605637733742674],
#   'test_d1': 658,
#   'test_d2': 409},
#  {'train_size': 0.2,
#   'lamU': 2,
#   'lamV': 2,
#   'cc': 7,
#   'iterpara': 0.125,
#   'numLat': 200,
#   'test_score': [0.
# %%
with gzip.open(filename_output, "wb+", 4) as fout:
    pickle.dump(results, fout)

# %% [markdown]
# ---

# %% [markdown]
# ## With selection

# %%
from sgimc import SparseGroupIMCClassifier

C_lasso, C_group, C_ridge, rank = (0.0, 1.0, 1.0, 13)

imc = SparseGroupIMCClassifier(
    rank,
    n_threads=8,
    random_state=42,
    C_lasso=C_lasso,
    C_group=C_group,
    C_ridge=C_ridge,
)

# fit on the whole development dataset
Y_train = get_submatrix(Y, ind_train_all)
imc.fit(U, V, Y_train)

# get the score
prob_full = imc.predict_proba(U, V)
prob_test = get_submatrix(prob_full, ind_test)
scores_test = mc_get_scores(Y_test, prob_test)
d1_test = sum(abs(imc.coef_W_).max(axis=1) > 0)
d2_test = sum(abs(imc.coef_H_).max(axis=1) > 0)

print(scores_test, d1_test, d2_test)
# Out:
# {'tn': 5355, 'fn': 412, 'fp': 308, 'tp': 2959, 'auc': 0.9669303880105017} 1360 22

# %% [markdown]
# ### Prepare similarity matrix

# %%
# Jaccard distance → convert to similarity
from sklearn.metrics import pairwise_distances

simD = 1 - pairwise_distances(
    U[:, np.where(abs(imc.coef_W_).max(axis=1) > 0)[0]].toarray(), metric="jaccard"
)
simT = 1 - pairwise_distances(
    V[:, np.where(abs(imc.coef_H_).max(axis=1) > 0)[0]].toarray(), metric="jaccard"
)
# Out:
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/sklearn/metrics/pairwise.py:2182: DataConversionWarning: Data was converted to boolean for metric jaccard
#   warnings.warn(msg, DataConversionWarning)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/sklearn/metrics/pairwise.py:2182: DataConversionWarning: Data was converted to boolean for metric jaccard
#   warnings.warn(msg, DataConversionWarning)

# %%
simD_Robj = r.matrix(
    robjects.FloatVector(simD.flatten()),
    byrow=True,
    nrow=simD.shape[0],
    ncol=simD.shape[0],
)
simT_Robj = r.matrix(
    robjects.FloatVector(simT.flatten()),
    byrow=True,
    nrow=simT.shape[0],
    ncol=simT.shape[0],
)

# %%
constrNeig = r["constrNeig"]

# %%
# Use neighorhood size K = 3
lap = constrNeig(simD_Robj, simT_Robj, K=3)
simD_Robj, simT_Robj = lap[2], lap[3]
simD, simT = np.array(simD), np.array(simT)

# %% [markdown]
# ### Implementation

# %%
dvlp_size, test_size = 0.9, 0.1

ind_dvlp, ind_test = next(
    mc_split(
        Y,
        n_splits=1,
        random_state=random_state,
        train_size=dvlp_size,
        test_size=test_size,
    )
)

Y_test = get_submatrix(Y, ind_test)

# %%
from sklearn.model_selection import ParameterGrid

grid_dataset = ParameterGrid(
    {
        "train_size": np.arange(0.001, 0.2, 0.02),
        # "train_size": [0.2],
        "n_splits": [2],
    }
)

grid_model = ParameterGrid(
    {
        "lamU": [0.01],
        "lamV": [0.01],
        "cc": [1, 3, 5, 7, 9],  # confidence parameter
        # "cc": [1],
        "iterpara": [0.001],  # learning rate
        "numLat": [1000],  # rank
    }
)

# %% [markdown]
# Notes:
#
# - lamU and lamV doesn't effect too much here.
#
# - Main effects come from iterpara and numLat.

# %%
from tqdm import tqdm
from sklearn.model_selection import ShuffleSplit, KFold
from sklearn.model_selection import train_test_split
from scipy.special import expit


results = []
for par_dtst in tqdm(grid_dataset):
    # prepare the train dataset: take the specified share from the beginnig of the index array
    ind_train_all, _ = train_test_split(
        ind_dvlp,
        shuffle=False,
        random_state=random_state,
        test_size=(1 - (par_dtst["train_size"] / dvlp_size)),
    )

    # Run the experiment: the model
    for par_mdl in grid_model:  # tqdm.tqdm(, desc="cv %02d" % (cv,))
        Y_train = get_submatrix(Y, ind_train_all)

        Y_train[Y_train == 0] = 0.5
        Y_train[Y_train == -1] = 0.0

        Y_train_Robj = r.matrix(
            robjects.FloatVector(Y_train.toarray().flatten()),
            byrow=True,
            nrow=Y_train.shape[0],
            ncol=Y_train.shape[1],
        )

        # set up the model
        lamU, lamV, cc, iterpara, numLat = (
            par_mdl["lamU"],
            par_mdl["lamV"],
            par_mdl["cc"],
            par_mdl["iterpara"],
            par_mdl["numLat"],
        )

        out = updateUV(
            cc=cc,
            inMat=Y_train_Robj,
            Sd=simD_Robj,
            St=simT_Robj,
            lamU=lamU,
            lamV=lamV,
            numLat=numLat,
            initMethod="useSeed",
            thisSeed=123,
            iterpara=iterpara,
            maxIter=100,
        )

        # fit on the whole development dataset
        est_A, est_B = np.array(out[0]), np.array(out[1])

        # get the score
        prob_full = expit(simD @ est_A @ est_B.T @ simT.T)
        prob_test = get_submatrix(prob_full, ind_test)
        scores_test = mc_get_scores(Y_test, prob_test)
        d1_test = sum(abs(est_A).max(axis=1) > 0)
        d2_test = sum(abs(est_B).max(axis=1) > 0)

        # record the results
        results.append(
            {
                "train_size": par_dtst["train_size"],
                "lamU": par_mdl["lamU"],
                "lamV": par_mdl["lamV"],
                "cc": par_mdl["cc"],
                "iterpara": par_mdl["iterpara"],
                "numLat": par_mdl["numLat"],
                "test_score": scores_test["auc"],
                "test_d1": d1_test,
                "test_d2": d2_test,
            }
        )
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]/Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
#  10%|█         | 1/10 [07:33<1:07:58, 453.14s/it]/Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
#  20%|██        | 2/10 [14:25<57:14, 429.28s/it]  /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
#  30%|███       | 3/10 [20:47<47:34, 407.82s/it]/Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
#  40%|████      | 4/10 [28:17<42:26, 424.35s/it]/Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
#  50%|█████     | 5/10 [38:36<41:13, 494.62s/it]/Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
#  60%|██████    | 6/10 [48:23<35:04, 526.03s/it]/Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
#  70%|███████   | 7/10 [58:14<27:21, 547.20s/it]/Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
#  80%|████████  | 8/10 [1:06:06<17:26, 523.05s/it]/Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
#  90%|█████████ | 9/10 [1:15:29<08:55, 535.76s/it]/Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sijianfan/.pyenv/versions/BiSSGL_venv_311/lib/python3.11/site-packages/scipy/sparse/_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# 100%|██████████| 10/10 [1:25:18<00:00, 511.89s/it]

# %%
plt.plot(out[3]), results  # 0.797701913983849
# Out:
# ([<matplotlib.lines.Line2D at 0x1369a2610>],
#  [{'train_size': 0.001,
#    'lamU': 0.01,
#    'lamV': 0.01,
#    'cc': 1,
#    'iterpara': 0.001,
#    'numLat': 1000,
#    'test_score': 0.48041593756598494,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.001,
#    'lamU': 0.01,
#    'lamV': 0.01,
#    'cc': 3,
#    'iterpara': 0.001,
#    'numLat': 1000,
#    'test_score': 0.33341079048102873,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.001,
#    'lamU': 0.01,
#    'lamV': 0.01,
#    'cc': 5,
#    'iterpara': 0.001,
#    'numLat': 1000,
#    'test_score': 0.5382657125116812,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.001,
#    'lamU': 0.01,
#    'lamV': 0.01,
#    'cc': 7,
#    'iterpara': 0.001,
#    'numLat': 1000,
#    'test_score': 0.30293307535190217,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.001,
#    'lamU': 0.01,
#    'lamV': 0.01,
#    'cc': 9,
#    'iterpara': 0.001,
#    'numLat': 1000,
#    'test_score': 0.3113344580821986,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.021,
#    'lamU': 0.01,
#    'lamV': 0.01,
#    'cc': 1,
#    'iterpara': 0.001,
#    'numLat': 1000,
#    'test_score': 0.5883918286367752,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.021,
#    'lamU': 0.01,
#    'lamV': 0.01,
#    'cc': 3,
#    'iterpara': 0.001,
#    'numLat': 1000,
#    'test_score': 0.6679647794718697,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.021,
#    'lamU': 0.01,
#    'lamV': 0.01,
#    'cc': 5,
#    'iterpara': 0.001,
#    'numLat': 1000,
#    'test_score': 0.5454056726646305,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.021,
#    'lamU': 0.01,
#    'lamV': 0.01,
#    'cc': 7,
#    'iterpara': 0.001,
#    'numLat': 1000,
#    'test_score': 0.33889634540243224,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.021,
#    'lamU': 0.01,
#    'lamV': 0.01,
#    'cc': 9,
#    'iterpara': 0.001,
#    'numLat': 1000,
#    'test_score': 0.4497540395836339,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.041,
#    'lamU': 0.01,
#    'lamV': 0.01,
#    'cc': 1,
#    'iterpara': 0.001,
#    'numLat': 1000,
#    'test_score': 0.6206528351824789,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.041,
#    'lamU': 0.01,
#    'lamV': 0.01,
#    'cc': 3,
#    'iterpara': 0.001,
#    'numLat': 1000,
#    'test_score': 0.6003258740323083,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.041,
#    'lamU': 0.01,
#    'lamV': 0.01,
#    'cc': 5,
#    'iterpara': 0.001,
#    'numLat': 1000,
#    'test_score': 0.6353220273075645,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.041,
#    'lamU': 0.01,
#    'lamV': 0.01,
#    'cc': 7,
#    'iterpara': 0.001,
#    'numLat': 1000,
#    'test_score': 0.36517815143969945,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.041,
#    'lamU': 0.01,
#    'lamV': 0.01,
#    'cc': 9,
#    'iterpara': 0.001,
#    'numLat': 1000,
#    'test_score': 0.5428031752204028,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.061,
#    'lamU': 0.01,
#    'lamV': 0.01,
#    'cc': 1,
#    'iterpara': 0.001,
#    'numLat': 1000,
#    'test_score': 0.6070809526497452,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.061,
#    'lamU': 0.01,
#    'lamV': 0.01,
#    'cc': 3,
#    'iterpara': 0.001,
#    'numLat': 1000,
#    'test_score': 0.5321497337606542,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.061,
#    'lamU': 0.01,
#    'lamV': 0.01,
#    'cc': 5,
#    'iterpara': 0.001,
#    'numLat': 1000,
#    'test_score': 0.6214134518291803,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.061,
#    'lamU': 0.01,
#    'lamV': 0.01,
#    'cc': 7,
#    'iterpara': 0.001,
#    'numLat': 1000,
#    'test_score': 0.3288149997177675,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.061,
#    'lamU': 0.01,
#    'lamV': 0.01,
#    'cc': 9,
#    'iterpara': 0.001,
#    'numLat': 1000,
#    'test_score': 0.4715024596041637,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.081,
#    'lamU': 0.01,
#    'lamV': 0.01,
#    'cc': 1,
#    'iterpara': 0.001,
#    'numLat': 1000,
#    'test_score': 0.5311588885474223,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.081,
#    'lamU': 0.01,
#    'lamV': 0.01,
#    'cc': 3,
#    'iterpara': 0.001,
#    'numLat': 1000,
#    'test_score': 0.4070233563091512,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.081,
#    'lamU': 0.01,
#    'lamV': 0.01,
#    'cc': 5,
#    'iterpara': 0.001,
#    'numLat': 1000,
#    'test_score': 0.46701381266868625,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.081,
#    'lamU': 0.01,
#    'lamV': 0.01,
#    'cc': 7,
#    'iterpara': 0.001,
#    'numLat': 1000,
#    'test_score': 0.5366439730812892,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.081,
#    'lamU': 0.01,
#    'lamV': 0.01,
#    'cc': 9,
#    'iterpara': 0.001,
#    'numLat': 1000,
#    'test_score': 0.6322588636691482,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.101,
#    'lamU': 0.01,
#    'lamV': 0.01,
#    'cc': 1,
#    'iterpara': 0.001,
#    'numLat': 1000,
#    'test_score': 0.5657906482776499,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.101,
#    'lamU': 0.01,
#    'lamV': 0.01,
#    'cc': 3,
#    'iterpara': 0.001,
#    'numLat': 1000,
#    'test_score': 0.41325687967904934,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.101,
#    'lamU': 0.01,
#    'lamV': 0.01,
#    'cc': 5,
#    'iterpara': 0.001,
#    'numLat': 1000,
#    'test_score': 0.40644932671863926,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.101,
#    'lamU': 0.01,
#    'lamV': 0.01,
#    'cc': 7,
#    'iterpara': 0.001,
#    'numLat': 1000,
#    'test_score': 0.38146359514058314,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.101,
#    'lamU': 0.01,
#    'lamV': 0.01,
#    'cc': 9,
#    'iterpara': 0.001,
#    'numLat': 1000,
#    'test_score': 0.5601742210905046,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.121,
#    'lamU': 0.01,
#    'lamV': 0.01,
#    'cc': 1,
#    'iterpara': 0.001,
#    'numLat': 1000,
#    'test_score': 0.5761474842629236,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.121,
#    'lamU': 0.01,
#    'lamV': 0.01,
#    'cc': 3,
#    'iterpara': 0.001,
#    'numLat': 1000,
#    'test_score': 0.41778916812486805,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.121,
#    'lamU': 0.01,
#    'lamV': 0.01,
#    'cc': 5,
#    'iterpara': 0.001,
#    'numLat': 1000,
#    'test_score': 0.4148760058453491,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.121,
#    'lamU': 0.01,
#    'lamV': 0.01,
#    'cc': 7,
#    'iterpara': 0.001,
#    'numLat': 1000,
#    'test_score': 0.40370017289355237,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.121,
#    'lamU': 0.01,
#    'lamV': 0.01,
#    'cc': 9,
#    'iterpara': 0.001,
#    'numLat': 1000,
#    'test_score': 0.6756237861388291,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.14100000000000001,
#    'lamU': 0.01,
#    'lamV': 0.01,
#    'cc': 1,
#    'iterpara': 0.001,
#    'numLat': 1000,
#    'test_score': 0.5827005053007449,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.14100000000000001,
#    'lamU': 0.01,
#    'lamV': 0.01,
#    'cc': 3,
#    'iterpara': 0.001,
#    'numLat': 1000,
#    'test_score': 0.6429773754047946,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.14100000000000001,
#    'lamU': 0.01,
#    'lamV': 0.01,
#    'cc': 5,
#    'iterpara': 0.001,
#    'numLat': 1000,
#    'test_score': 0.605700574290917,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.14100000000000001,
#    'lamU': 0.01,
#    'lamV': 0.01,
#    'cc': 7,
#    'iterpara': 0.001,
#    'numLat': 1000,
#    'test_score': 0.723503279123783,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.14100000000000001,
#    'lamU': 0.01,
#    'lamV': 0.01,
#    'cc': 9,
#    'iterpara': 0.001,
#    'numLat': 1000,
#    'test_score': 0.33766032375206184,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.161,
#    'lamU': 0.01,
#    'lamV': 0.01,
#    'cc': 1,
#    'iterpara': 0.001,
#    'numLat': 1000,
#    'test_score': 0.8181087703233548,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.161,
#    'lamU': 0.01,
#    'lamV': 0.01,
#    'cc': 3,
#    'iterpara': 0.001,
#    'numLat': 1000,
#    'test_score': 0.677787412011398,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.161,
#    'lamU': 0.01,
#    'lamV': 0.01,
#    'cc': 5,
#    'iterpara': 0.001,
#    'numLat': 1000,
#    'test_score': 0.5840125729362008,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.161,
#    'lamU': 0.01,
#    'lamV': 0.01,
#    'cc': 7,
#    'iterpara': 0.001,
#    'numLat': 1000,
#    'test_score': 0.3189818618565882,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.161,
#    'lamU': 0.01,
#    'lamV': 0.01,
#    'cc': 9,
#    'iterpara': 0.001,
#    'numLat': 1000,
#    'test_score': 0.7234272331386974,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.181,
#    'lamU': 0.01,
#    'lamV': 0.01,
#    'cc': 1,
#    'iterpara': 0.001,
#    'numLat': 1000,
#    'test_score': 0.6580053164244694,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.181,
#    'lamU': 0.01,
#    'lamV': 0.01,
#    'cc': 3,
#    'iterpara': 0.001,
#    'numLat': 1000,
#    'test_score': 0.4712574922281526,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.181,
#    'lamU': 0.01,
#    'lamV': 0.01,
#    'cc': 5,
#    'iterpara': 0.001,
#    'numLat': 1000,
#    'test_score': 0.4011795751459769,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.181,
#    'lamU': 0.01,
#    'lamV': 0.01,
#    'cc': 7,
#    'iterpara': 0.001,
#    'numLat': 1000,
#    'test_score': 0.6126845748428383,
#    'test_d1': 6949,
#    'test_d2': 13},
#   {'train_size': 0.181,
#    'lamU': 0.01,
#    'lamV': 0.01,
#    'cc': 9,
#    'iterpara': 0.001,
#    'numLat': 1000,
#    'test_score': 0.5486790995319122,
#    'test_d1': 6949,
#    'test_d2': 13}])

# %%
filename_output
# Out:
# '/Users/sijianfan/Documents/projects/BiSSGL/outputs/results/realAnalysis/tuberculosis/results_drimc.gz'

# %%
with gzip.open(filename_output, "wb+", 4) as fout:
    pickle.dump(results, fout)
